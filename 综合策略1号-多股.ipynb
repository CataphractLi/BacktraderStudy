# %%
# 数据接口 
import akshare as ak
import baostock as bs
import tushare as ts

# 基础模块
import datetime
from itertools import product
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time

# 回测框架
import backtrader as bt

# 基础函数
import utilsJ

# %% [markdown]
# # 策略

# %%
class Strategy_comp_mul(bt.Strategy):
    
    params = (
        # General params
        ('printlog', False),
        ('p_stake', 100),
        ('buy_signal', 'b'),
        ('sell_signal', 'b'),

        # Indicator params
        ('bollinger_per', 20),
        ('bollinger_dev', 2),
        ('rsi_short', 6),
        ('rsi_long', 12),
        ('wave_period', 7),
        ('wr', 14),
        
        # ATR params
        ('using_atr', False),
        ('atr_period', 14),
        ('atr_percent', 1),
    )
    
    
    def log(self, txt, dt=None, doprint=False):
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s: %s' % (dt.isoformat(), txt))
            #with open('log.txt', 'a') as file:
                #file.write('%s: %s \n' % (dt.isoformat(), txt))
        
    
    def __init__(self):

        # Record ATR Initial
        self.atr_initial = self.broker.get_cash()
        self.inds = dict()
        self.data_tracker = None

        for d in self.datas:

            self.inds[d] = dict()
            
            # Keep references to lines in the data[0] dataseries
            self.inds[d]['dataclose'] = d.close
            self.inds[d]['datahigh'] = d.high
            self.inds[d]['datalow'] = d.low

            # Keep references to executed order & price
            self.inds[d]['buyprice'] = 0
            self.inds[d]['sellprice'] = 0
            self.inds[d]['order'] = None
                
            # Add indicators
            ## Wave indicator
            ### MovingAverageSimple indicator
            self.inds[d]['sma'] = bt.indicators.SimpleMovingAverage(d, period=self.params.wave_period)
            self.inds[d]['wave_buy'] = bt.And(self.inds[d]['sma'](0) > self.inds[d]['sma'](-1), 
                                              self.inds[d]['sma'](-1) < self.inds[d]['sma'](-2), 
                                              self.inds[d]['sma'](-2) < self.inds[d]['sma'](-3))

            self.inds[d]['wave_sell'] = bt.And(self.inds[d]['sma'](0) < self.inds[d]['sma'](-1), 
                                               self.inds[d]['sma'](-1) > self.inds[d]['sma'](-2), 
                                               self.inds[d]['sma'](-2) > self.inds[d]['sma'](-3))

            ## MACD indicator
            self.inds[d]['macdhisto'] = bt.indicators.MACDHisto(d)
            self.inds[d]['macd_buy'] = bt.And(self.inds[d]['macdhisto'](0) > 0, self.inds[d]['macdhisto'](-1) < 0)
            self.inds[d]['macd_sell'] = bt.And(self.inds[d]['macdhisto'](0) < 0, self.inds[d]['macdhisto'](-1) > 0)

            ## Bollinger Bands indicator
            self.inds[d]['bolling'] = bt.indicators.BollingerBands(d, 
                                                        period=self.params.bollinger_per, 
                                                        devfactor=self.params.bollinger_dev)
            self.inds[d]['bolling_buy'] = bt.Or(bt.And(self.inds[d]['dataclose'](0) > self.inds[d]['bolling'].top(0), 
                                                       self.inds[d]['dataclose'](-1) < self.inds[d]['bolling'].top(-1)), 
                                                bt.And(self.inds[d]['dataclose'](0) > self.inds[d]['bolling'].bot(0), 
                                                       self.inds[d]['dataclose'](-1) < self.inds[d]['bolling'].bot(-1)))
            self.inds[d]['bolling_sell'] = bt.Or(bt.And(self.inds[d]['dataclose'](0) < self.inds[d]['bolling'].top(0), 
                                                        self.inds[d]['dataclose'](-1) > self.inds[d]['bolling'].top(-1)), 
                                                 bt.And(self.inds[d]['dataclose'](0) < self.inds[d]['bolling'].bot(0), 
                                                        self.inds[d]['dataclose'](-1) > self.inds[d]['bolling'].bot(-1)))

            ## RSI indicator
            self.inds[d]['rsi_s'] = bt.indicators.RelativeStrengthIndex(d, period=self.params.rsi_short, safediv=True)
            self.inds[d]['rsi_l'] = bt.indicators.RelativeStrengthIndex(d, period=self.params.rsi_long, safediv=True)
            self.inds[d]['rsi_buy'] = bt.And(self.inds[d]['rsi_s'](0) > self.inds[d]['rsi_l'](0), 
                                             self.inds[d]['rsi_s'](-1) < self.inds[d]['rsi_l'](-1))
            self.inds[d]['rsi_sell'] = bt.And(self.inds[d]['rsi_s'](0) < self.inds[d]['rsi_l'](0), 
                                              self.inds[d]['rsi_s'](-1) > self.inds[d]['rsi_l'](-1))

            ## WilliamR indicator
            self.inds[d]['wr'] = bt.indicators.WilliamsR(d, period=self.params.wr)
            self.inds[d]['wr_buy'] = self.inds[d]['wr'] < -80
            self.inds[d]['wr_sell'] = self.inds[d]['wr'] > -20
        
            ## ATR indicator
            self.inds[d]['tr'] = bt.indicators.Max((self.inds[d]['datahigh'](0) - self.inds[d]['datalow'](0)), 
                                                    abs(self.inds[d]['dataclose'](-1) - self.inds[d]['datahigh'](0)),
                                                    abs(self.inds[d]['dataclose'](-1) - self.inds[d]['datalow'](0)))
            self.inds[d]['atr'] = bt.indicators.SimpleMovingAverage(self.inds[d]['tr'], period=self.params.atr_period)





    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                if self.inds[self.data_tracker]['wave_buy']:
                    self.inds[self.data_tracker]['buyprice']
                self.log('BUY EXECUTED, Price:%.2f, Lot:%i, Cash:%i.' %
                         (order.executed.price,
                          order.executed.size,
                          self.broker.get_cash()))

            else:  # Sell
                self.inds[self.data_tracker]['sellprice'] = order.executed.price
                self.log('SELL EXECUTED, Price:%.2f, Lot:%i, Cash:%i.' %
                        (order.executed.price,
                          -order.executed.size,
                          self.broker.get_cash()))

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        #self.order = None


    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))
    

    def next(self):

        for d in self.datas:
        # Check if an order is pending ... if yes, we cannot send a 2nd one
            if self.inds[d]['order']:
                return
            self.data_tracker = d
            buy_indicator = (self.params.buy_signal == 'b' and self.inds[d]['bolling_buy']) or \
                            (self.params.buy_signal == 'm' and self.inds[d]['macd_buy']) or \
                            (self.params.buy_signal == 'w' and self.inds[d]['wave_buy'] and self.inds[d]['dataclose'][0] > self.inds[d]['buyprice']) or \
                            (self.params.buy_signal == 'r' and self.inds[d]['rsi_buy']) or \
                            (self.params.buy_signal == 'wr' and self.inds[d]['wr_buy'])
            
            #buy_indicator = self.inds[d]['bolling_buy'] and \
            #                self.inds[d]['macd_buy'] and \
            #                (self.inds[d]['wave_buy'] and self.inds[d]['dataclose'][0] > self.inds[d]['buyprice']) and \
            #                self.inds[d]['rsi_buy'] and \
            #                self.inds[d]['wr_buy']
                            
            sell_indicator = (self.params.sell_signal == 'b' and self.inds[d]['bolling_sell']) or \
                            (self.params.sell_signal == 'm' and self.inds[d]['macd_sell']) or \
                            (self.params.sell_signal == 'w' and self.inds[d]['wave_sell']) or \
                            (self.params.sell_signal == 'r' and self.inds[d]['rsi_sell']) or \
                            (self.params.sell_signal == 'wr' and self.inds[d]['wr_sell'])
            
            #sell_indicator = self.inds[d]['bolling_sell'] or \
            #                 self.inds[d]['macd_sell'] or \
            #                 self.inds[d]['wave_sell'] or \
            #                 self.inds[d]['rsi_sell'] or \
            #                 self.inds[d]['wr_sell']

            if sell_indicator and self.getposition(d).size > 0:
                self.log('Sell CREATE(Close), Code: %s, Price: %.2f, Current Position: %i' % 
                         (d._name, 
                          self.inds[d]['dataclose'][0],
                          self.getposition(d).size))
                self.close(data=d, name=d._name)
                
            elif buy_indicator:
                if self.params.using_atr:
                    opt_pos = np.floor(self.atr_initial * self.params.atr_percent / self.params.p_stake / self.inds[d]['atr'][0])
                    if opt_pos*self.params.p_stake > 0 and self.getposition(d).size < opt_pos*self.params.p_stake:
                        self.log('BUY CREATE, Code: %s, Price: %.2f, Lots: %i, Current Position: %i' % 
                                (d._name, 
                                 self.inds[d]['dataclose'][0], 
                                 opt_pos*self.params.p_stake-self.getposition(d).size,
                                 self.getposition(d).size))
                        self.buy(data=d, size=opt_pos*self.params.p_stake-self.getposition(d).size, name=d._name)
                    
                    elif opt_pos*self.params.p_stake > 0 and self.getposition(d).size > opt_pos*self.params.p_stake:
                        self.log('SELL CREATE, Code: %s, Price: %.2f, Lots: %i, Current Position: %i' % 
                                (d._name, 
                                 self.inds[d]['dataclose'][0], 
                                 self.getposition(d).size-opt_pos*self.params.p_stake,
                                 self.getposition(d).size))
                        self.sell(data=d, size=self.getposition(d).size-opt_pos*self.params.p_stake, name=d._name)
                else:
                    self.log('BUY CREATE, Code: %s, Price: %.2f, Lots: %i, Current Position: %i' % 
                            (d._name, 
                             self.inds[d]['dataclose'][0],
                             self.params.p_stake,
                             self.getposition(d).size))
                    self.buy(data=d, size=self.params.p_stake, name=d._name)

    def stop(self):
        self.log('Ending Position:%i. Ending Value:%.2f.' %
                (1,
                self.cerebro.broker.getvalue()), doprint=False)

# %% [markdown]
# # 全市场选股

# %% [markdown]
# ## 数据下载

# %%
s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 365)
e_date = datetime.date(2020, 12, 31)

#s_date = datetime.datetime.now() - datetime.timedelta(days = 365)
#e_date = datetime.datetime.now()

stock_index = '399300.SZ'

# Download Data
utilsJ.index_to_csv_tushare('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6', stock_index,
                             0.2, s_date, e_date)

# %%
profit_list = []

# 904ff4752522814dca00e032a709fdfc26d8744913500ef204e02157
# 74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6

s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 365)
e_date = datetime.date(2020, 12, 31)

stock_index = '399300.SZ'
pro = ts.pro_api('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6')
index_list = np.unique(pro.index_weight(index_code=stock_index,
                                        start_date=s_date.strftime('%Y%m%d'),
                                        end_date=e_date.strftime('%Y%m%d')).con_code).tolist()

buy_s = ['b','m','w', 'r', 'wr']
sell_s = ['b','m','w', 'r', 'wr']
for s in product(*[buy_s, sell_s]):

    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    strats = cerebro.addstrategy(Strategy_comp_mul, printlog=False, using_atr=True, atr_percent=1/len(index_list)/10, buy_signal = s[0], sell_signal = s[1]) 

    for s_code in index_list:
        df = pd.read_csv('.\\Data\\' + s_code + '.csv')
        df.index=pd.to_datetime(df.trade_date)
        data = bt.feeds.PandasData(dataname=df,fromdate=s_date,todate=e_date)

        # Add the index Data Feed to Cerebo
        cerebro.adddata(data, name = s_code)
    
    # Set cash inside the strategy
    cerebro.broker = bt.brokers.BackBroker(coc=True)   
    cerebro.broker.setcash(5000000)

    # Set commission
    #cerebro.broker.setcommission()

    # Print out the starting conditions
    start_value = cerebro.broker.getvalue()
    #print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    final_value = cerebro.broker.getvalue()
    #print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    print('(%s, %s) Net Profit: %.2f%%' % (s[0], s[1], (final_value - start_value) / start_value * 100))
    profit_list.append((s, (final_value - start_value) / start_value * 100))
# Out:
# (b, b) Net Profit: 3.16%
# (b, m) Net Profit: 0.71%
# (b, w) Net Profit: 1.37%
# (b, r) Net Profit: 2.70%
# (b, wr) Net Profit: 0.13%
# (m, b) Net Profit: 0.55%
# (m, m) Net Profit: 3.44%
# (m, w) Net Profit: 0.71%
# (m, r) Net Profit: -0.57%
# (m, wr) Net Profit: -0.75%
# (w, b) Net Profit: 0.28%
# (w, m) Net Profit: 1.13%
# (w, w) Net Profit: -0.24%
# (w, r) Net Profit: 0.05%
# (w, wr) Net Profit: -2.49%
# (r, b) Net Profit: 1.23%
# (r, m) Net Profit: -0.55%
# (r, w) Net Profit: 0.99%
# (r, r) Net Profit: 3.59%
# (r, wr) Net Profit: -0.80%
# (wr, b) Net Profit: 2.58%
# (wr, m) Net Profit: 7.56%
# (wr, w) Net Profit: 6.15%
# (wr, r) Net Profit: 4.60%
# (wr, wr) Net Profit: 0.86%

# %%
s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 365)
e_date = datetime.date(2020, 12, 31)

stock_index = '399300.SZ'
#pro = ts.pro_api('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6')
#index_list = np.unique(pro.index_weight(index_code=stock_index,
#                                        start_date=s_date.strftime('%Y%m%d'),
#                                        end_date=e_date.strftime('%Y%m%d')).con_code).tolist()

cerebro = bt.Cerebro()

# Add a strategy
strats = cerebro.addstrategy(Strategy_comp_mul, printlog=True, using_atr=True, atr_percent=1/len(index_list)/10, buy_signal = 'wr', sell_signal = 'm') 

for s_code in index_list:
    df = pd.read_csv('.\\Data\\' + s_code + '.csv')
    df.index=pd.to_datetime(df.trade_date)
    data = bt.feeds.PandasData(dataname=df,fromdate=s_date,todate=e_date)

    # Add the index Data Feed to Cerebo
    cerebro.adddata(data, name = s_code)

# Set cash inside the strategy
cerebro.broker = bt.brokers.BackBroker(coc=True)   
cerebro.broker.setcash(5000000)

# Set commission
#cerebro.broker.setcommission()

# Print out the starting conditions
start_value = cerebro.broker.getvalue()
#print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

# Run over everything
cerebro.run()

# Print out the final result
final_value = cerebro.broker.getvalue()
#print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
print('Net Profit: %.2f%%' % ((final_value - start_value) / start_value * 100))
# Out:
# 2020-08-13: BUY CREATE, Code: 000538.SZ, Price: 103.18, Lots: 300, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 000568.SZ, Price: 111.18, Lots: 300, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 000651.SZ, Price: 55.78, Lots: 1100, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 000708.SZ, Price: 18.18, Lots: 1900, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 000783.SZ, Price: 8.36, Lots: 4200, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 000786.SZ, Price: 29.66, Lots: 800, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 000895.SZ, Price: 51.09, Lots: 500, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 000938.SZ, Price: 41.06, Lots: 900, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 000963.SZ, Price: 26.29, Lots: 1200, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 000977.SZ, Price: 35.75, Lots: 1000, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002007.SZ, Price: 54.04, Lots: 200, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002120.SZ, Price: 23.28, Lots: 2100, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002153.SZ, Price: 32.72, Lots: 900, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002252.SZ, Price: 9.40, Lots: 3300, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002294.SZ, Price: 31.80, Lots: 1000, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002352.SZ, Price: 64.98, Lots: 400, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002410.SZ, Price: 65.80, Lots: 400, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002414.SZ, Price: 37.39, Lots: 600, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002558.SZ, Price: 20.33, Lots: 1800, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002602.SZ, Price: 10.59, Lots: 2700, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002773.SZ, Price: 43.79, Lots: 600, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002916.SZ, Price: 144.00, Lots: 200, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 002938.SZ, Price: 45.65, Lots: 600, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 300003.SZ, Price: 38.55, Lots: 800, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 300014.SZ, Price: 50.39, Lots: 500, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 300015.SZ, Price: 44.40, Lots: 900, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 300059.SZ, Price: 24.91, Lots: 1000, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 300144.SZ, Price: 15.90, Lots: 1500, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 300347.SZ, Price: 100.50, Lots: 200, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 300433.SZ, Price: 29.38, Lots: 800, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 300529.SZ, Price: 68.93, Lots: 400, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 300676.SZ, Price: 149.80, Lots: 100, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600031.SH, Price: 20.23, Lots: 2100, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600061.SH, Price: 14.54, Lots: 2500, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600109.SH, Price: 13.87, Lots: 2300, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600208.SH, Price: 3.33, Lots: 12800, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600276.SH, Price: 88.88, Lots: 500, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600332.SH, Price: 34.32, Lots: 1000, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600362.SH, Price: 15.02, Lots: 1900, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600438.SH, Price: 23.39, Lots: 700, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600489.SH, Price: 10.14, Lots: 2400, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600547.SH, Price: 38.88, Lots: 600, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600566.SH, Price: 24.10, Lots: 1900, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600585.SH, Price: 59.03, Lots: 700, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600588.SH, Price: 43.86, Lots: 700, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600600.SH, Price: 74.61, Lots: 400, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600745.SH, Price: 134.20, Lots: 200, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600809.SH, Price: 162.36, Lots: 100, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600845.SH, Price: 66.67, Lots: 300, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600998.SH, Price: 17.68, Lots: 2000, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600999.SH, Price: 20.11, Lots: 1600, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 601212.SH, Price: 3.11, Lots: 6400, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 601225.SH, Price: 7.72, Lots: 7600, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 601298.SH, Price: 6.27, Lots: 7600, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 601328.SH, Price: 4.76, Lots: 28400, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 601555.SH, Price: 10.23, Lots: 2400, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 601600.SH, Price: 3.22, Lots: 11800, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 601878.SH, Price: 15.40, Lots: 1600, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 601899.SH, Price: 5.72, Lots: 4100, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 601988.SH, Price: 3.33, Lots: 39500, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 603160.SH, Price: 206.52, Lots: 200, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 603259.SH, Price: 107.13, Lots: 200, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 603260.SH, Price: 29.87, Lots: 1000, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 603501.SH, Price: 182.97, Lots: 100, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 603658.SH, Price: 144.77, Lots: 200, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 603986.SH, Price: 210.63, Lots: 100, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 603993.SH, Price: 4.31, Lots: 6400, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 688036.SH, Price: 94.51, Lots: 100, Current Position: 0
# 2020-08-14: BUY EXECUTED, Price:103.18, Lot:300, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:111.18, Lot:300, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:55.78, Lot:1100, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:18.18, Lot:1900, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:8.36, Lot:4200, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:29.66, Lot:800, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:51.09, Lot:500, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:41.06, Lot:900, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:26.29, Lot:1200, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:35.75, Lot:1000, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:54.04, Lot:200, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:23.28, Lot:2100, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:32.72, Lot:900, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:9.40, Lot:3300, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:31.80, Lot:1000, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:64.98, Lot:400, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:65.80, Lot:400, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:37.39, Lot:600, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:20.33, Lot:1800, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:10.59, Lot:2700, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:43.79, Lot:600, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:144.00, Lot:200, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:45.65, Lot:600, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:38.55, Lot:800, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:50.39, Lot:500, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:44.40, Lot:900, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:24.91, Lot:1000, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:15.90, Lot:1500, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:100.50, Lot:200, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:29.38, Lot:800, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:68.93, Lot:400, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:149.80, Lot:100, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:20.23, Lot:2100, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:14.54, Lot:2500, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:13.87, Lot:2300, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:3.33, Lot:12800, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:88.88, Lot:500, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:34.32, Lot:1000, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:15.02, Lot:1900, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:23.39, Lot:700, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:10.14, Lot:2400, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:38.88, Lot:600, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:24.10, Lot:1900, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:59.03, Lot:700, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:43.86, Lot:700, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:74.61, Lot:400, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:134.20, Lot:200, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:162.36, Lot:100, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:66.67, Lot:300, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:17.68, Lot:2000, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:20.11, Lot:1600, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:3.11, Lot:6400, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:7.72, Lot:7600, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:6.27, Lot:7600, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:4.76, Lot:28400, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:10.23, Lot:2400, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:3.22, Lot:11800, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:15.40, Lot:1600, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:5.72, Lot:4100, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:3.33, Lot:39500, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:206.52, Lot:200, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:107.13, Lot:200, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:29.87, Lot:1000, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:182.97, Lot:100, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:144.77, Lot:200, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:210.63, Lot:100, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:4.31, Lot:6400, Cash:2741384.
# 2020-08-14: BUY EXECUTED, Price:94.51, Lot:100, Cash:2741384.
# 2020-08-14: BUY CREATE, Code: 000708.SZ, Price: 18.44, Lots: 200, Current Position: 1900
# 2020-08-14: BUY CREATE, Code: 002558.SZ, Price: 20.53, Lots: 100, Current Position: 1800
# 2020-08-14: BUY CREATE, Code: 002602.SZ, Price: 10.64, Lots: 200, Current Position: 2700
# 2020-08-14: BUY CREATE, Code: 300003.SZ, Price: 38.80, Lots: 100, Current Position: 800
# 2020-08-14: Sell CREATE(Close), Code: 600031.SH, Price: 20.40, Current Position: 2100
# 2020-08-14: BUY CREATE, Code: 600276.SH, Price: 89.50, Lots: 100, Current Position: 500
# 2020-08-14: BUY CREATE, Code: 600362.SH, Price: 15.10, Lots: 100, Current Position: 1900
# 2020-08-14: BUY CREATE, Code: 600438.SH, Price: 23.47, Lots: 100, Current Position: 700
# 2020-08-14: BUY CREATE, Code: 600489.SH, Price: 10.20, Lots: 200, Current Position: 2400
# 2020-08-14: BUY CREATE, Code: 600566.SH, Price: 24.24, Lots: 100, Current Position: 1900
# 2020-08-14: BUY CREATE, Code: 601212.SH, Price: 3.14, Lots: 400, Current Position: 6400
# 2020-08-14: BUY CREATE, Code: 601298.SH, Price: 6.30, Lots: 200, Current Position: 7600
# 2020-08-14: BUY CREATE, Code: 601555.SH, Price: 10.36, Lots: 200, Current Position: 2400
# 2020-08-14: BUY CREATE, Code: 601600.SH, Price: 3.25, Lots: 300, Current Position: 11800
# 2020-08-14: BUY CREATE, Code: 601878.SH, Price: 15.47, Lots: 100, Current Position: 1600
# 2020-08-14: BUY CREATE, Code: 603799.SH, Price: 42.11, Lots: 600, Current Position: 0
# 2020-08-14: BUY CREATE, Code: 603993.SH, Price: 4.35, Lots: 300, Current Position: 6400
# 2020-08-17: BUY EXECUTED, Price:18.44, Lot:200, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:20.53, Lot:100, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:10.64, Lot:200, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:38.80, Lot:100, Cash:2721523.
# 2020-08-17: SELL EXECUTED, Price:20.40, Lot:2100, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:89.50, Lot:100, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:15.10, Lot:100, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:23.47, Lot:100, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:10.20, Lot:200, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:24.24, Lot:100, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:3.14, Lot:400, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:6.30, Lot:200, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:10.36, Lot:200, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:3.25, Lot:300, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:15.47, Lot:100, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:42.11, Lot:600, Cash:2721523.
# 2020-08-17: BUY EXECUTED, Price:4.35, Lot:300, Cash:2721523.
# 2020-08-17: OPERATION PROFIT, GROSS 357.00, NET 357.00
# 2020-08-17: Sell CREATE(Close), Code: 300347.SZ, Price: 100.78, Current Position: 200
# 2020-08-17: BUY CREATE, Code: 600845.SH, Price: 67.40, Lots: 100, Current Position: 300
# 2020-08-17: BUY CREATE, Code: 601888.SH, Price: 207.20, Lots: 100, Current Position: 0
# 2020-08-18: SELL EXECUTED, Price:100.78, Lot:200, Cash:2714219.
# 2020-08-18: BUY EXECUTED, Price:67.40, Lot:100, Cash:2714219.
# 2020-08-18: BUY EXECUTED, Price:207.20, Lot:100, Cash:2714219.
# 2020-08-18: OPERATION PROFIT, GROSS 56.00, NET 56.00
# 2020-08-18: BUY CREATE, Code: 002050.SZ, Price: 21.74, Lots: 1300, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 002916.SZ, Price: 146.44, Lots: 100, Current Position: 200
# 2020-08-18: BUY CREATE, Code: 300142.SZ, Price: 74.99, Lots: 100, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 300529.SZ, Price: 69.22, Lots: 100, Current Position: 400
# 2020-08-18: BUY CREATE, Code: 600196.SH, Price: 58.52, Lots: 200, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 600816.SH, Price: 1.91, Lots: 31000, Current Position: 0
# 2020-08-19: BUY EXECUTED, Price:21.74, Lot:1300, Cash:2585978.
# 2020-08-19: BUY EXECUTED, Price:146.44, Lot:100, Cash:2585978.
# 2020-08-19: BUY EXECUTED, Price:74.99, Lot:100, Cash:2585978.
# 2020-08-19: BUY EXECUTED, Price:69.22, Lot:100, Cash:2585978.
# 2020-08-19: BUY EXECUTED, Price:58.52, Lot:200, Cash:2585978.
# 2020-08-19: BUY EXECUTED, Price:1.91, Lot:31000, Cash:2585978.
# 2020-08-19: Sell CREATE(Close), Code: 000538.SZ, Price: 102.97, Current Position: 300
# 2020-08-19: BUY CREATE, Code: 000651.SZ, Price: 55.19, Lots: 500, Current Position: 1100
# 2020-08-19: BUY CREATE, Code: 002008.SZ, Price: 37.96, Lots: 800, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 002024.SZ, Price: 10.24, Lots: 3300, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 002153.SZ, Price: 32.22, Lots: 100, Current Position: 900
# 2020-08-19: BUY CREATE, Code: 002202.SZ, Price: 11.57, Lots: 2600, Current Position: 0
# 2020-08-19: Sell CREATE(Close), Code: 002252.SZ, Price: 9.30, Current Position: 3300
# 2020-08-19: BUY CREATE, Code: 002411.SZ, Price: 7.17, Lots: 5900, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 002460.SZ, Price: 54.21, Lots: 500, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 002463.SZ, Price: 23.31, Lots: 3000, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 002475.SZ, Price: 50.29, Lots: 500, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 002594.SZ, Price: 79.65, Lots: 400, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 002600.SZ, Price: 11.18, Lots: 2400, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 002714.SZ, Price: 89.60, Lots: 400, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 002812.SZ, Price: 75.78, Lots: 300, Current Position: 0
# 2020-08-19: SELL CREATE, Code: 002916.SZ, Price: 141.90, Lots: 100, Current Position: 300
# 2020-08-19: BUY CREATE, Code: 002938.SZ, Price: 45.78, Lots: 100, Current Position: 600
# 2020-08-19: BUY CREATE, Code: 300024.SZ, Price: 15.03, Lots: 2600, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 300122.SZ, Price: 135.60, Lots: 100, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 300347.SZ, Price: 99.31, Lots: 300, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 300413.SZ, Price: 61.03, Lots: 400, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 300628.SZ, Price: 61.21, Lots: 600, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 600161.SH, Price: 44.61, Lots: 400, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 600183.SH, Price: 27.03, Lots: 1700, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 600297.SH, Price: 3.94, Lots: 6200, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 600332.SH, Price: 34.29, Lots: 200, Current Position: 1000
# 2020-08-19: BUY CREATE, Code: 600438.SH, Price: 22.54, Lots: 100, Current Position: 800
# 2020-08-19: Sell CREATE(Close), Code: 600547.SH, Price: 30.28, Current Position: 600
# 2020-08-19: Sell CREATE(Close), Code: 600745.SH, Price: 132.87, Current Position: 200
# 2020-08-19: BUY CREATE, Code: 600760.SH, Price: 64.33, Lots: 200, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 600887.SH, Price: 34.99, Lots: 1100, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 601012.SH, Price: 53.54, Lots: 500, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 601231.SH, Price: 23.00, Lots: 900, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 601933.SH, Price: 9.00, Lots: 6900, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 603260.SH, Price: 29.88, Lots: 100, Current Position: 1000
# 2020-08-20: SELL EXECUTED, Price:102.97, Lot:300, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:55.19, Lot:500, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:37.96, Lot:800, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:10.24, Lot:3300, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:32.22, Lot:100, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:11.57, Lot:2600, Cash:1890288.
# 2020-08-20: SELL EXECUTED, Price:9.30, Lot:3300, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:7.17, Lot:5900, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:54.21, Lot:500, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:23.31, Lot:3000, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:50.29, Lot:500, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:79.65, Lot:400, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:11.18, Lot:2400, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:89.60, Lot:400, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:75.78, Lot:300, Cash:1890288.
# 2020-08-20: SELL EXECUTED, Price:141.90, Lot:100, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:45.78, Lot:100, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:15.03, Lot:2600, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:135.60, Lot:100, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:99.31, Lot:300, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:61.03, Lot:400, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:61.21, Lot:600, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:44.61, Lot:400, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:27.03, Lot:1700, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:3.94, Lot:6200, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:34.29, Lot:200, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:22.54, Lot:100, Cash:1890288.
# 2020-08-20: SELL EXECUTED, Price:30.28, Lot:600, Cash:1890288.
# 2020-08-20: SELL EXECUTED, Price:132.87, Lot:200, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:64.33, Lot:200, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:34.99, Lot:1100, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:53.54, Lot:500, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:23.00, Lot:900, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:9.00, Lot:6900, Cash:1890288.
# 2020-08-20: BUY EXECUTED, Price:29.88, Lot:100, Cash:1890288.
# 2020-08-20: OPERATION PROFIT, GROSS -63.00, NET -63.00
# 2020-08-20: OPERATION PROFIT, GROSS -330.00, NET -330.00
# 2020-08-20: OPERATION PROFIT, GROSS -5160.00, NET -5160.00
# 2020-08-20: OPERATION PROFIT, GROSS -266.00, NET -266.00
# 2020-08-20: BUY CREATE, Code: 000066.SZ, Price: 18.74, Lots: 1100, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 000333.SZ, Price: 69.04, Lots: 600, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 000338.SZ, Price: 15.48, Lots: 2600, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 000538.SZ, Price: 101.30, Lots: 400, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 000629.SZ, Price: 2.21, Lots: 21400, Current Position: 0
# 2020-08-20: SELL CREATE, Code: 000651.SZ, Price: 54.13, Lots: 100, Current Position: 1600
# 2020-08-20: BUY CREATE, Code: 002024.SZ, Price: 10.24, Lots: 200, Current Position: 3300
# 2020-08-20: BUY CREATE, Code: 002120.SZ, Price: 22.75, Lots: 200, Current Position: 2100
# 2020-08-20: BUY CREATE, Code: 002129.SZ, Price: 22.81, Lots: 1500, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 002153.SZ, Price: 32.32, Lots: 100, Current Position: 1000
# 2020-08-20: BUY CREATE, Code: 002179.SZ, Price: 42.75, Lots: 500, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 002202.SZ, Price: 11.43, Lots: 400, Current Position: 2600
# 2020-08-20: BUY CREATE, Code: 002252.SZ, Price: 9.34, Lots: 4100, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 002304.SZ, Price: 127.52, Lots: 300, Current Position: 0
# 2020-08-20: SELL CREATE, Code: 002411.SZ, Price: 6.71, Lots: 400, Current Position: 5900
# 2020-08-20: BUY CREATE, Code: 002415.SZ, Price: 37.81, Lots: 1000, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 002463.SZ, Price: 23.03, Lots: 100, Current Position: 3000
# 2020-08-20: BUY CREATE, Code: 002466.SZ, Price: 24.60, Lots: 900, Current Position: 0
# 2020-08-20: Sell CREATE(Close), Code: 002594.SZ, Price: 78.55, Current Position: 400
# 2020-08-20: BUY CREATE, Code: 002600.SZ, Price: 11.32, Lots: 300, Current Position: 2400
# 2020-08-20: BUY CREATE, Code: 002773.SZ, Price: 43.51, Lots: 100, Current Position: 600
# 2020-08-20: BUY CREATE, Code: 002841.SZ, Price: 96.29, Lots: 300, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 002916.SZ, Price: 142.84, Lots: 100, Current Position: 200
# 2020-08-20: BUY CREATE, Code: 002945.SZ, Price: 15.66, Lots: 2100, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 300003.SZ, Price: 37.80, Lots: 100, Current Position: 900
# 2020-08-20: Sell CREATE(Close), Code: 300015.SZ, Price: 44.17, Current Position: 900
# 2020-08-20: BUY CREATE, Code: 300142.SZ, Price: 64.70, Lots: 100, Current Position: 100
# 2020-08-20: BUY CREATE, Code: 300408.SZ, Price: 26.92, Lots: 1400, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 300413.SZ, Price: 59.58, Lots: 100, Current Position: 400
# 2020-08-20: SELL CREATE, Code: 300628.SZ, Price: 57.71, Lots: 100, Current Position: 600
# 2020-08-20: BUY CREATE, Code: 600000.SH, Price: 10.47, Lots: 7300, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 600018.SH, Price: 4.47, Lots: 13100, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 600100.SH, Price: 7.82, Lots: 7100, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 600104.SH, Price: 18.16, Lots: 4100, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 600271.SH, Price: 17.50, Lots: 2800, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 600352.SH, Price: 14.66, Lots: 2200, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 600438.SH, Price: 22.14, Lots: 100, Current Position: 900
# 2020-08-20: BUY CREATE, Code: 600498.SH, Price: 27.37, Lots: 2500, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 600516.SH, Price: 6.91, Lots: 6300, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 600535.SH, Price: 17.40, Lots: 2200, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 600547.SH, Price: 29.07, Lots: 500, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 600566.SH, Price: 24.34, Lots: 100, Current Position: 2000
# 2020-08-20: BUY CREATE, Code: 600816.SH, Price: 1.89, Lots: 500, Current Position: 31000
# 2020-08-20: BUY CREATE, Code: 600918.SH, Price: 16.25, Lots: 1700, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 600998.SH, Price: 17.75, Lots: 100, Current Position: 2000
# 2020-08-20: BUY CREATE, Code: 601018.SH, Price: 3.91, Lots: 16500, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 601108.SH, Price: 15.07, Lots: 1500, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 601212.SH, Price: 3.12, Lots: 1400, Current Position: 6800
# 2020-08-20: Sell CREATE(Close), Code: 601298.SH, Price: 6.28, Current Position: 7800
# 2020-08-20: BUY CREATE, Code: 601328.SH, Price: 4.77, Lots: 2100, Current Position: 28400
# 2020-08-20: BUY CREATE, Code: 601555.SH, Price: 10.36, Lots: 400, Current Position: 2600
# 2020-08-20: BUY CREATE, Code: 601607.SH, Price: 21.81, Lots: 1000, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 601766.SH, Price: 5.87, Lots: 10300, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 601788.SH, Price: 21.85, Lots: 1000, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 601808.SH, Price: 13.38, Lots: 3900, Current Position: 0
# 2020-08-20: SELL CREATE, Code: 601988.SH, Price: 3.33, Lots: 800, Current Position: 39500
# 2020-08-20: BUY CREATE, Code: 603087.SH, Price: 159.67, Lots: 100, Current Position: 0
# 2020-08-20: SELL CREATE, Code: 603160.SH, Price: 190.10, Lots: 100, Current Position: 200
# 2020-08-20: BUY CREATE, Code: 603899.SH, Price: 64.15, Lots: 600, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 688008.SH, Price: 85.11, Lots: 300, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 688009.SH, Price: 6.17, Lots: 11100, Current Position: 0
# 2020-08-21: BUY EXECUTED, Price:18.74, Lot:1100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:69.04, Lot:600, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:15.48, Lot:2600, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:101.30, Lot:400, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:2.21, Lot:21400, Cash:552979.
# 2020-08-21: SELL EXECUTED, Price:54.13, Lot:100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:10.24, Lot:200, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:22.75, Lot:200, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:22.81, Lot:1500, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:32.32, Lot:100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:42.75, Lot:500, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:11.43, Lot:400, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:9.34, Lot:4100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:127.52, Lot:300, Cash:552979.
# 2020-08-21: SELL EXECUTED, Price:6.71, Lot:400, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:37.81, Lot:1000, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:23.03, Lot:100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:24.60, Lot:900, Cash:552979.
# 2020-08-21: SELL EXECUTED, Price:78.55, Lot:400, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:11.32, Lot:300, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:43.51, Lot:100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:96.29, Lot:300, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:142.84, Lot:100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:15.66, Lot:2100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:37.80, Lot:100, Cash:552979.
# 2020-08-21: SELL EXECUTED, Price:44.17, Lot:900, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:64.70, Lot:100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:26.92, Lot:1400, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:59.58, Lot:100, Cash:552979.
# 2020-08-21: SELL EXECUTED, Price:57.71, Lot:100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:10.47, Lot:7300, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:4.47, Lot:13100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:7.82, Lot:7100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:18.16, Lot:4100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:17.50, Lot:2800, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:14.66, Lot:2200, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:22.14, Lot:100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:27.37, Lot:2500, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:6.91, Lot:6300, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:17.40, Lot:2200, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:29.07, Lot:500, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:24.34, Lot:100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:1.89, Lot:500, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:16.25, Lot:1700, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:17.75, Lot:100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:3.91, Lot:16500, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:15.07, Lot:1500, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:3.12, Lot:1400, Cash:552979.
# 2020-08-21: SELL EXECUTED, Price:6.28, Lot:7800, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:4.77, Lot:2100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:10.36, Lot:400, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:21.81, Lot:1000, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:5.87, Lot:10300, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:21.85, Lot:1000, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:13.38, Lot:3900, Cash:552979.
# 2020-08-21: SELL EXECUTED, Price:3.33, Lot:800, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:159.67, Lot:100, Cash:552979.
# 2020-08-21: SELL EXECUTED, Price:190.10, Lot:100, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:64.15, Lot:600, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:85.11, Lot:300, Cash:552979.
# 2020-08-21: BUY EXECUTED, Price:6.17, Lot:11100, Cash:552979.
# 2020-08-21: OPERATION PROFIT, GROSS -440.00, NET -440.00
# 2020-08-21: OPERATION PROFIT, GROSS -207.00, NET -207.00
# 2020-08-21: OPERATION PROFIT, GROSS 72.00, NET 72.00
# 2020-08-21: BUY CREATE, Code: 000066.SZ, Price: 18.48, Lots: 100, Current Position: 1100
# 2020-08-21: BUY CREATE, Code: 000333.SZ, Price: 69.38, Lots: 100, Current Position: 600
# 2020-08-21: Sell CREATE(Close), Code: 000338.SZ, Price: 15.39, Current Position: 2600
# 2020-08-21: BUY CREATE, Code: 000629.SZ, Price: 2.21, Lots: 500, Current Position: 21400
# 2020-08-21: Sell CREATE(Close), Code: 000963.SZ, Price: 26.89, Current Position: 1200
# 2020-08-21: BUY CREATE, Code: 002007.SZ, Price: 55.53, Lots: 100, Current Position: 200
# 2020-08-21: Sell CREATE(Close), Code: 002008.SZ, Price: 37.41, Current Position: 800
# 2020-08-21: Sell CREATE(Close), Code: 002024.SZ, Price: 10.25, Current Position: 3500
# 2020-08-21: BUY CREATE, Code: 002049.SZ, Price: 128.42, Lots: 100, Current Position: 0
# 2020-08-21: SELL CREATE, Code: 002120.SZ, Price: 22.52, Lots: 100, Current Position: 2300
# 2020-08-21: BUY CREATE, Code: 002202.SZ, Price: 11.33, Lots: 300, Current Position: 3000
# 2020-08-21: BUY CREATE, Code: 002252.SZ, Price: 9.37, Lots: 200, Current Position: 4100
# 2020-08-21: SELL CREATE, Code: 002463.SZ, Price: 21.93, Lots: 500, Current Position: 3100
# 2020-08-21: BUY CREATE, Code: 002594.SZ, Price: 79.58, Lots: 400, Current Position: 0
# 2020-08-21: Sell CREATE(Close), Code: 002714.SZ, Price: 89.74, Current Position: 400
# 2020-08-21: SELL CREATE, Code: 002916.SZ, Price: 139.50, Lots: 100, Current Position: 300
# 2020-08-21: BUY CREATE, Code: 300628.SZ, Price: 56.83, Lots: 100, Current Position: 500
# 2020-08-21: BUY CREATE, Code: 600089.SH, Price: 8.40, Lots: 3600, Current Position: 0
# 2020-08-21: BUY CREATE, Code: 600100.SH, Price: 7.89, Lots: 300, Current Position: 7100
# 2020-08-21: BUY CREATE, Code: 600111.SH, Price: 12.93, Lots: 2000, Current Position: 0
# 2020-08-21: SELL CREATE, Code: 600183.SH, Price: 24.94, Lots: 200, Current Position: 1700
# 2020-08-21: BUY CREATE, Code: 600297.SH, Price: 3.87, Lots: 600, Current Position: 6200
# 2020-08-21: BUY CREATE, Code: 600299.SH, Price: 15.16, Lots: 1900, Current Position: 0
# 2020-08-21: Sell CREATE(Close), Code: 600332.SH, Price: 34.35, Current Position: 1200
# 2020-08-21: BUY CREATE, Code: 600352.SH, Price: 14.83, Lots: 300, Current Position: 2200
# 2020-08-21: Sell CREATE(Close), Code: 600516.SH, Price: 6.94, Current Position: 6300
# 2020-08-21: BUY CREATE, Code: 600733.SH, Price: 6.81, Lots: 3800, Current Position: 0
# 2020-08-21: BUY CREATE, Code: 600745.SH, Price: 135.54, Lots: 200, Current Position: 0
# 2020-08-21: BUY CREATE, Code: 600816.SH, Price: 1.88, Lots: 500, Current Position: 31500
# 2020-08-21: Sell CREATE(Close), Code: 600845.SH, Price: 66.41, Current Position: 400
# 2020-08-21: BUY CREATE, Code: 600998.SH, Price: 17.90, Lots: 400, Current Position: 2100
# 2020-08-21: BUY CREATE, Code: 601018.SH, Price: 3.92, Lots: 500, Current Position: 16500
# 2020-08-21: BUY CREATE, Code: 601100.SH, Price: 60.10, Lots: 500, Current Position: 0
# 2020-08-21: BUY CREATE, Code: 601212.SH, Price: 3.10, Lots: 100, Current Position: 8200
# 2020-08-21: BUY CREATE, Code: 601231.SH, Price: 23.51, Lots: 100, Current Position: 900
# 2020-08-21: BUY CREATE, Code: 601238.SH, Price: 10.36, Lots: 4000, Current Position: 0
# 2020-08-21: BUY CREATE, Code: 601328.SH, Price: 4.77, Lots: 500, Current Position: 30500
# 2020-08-21: BUY CREATE, Code: 601607.SH, Price: 21.71, Lots: 100, Current Position: 1000
# 2020-08-21: BUY CREATE, Code: 601633.SH, Price: 13.82, Lots: 1700, Current Position: 0
# 2020-08-21: Sell CREATE(Close), Code: 601766.SH, Price: 5.89, Current Position: 10300
# 2020-08-21: Sell CREATE(Close), Code: 601788.SH, Price: 22.08, Current Position: 1000
# 2020-08-21: BUY CREATE, Code: 601933.SH, Price: 8.91, Lots: 600, Current Position: 6900
# 2020-08-21: BUY CREATE, Code: 601988.SH, Price: 3.33, Lots: 800, Current Position: 38700
# 2020-08-21: Sell CREATE(Close), Code: 603087.SH, Price: 154.46, Current Position: 100
# 2020-08-21: BUY CREATE, Code: 603160.SH, Price: 188.63, Lots: 100, Current Position: 100
# 2020-08-21: BUY CREATE, Code: 688012.SH, Price: 197.68, Lots: 100, Current Position: 0
# 2020-08-24: BUY EXECUTED, Price:18.48, Lot:100, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:69.38, Lot:100, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:15.39, Lot:2600, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:2.21, Lot:500, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:26.89, Lot:1200, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:55.53, Lot:100, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:37.41, Lot:800, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:10.25, Lot:3500, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:128.42, Lot:100, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:22.52, Lot:100, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:11.33, Lot:300, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:9.37, Lot:200, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:21.93, Lot:500, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:79.58, Lot:400, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:89.74, Lot:400, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:139.50, Lot:100, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:56.83, Lot:100, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:8.40, Lot:3600, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:7.89, Lot:300, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:12.93, Lot:2000, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:24.94, Lot:200, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:3.87, Lot:600, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:15.16, Lot:1900, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:34.35, Lot:1200, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:14.83, Lot:300, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:6.94, Lot:6300, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:6.81, Lot:3800, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:135.54, Lot:200, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:1.88, Lot:500, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:66.41, Lot:400, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:17.90, Lot:400, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:3.92, Lot:500, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:60.10, Lot:500, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:3.10, Lot:100, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:23.51, Lot:100, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:10.36, Lot:4000, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:4.77, Lot:500, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:21.71, Lot:100, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:13.82, Lot:1700, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:5.89, Lot:10300, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:22.08, Lot:1000, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:8.91, Lot:600, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:3.33, Lot:800, Cash:591810.
# 2020-08-24: SELL EXECUTED, Price:154.46, Lot:100, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:188.63, Lot:100, Cash:591810.
# 2020-08-24: BUY EXECUTED, Price:197.68, Lot:100, Cash:591810.
# 2020-08-24: OPERATION PROFIT, GROSS -234.00, NET -234.00
# 2020-08-24: OPERATION PROFIT, GROSS 720.00, NET 720.00
# 2020-08-24: OPERATION PROFIT, GROSS -440.00, NET -440.00
# 2020-08-24: OPERATION PROFIT, GROSS 35.00, NET 35.00
# 2020-08-24: OPERATION PROFIT, GROSS 56.00, NET 56.00
# 2020-08-24: OPERATION PROFIT, GROSS 42.00, NET 42.00
# 2020-08-24: OPERATION PROFIT, GROSS 189.00, NET 189.00
# 2020-08-24: OPERATION PROFIT, GROSS -177.00, NET -177.00
# 2020-08-24: OPERATION PROFIT, GROSS 206.00, NET 206.00
# 2020-08-24: OPERATION PROFIT, GROSS 230.00, NET 230.00
# 2020-08-24: OPERATION PROFIT, GROSS -521.00, NET -521.00
# 2020-08-24: BUY CREATE, Code: 000002.SZ, Price: 27.13, Lots: 1900, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 000066.SZ, Price: 18.42, Lots: 100, Current Position: 1200
# 2020-08-24: BUY CREATE, Code: 000415.SZ, Price: 2.93, Lots: 20700, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 000629.SZ, Price: 2.22, Lots: 1200, Current Position: 21900
# 2020-08-24: BUY CREATE, Code: 000977.SZ, Price: 35.78, Lots: 100, Current Position: 1000
# 2020-08-24: BUY CREATE, Code: 002024.SZ, Price: 10.17, Lots: 4500, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 002153.SZ, Price: 32.23, Lots: 100, Current Position: 1100
# 2020-08-24: BUY CREATE, Code: 002202.SZ, Price: 11.42, Lots: 300, Current Position: 3300
# 2020-08-24: BUY CREATE, Code: 002371.SZ, Price: 194.70, Lots: 100, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 002411.SZ, Price: 6.76, Lots: 100, Current Position: 5500
# 2020-08-24: SELL CREATE, Code: 002463.SZ, Price: 21.53, Lots: 200, Current Position: 2600
# 2020-08-24: BUY CREATE, Code: 003816.SZ, Price: 3.03, Lots: 29200, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 600000.SH, Price: 10.46, Lots: 500, Current Position: 7300
# 2020-08-24: BUY CREATE, Code: 600016.SH, Price: 5.58, Lots: 20700, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 600089.SH, Price: 8.41, Lots: 100, Current Position: 3600
# 2020-08-24: BUY CREATE, Code: 600196.SH, Price: 54.31, Lots: 100, Current Position: 200
# 2020-08-24: BUY CREATE, Code: 600297.SH, Price: 3.86, Lots: 1000, Current Position: 6800
# 2020-08-24: BUY CREATE, Code: 600332.SH, Price: 34.34, Lots: 1300, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 600566.SH, Price: 24.18, Lots: 100, Current Position: 2100
# 2020-08-24: BUY CREATE, Code: 600584.SH, Price: 42.39, Lots: 500, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 600733.SH, Price: 6.70, Lots: 300, Current Position: 3800
# 2020-08-24: BUY CREATE, Code: 600816.SH, Price: 1.86, Lots: 500, Current Position: 32000
# 2020-08-24: Sell CREATE(Close), Code: 601018.SH, Price: 3.92, Current Position: 17000
# 2020-08-24: BUY CREATE, Code: 601166.SH, Price: 15.85, Lots: 5000, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 601186.SH, Price: 8.92, Lots: 7400, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 601212.SH, Price: 3.12, Lots: 100, Current Position: 8300
# 2020-08-24: BUY CREATE, Code: 601288.SH, Price: 3.23, Lots: 50400, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 601328.SH, Price: 4.76, Lots: 3100, Current Position: 31000
# 2020-08-24: BUY CREATE, Code: 601607.SH, Price: 21.74, Lots: 100, Current Position: 1100
# 2020-08-24: BUY CREATE, Code: 601633.SH, Price: 13.86, Lots: 100, Current Position: 1700
# 2020-08-24: BUY CREATE, Code: 601766.SH, Price: 5.88, Lots: 11200, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 601788.SH, Price: 21.82, Lots: 1100, Current Position: 0
# 2020-08-24: Sell CREATE(Close), Code: 601878.SH, Price: 14.98, Current Position: 1700
# 2020-08-24: BUY CREATE, Code: 601933.SH, Price: 8.91, Lots: 600, Current Position: 7500
# 2020-08-24: BUY CREATE, Code: 601988.SH, Price: 3.32, Lots: 3400, Current Position: 39500
# 2020-08-24: BUY CREATE, Code: 603087.SH, Price: 143.60, Lots: 100, Current Position: 0
# 2020-08-25: Order Canceled/Margin/Rejected
# 2020-08-25: Order Canceled/Margin/Rejected
# 2020-08-25: Order Canceled/Margin/Rejected
# 2020-08-25: Order Canceled/Margin/Rejected
# 2020-08-25: Order Canceled/Margin/Rejected
# 2020-08-25: Order Canceled/Margin/Rejected
# 2020-08-25: Order Canceled/Margin/Rejected
# 2020-08-25: Order Canceled/Margin/Rejected
# 2020-08-25: Order Canceled/Margin/Rejected
# 2020-08-25: Order Canceled/Margin/Rejected
# 2020-08-25: BUY EXECUTED, Price:27.13, Lot:1900, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:18.42, Lot:100, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:2.93, Lot:20700, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:2.22, Lot:1200, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:35.78, Lot:100, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:10.17, Lot:4500, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:32.23, Lot:100, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:11.42, Lot:300, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:194.70, Lot:100, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:6.76, Lot:100, Cash:33805.
# 2020-08-25: SELL EXECUTED, Price:21.53, Lot:200, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:3.03, Lot:29200, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:10.46, Lot:500, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:5.58, Lot:20700, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:8.41, Lot:100, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:54.31, Lot:100, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:3.86, Lot:1000, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:34.34, Lot:1300, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:24.18, Lot:100, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:42.39, Lot:500, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:6.70, Lot:300, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:1.86, Lot:500, Cash:33805.
# 2020-08-25: SELL EXECUTED, Price:3.92, Lot:17000, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:15.85, Lot:5000, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:8.92, Lot:7400, Cash:33805.
# 2020-08-25: BUY EXECUTED, Price:3.12, Lot:100, Cash:33805.
# 2020-08-25: OPERATION PROFIT, GROSS 165.00, NET 165.00
# 2020-08-25: BUY CREATE, Code: 000415.SZ, Price: 2.93, Lots: 300, Current Position: 20700
# 2020-08-25: BUY CREATE, Code: 000629.SZ, Price: 2.19, Lots: 900, Current Position: 23100
# 2020-08-25: BUY CREATE, Code: 000630.SZ, Price: 2.26, Lots: 18000, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 000651.SZ, Price: 54.29, Lots: 100, Current Position: 1500
# 2020-08-25: BUY CREATE, Code: 000708.SZ, Price: 18.36, Lots: 300, Current Position: 2100
# 2020-08-25: Sell CREATE(Close), Code: 000938.SZ, Price: 31.28, Current Position: 900
# 2020-08-25: BUY CREATE, Code: 001979.SZ, Price: 16.91, Lots: 4100, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 002024.SZ, Price: 10.05, Lots: 200, Current Position: 4500
# 2020-08-25: SELL CREATE, Code: 002120.SZ, Price: 21.70, Lots: 100, Current Position: 2200
# 2020-08-25: BUY CREATE, Code: 002411.SZ, Price: 6.67, Lots: 200, Current Position: 5600
# 2020-08-25: BUY CREATE, Code: 002460.SZ, Price: 52.55, Lots: 100, Current Position: 500
# 2020-08-25: Sell CREATE(Close), Code: 002945.SZ, Price: 15.63, Current Position: 2100
# 2020-08-25: BUY CREATE, Code: 002958.SZ, Price: 5.51, Lots: 7400, Current Position: 0
# 2020-08-25: Sell CREATE(Close), Code: 300122.SZ, Price: 135.52, Current Position: 100
# 2020-08-25: Sell CREATE(Close), Code: 300142.SZ, Price: 62.90, Current Position: 200
# 2020-08-25: BUY CREATE, Code: 300676.SZ, Price: 143.96, Lots: 100, Current Position: 100
# 2020-08-25: BUY CREATE, Code: 600000.SH, Price: 10.45, Lots: 400, Current Position: 7800
# 2020-08-25: BUY CREATE, Code: 600010.SH, Price: 1.16, Lots: 56000, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 600016.SH, Price: 5.56, Lots: 700, Current Position: 20700
# 2020-08-25: BUY CREATE, Code: 600068.SH, Price: 6.48, Lots: 8000, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 600085.SH, Price: 29.43, Lots: 1000, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 600089.SH, Price: 8.14, Lots: 100, Current Position: 3700
# 2020-08-25: BUY CREATE, Code: 600100.SH, Price: 7.91, Lots: 300, Current Position: 7400
# 2020-08-25: BUY CREATE, Code: 600111.SH, Price: 12.65, Lots: 100, Current Position: 2000
# 2020-08-25: BUY CREATE, Code: 600150.SH, Price: 21.09, Lots: 1100, Current Position: 0
# 2020-08-25: Sell CREATE(Close), Code: 600161.SH, Price: 43.50, Current Position: 400
# 2020-08-25: BUY CREATE, Code: 600297.SH, Price: 3.78, Lots: 600, Current Position: 7800
# 2020-08-25: BUY CREATE, Code: 600299.SH, Price: 15.03, Lots: 200, Current Position: 1900
# 2020-08-25: BUY CREATE, Code: 600332.SH, Price: 34.23, Lots: 100, Current Position: 1300
# 2020-08-25: Sell CREATE(Close), Code: 600362.SH, Price: 15.13, Current Position: 2000
# 2020-08-25: BUY CREATE, Code: 600372.SH, Price: 18.24, Lots: 900, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 600482.SH, Price: 19.81, Lots: 1200, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 600498.SH, Price: 26.79, Lots: 100, Current Position: 2500
# 2020-08-25: BUY CREATE, Code: 600516.SH, Price: 6.87, Lots: 7400, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 600566.SH, Price: 24.12, Lots: 100, Current Position: 2200
# 2020-08-25: BUY CREATE, Code: 600705.SH, Price: 5.14, Lots: 5600, Current Position: 0
# 2020-08-25: Sell CREATE(Close), Code: 600733.SH, Price: 6.73, Current Position: 4100
# 2020-08-25: BUY CREATE, Code: 600893.SH, Price: 43.82, Lots: 300, Current Position: 0
# 2020-08-25: Sell CREATE(Close), Code: 600918.SH, Price: 16.35, Current Position: 1700
# 2020-08-25: BUY CREATE, Code: 600968.SH, Price: 2.53, Lots: 26100, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601018.SH, Price: 3.88, Lots: 18300, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601077.SH, Price: 5.27, Lots: 13900, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601108.SH, Price: 14.70, Lots: 400, Current Position: 1500
# 2020-08-25: BUY CREATE, Code: 601186.SH, Price: 8.88, Lots: 300, Current Position: 7400
# 2020-08-25: Sell CREATE(Close), Code: 601212.SH, Price: 3.06, Current Position: 8400
# 2020-08-25: BUY CREATE, Code: 601229.SH, Price: 8.36, Lots: 9900, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601236.SH, Price: 21.39, Lots: 1600, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601238.SH, Price: 10.30, Lots: 100, Current Position: 4000
# 2020-08-25: BUY CREATE, Code: 601288.SH, Price: 3.23, Lots: 54500, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601319.SH, Price: 7.27, Lots: 6100, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601328.SH, Price: 4.77, Lots: 5000, Current Position: 31000
# 2020-08-25: BUY CREATE, Code: 601600.SH, Price: 3.22, Lots: 3600, Current Position: 12100
# 2020-08-25: BUY CREATE, Code: 601607.SH, Price: 21.21, Lots: 200, Current Position: 1100
# 2020-08-25: BUY CREATE, Code: 601633.SH, Price: 13.76, Lots: 100, Current Position: 1700
# 2020-08-25: BUY CREATE, Code: 601698.SH, Price: 22.80, Lots: 1000, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601727.SH, Price: 5.62, Lots: 6100, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601766.SH, Price: 5.85, Lots: 11500, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601788.SH, Price: 21.53, Lots: 1100, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601816.SH, Price: 6.22, Lots: 16200, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601933.SH, Price: 8.84, Lots: 1000, Current Position: 7500
# 2020-08-25: BUY CREATE, Code: 601988.SH, Price: 3.32, Lots: 5300, Current Position: 39500
# 2020-08-25: BUY CREATE, Code: 601989.SH, Price: 4.88, Lots: 7000, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 601990.SH, Price: 15.48, Lots: 2900, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 603087.SH, Price: 144.40, Lots: 100, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 603260.SH, Price: 29.24, Lots: 100, Current Position: 1100
# 2020-08-25: BUY CREATE, Code: 603799.SH, Price: 41.16, Lots: 100, Current Position: 600
# 2020-08-25: BUY CREATE, Code: 603993.SH, Price: 4.28, Lots: 1900, Current Position: 6700
# 2020-08-25: BUY CREATE, Code: 688008.SH, Price: 84.00, Lots: 100, Current Position: 300
# 2020-08-26: Order Canceled/Margin/Rejected
# 2020-08-26: Order Canceled/Margin/Rejected
# 2020-08-26: Order Canceled/Margin/Rejected
# 2020-08-26: Order Canceled/Margin/Rejected
# 2020-08-26: Order Canceled/Margin/Rejected
# 2020-08-26: Order Canceled/Margin/Rejected
# 2020-08-26: Order Canceled/Margin/Rejected
# 2020-08-26: Order Canceled/Margin/Rejected
# 2020-08-26: Order Canceled/Margin/Rejected
# 2020-08-26: Order Canceled/Margin/Rejected
# 2020-08-26: Order Canceled/Margin/Rejected
# 2020-08-26: Order Canceled/Margin/Rejected
# ...
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: Order Canceled/Margin/Rejected
# 2020-12-30: BUY EXECUTED, Price:5.30, Lot:7600, Cash:515.
# 2020-12-30: BUY CREATE, Code: 000625.SZ, Price: 21.53, Lots: 900, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 000671.SZ, Price: 6.41, Lots: 10200, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 000898.SZ, Price: 3.06, Lots: 14500, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 000963.SZ, Price: 26.21, Lots: 1300, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 002007.SZ, Price: 41.23, Lots: 300, Current Position: 500
# 2020-12-30: BUY CREATE, Code: 002010.SZ, Price: 4.64, Lots: 12100, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 002044.SZ, Price: 10.72, Lots: 3300, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 002081.SZ, Price: 9.37, Lots: 4700, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 002120.SZ, Price: 15.43, Lots: 900, Current Position: 2200
# 2020-12-30: BUY CREATE, Code: 002146.SZ, Price: 6.48, Lots: 12400, Current Position: 0
# 2020-12-30: SELL CREATE, Code: 002153.SZ, Price: 30.65, Lots: 100, Current Position: 1200
# 2020-12-30: BUY CREATE, Code: 002252.SZ, Price: 7.24, Lots: 1600, Current Position: 4300
# 2020-12-30: BUY CREATE, Code: 002411.SZ, Price: 5.17, Lots: 2000, Current Position: 5600
# 2020-12-30: BUY CREATE, Code: 002422.SZ, Price: 19.10, Lots: 2900, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 002456.SZ, Price: 12.83, Lots: 3000, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 002468.SZ, Price: 10.00, Lots: 4200, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 002508.SZ, Price: 39.45, Lots: 900, Current Position: 0
# 2020-12-30: SELL CREATE, Code: 002600.SZ, Price: 12.00, Lots: 700, Current Position: 2700
# 2020-12-30: BUY CREATE, Code: 002607.SZ, Price: 34.00, Lots: 700, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 002958.SZ, Price: 5.00, Lots: 5300, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 300024.SZ, Price: 12.06, Lots: 1500, Current Position: 2600
# 2020-12-30: BUY CREATE, Code: 300033.SZ, Price: 118.74, Lots: 300, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 300498.SZ, Price: 18.12, Lots: 3100, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 300676.SZ, Price: 126.71, Lots: 200, Current Position: 100
# 2020-12-30: BUY CREATE, Code: 600000.SH, Price: 9.50, Lots: 2400, Current Position: 7800
# 2020-12-30: BUY CREATE, Code: 600029.SH, Price: 5.76, Lots: 9200, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600050.SH, Price: 4.45, Lots: 21900, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600085.SH, Price: 23.47, Lots: 2800, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600150.SH, Price: 17.39, Lots: 3400, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600153.SH, Price: 8.21, Lots: 6500, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600170.SH, Price: 3.00, Lots: 43800, Current Position: 0
# 2020-12-30: Sell CREATE(Close), Code: 600196.SH, Price: 51.79, Current Position: 300
# 2020-12-30: BUY CREATE, Code: 600233.SH, Price: 11.39, Lots: 3800, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600297.SH, Price: 2.84, Lots: 3400, Current Position: 7800
# 2020-12-30: BUY CREATE, Code: 600299.SH, Price: 11.34, Lots: 2300, Current Position: 1900
# 2020-12-30: BUY CREATE, Code: 600332.SH, Price: 28.97, Lots: 1700, Current Position: 1300
# 2020-12-30: BUY CREATE, Code: 600352.SH, Price: 13.51, Lots: 2500, Current Position: 2500
# 2020-12-30: BUY CREATE, Code: 600383.SH, Price: 13.27, Lots: 4200, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600398.SH, Price: 6.04, Lots: 9200, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600566.SH, Price: 20.10, Lots: 1200, Current Position: 2200
# 2020-12-30: BUY CREATE, Code: 600606.SH, Price: 5.76, Lots: 9200, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600655.SH, Price: 8.08, Lots: 6500, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600663.SH, Price: 10.71, Lots: 8000, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600900.SH, Price: 19.03, Lots: 3800, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600919.SH, Price: 5.40, Lots: 10300, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600968.SH, Price: 2.38, Lots: 30500, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600977.SH, Price: 11.89, Lots: 5100, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601006.SH, Price: 6.41, Lots: 16400, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601111.SH, Price: 7.15, Lots: 7000, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601155.SH, Price: 33.80, Lots: 1800, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601186.SH, Price: 7.83, Lots: 7000, Current Position: 7400
# 2020-12-30: BUY CREATE, Code: 601211.SH, Price: 17.14, Lots: 4200, Current Position: 0
# 2020-12-30: SELL CREATE, Code: 601225.SH, Price: 9.32, Lots: 3800, Current Position: 7600
# 2020-12-30: BUY CREATE, Code: 601288.SH, Price: 3.13, Lots: 54500, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601360.SH, Price: 15.57, Lots: 2500, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601390.SH, Price: 5.22, Lots: 18000, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601668.SH, Price: 4.94, Lots: 21400, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601669.SH, Price: 3.82, Lots: 17800, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601688.SH, Price: 17.51, Lots: 4000, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601766.SH, Price: 5.27, Lots: 19500, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601800.SH, Price: 7.21, Lots: 11500, Current Position: 0
# 2020-12-30: SELL CREATE, Code: 601808.SH, Price: 12.74, Lots: 1000, Current Position: 3900
# 2020-12-30: BUY CREATE, Code: 601816.SH, Price: 5.57, Lots: 19700, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601857.SH, Price: 4.13, Lots: 25500, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601933.SH, Price: 7.03, Lots: 1300, Current Position: 7500
# 2020-12-30: BUY CREATE, Code: 601939.SH, Price: 6.22, Lots: 14200, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601988.SH, Price: 3.17, Lots: 25500, Current Position: 39500
# 2020-12-30: BUY CREATE, Code: 601990.SH, Price: 11.73, Lots: 3500, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 601992.SH, Price: 2.97, Lots: 31500, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 603156.SH, Price: 25.86, Lots: 1200, Current Position: 0
# 2020-12-30: Sell CREATE(Close), Code: 603260.SH, Price: 33.58, Current Position: 1100
# 2020-12-30: BUY CREATE, Code: 688009.SH, Price: 5.84, Lots: 7200, Current Position: 11100
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: Order Canceled/Margin/Rejected
# 2020-12-31: BUY CREATE, Code: 000625.SZ, Price: 21.88, Lots: 900, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 000629.SZ, Price: 2.17, Lots: 9100, Current Position: 9000
# 2020-12-31: BUY CREATE, Code: 000898.SZ, Price: 3.04, Lots: 15300, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 000963.SZ, Price: 26.56, Lots: 1400, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 002081.SZ, Price: 9.39, Lots: 5600, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 002146.SZ, Price: 6.53, Lots: 12600, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 002411.SZ, Price: 5.20, Lots: 3700, Current Position: 5600
# 2020-12-31: BUY CREATE, Code: 002468.SZ, Price: 10.08, Lots: 4500, Current Position: 0
# 2020-12-31: SELL CREATE, Code: 002600.SZ, Price: 11.99, Lots: 600, Current Position: 2700
# 2020-12-31: BUY CREATE, Code: 300136.SZ, Price: 35.88, Lots: 800, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 300498.SZ, Price: 18.23, Lots: 3200, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 300676.SZ, Price: 128.56, Lots: 200, Current Position: 100
# 2020-12-31: BUY CREATE, Code: 600011.SH, Price: 4.48, Lots: 9600, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 600023.SH, Price: 3.63, Lots: 16800, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 600050.SH, Price: 4.46, Lots: 22400, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 600153.SH, Price: 8.21, Lots: 7200, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 600170.SH, Price: 3.01, Lots: 50400, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 600297.SH, Price: 2.86, Lots: 3900, Current Position: 7800
# 2020-12-31: BUY CREATE, Code: 600566.SH, Price: 20.23, Lots: 1200, Current Position: 2200
# 2020-12-31: BUY CREATE, Code: 600663.SH, Price: 10.70, Lots: 8200, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 600919.SH, Price: 5.46, Lots: 10600, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 600968.SH, Price: 2.39, Lots: 31500, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 601186.SH, Price: 7.90, Lots: 7300, Current Position: 7400
# 2020-12-31: BUY CREATE, Code: 601288.SH, Price: 3.14, Lots: 53000, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 601727.SH, Price: 5.40, Lots: 8500, Current Position: 0
# 2020-12-31: SELL CREATE, Code: 601808.SH, Price: 12.77, Lots: 900, Current Position: 3900
# 2020-12-31: BUY CREATE, Code: 601992.SH, Price: 2.97, Lots: 33600, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 603156.SH, Price: 25.84, Lots: 1200, Current Position: 0
# 2020-12-31: SELL CREATE, Code: 603260.SH, Price: 33.44, Lots: 500, Current Position: 1100
# 2020-12-31: BUY CREATE, Code: 688008.SH, Price: 82.88, Lots: 100, Current Position: 300
# 2020-12-31: BUY CREATE, Code: 688009.SH, Price: 5.86, Lots: 8800, Current Position: 11100
# 2020-12-31: Ending Position:1. Ending Value:5378205.00.
# Net Profit: 7.56%
