# %%
# 数据接口 
import akshare as ak
import baostock as bs
import tushare as ts

# 基础模块
import datetime
from itertools import product
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import random
import time

# 回测框架
import backtrader as bt

# 基础函数
import utilsJ

# %% [markdown]
# # 策略

# %%
class Strategy_comp_mul(bt.Strategy):
    
    params = (
        # General params
        ('printlog', False),
        ('p_stake', 100),
        ('buy_signal', 'b'),
        ('sell_signal', 'b'),

        # Indicator params
        ('bollinger_per', 20),
        ('bollinger_dev', 2),
        ('rsi_short', 6),
        ('rsi_long', 12),
        ('wave_period', 7),
        ('wr', 14),
        
        # ATR params
        ('using_atr', False),
        ('atr_period', 14),
        ('atr_percent', 1),
    )
    
    
    def log(self, txt, dt=None, doprint=False):
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s: %s' % (dt.isoformat(), txt))
            #with open('log.txt', 'a') as file:
                #file.write('%s: %s \n' % (dt.isoformat(), txt))
        
    
    def __init__(self):

        # Record ATR Initial
        self.atr_initial = self.broker.get_cash()
        self.inds = dict()
        self.data_tracker = None

        for d in self.datas:

            self.inds[d] = dict()
            
            # Keep references to lines in the data[0] dataseries
            self.inds[d]['dataclose'] = d.close
            self.inds[d]['datahigh'] = d.high
            self.inds[d]['datalow'] = d.low

            # Keep references to executed order & price
            self.inds[d]['buyprice'] = 0
            self.inds[d]['sellprice'] = 0
            self.inds[d]['order'] = None
                
            # Add indicators
            ## Wave indicator
            ### MovingAverageSimple indicator
            self.inds[d]['sma'] = bt.indicators.SimpleMovingAverage(d, period=self.params.wave_period)
            self.inds[d]['wave_buy'] = bt.And(self.inds[d]['sma'](0) > self.inds[d]['sma'](-1), 
                                              self.inds[d]['sma'](-1) < self.inds[d]['sma'](-2), 
                                              self.inds[d]['sma'](-2) < self.inds[d]['sma'](-3))

            self.inds[d]['wave_sell'] = bt.And(self.inds[d]['sma'](0) < self.inds[d]['sma'](-1), 
                                               self.inds[d]['sma'](-1) > self.inds[d]['sma'](-2), 
                                               self.inds[d]['sma'](-2) > self.inds[d]['sma'](-3))

            ## MACD indicator
            self.inds[d]['macdhisto'] = bt.indicators.MACDHisto(d)
            self.inds[d]['macd_buy'] = bt.And(self.inds[d]['macdhisto'](0) > 0, self.inds[d]['macdhisto'](-1) < 0)
            self.inds[d]['macd_sell'] = bt.And(self.inds[d]['macdhisto'](0) < 0, self.inds[d]['macdhisto'](-1) > 0)

            ## Bollinger Bands indicator
            self.inds[d]['bolling'] = bt.indicators.BollingerBands(d, 
                                                        period=self.params.bollinger_per, 
                                                        devfactor=self.params.bollinger_dev)
            self.inds[d]['bolling_buy'] = bt.Or(bt.And(self.inds[d]['dataclose'](0) > self.inds[d]['bolling'].top(0), 
                                                       self.inds[d]['dataclose'](-1) < self.inds[d]['bolling'].top(-1)), 
                                                bt.And(self.inds[d]['dataclose'](0) > self.inds[d]['bolling'].bot(0), 
                                                       self.inds[d]['dataclose'](-1) < self.inds[d]['bolling'].bot(-1)))
            self.inds[d]['bolling_sell'] = bt.Or(bt.And(self.inds[d]['dataclose'](0) < self.inds[d]['bolling'].top(0), 
                                                        self.inds[d]['dataclose'](-1) > self.inds[d]['bolling'].top(-1)), 
                                                 bt.And(self.inds[d]['dataclose'](0) < self.inds[d]['bolling'].bot(0), 
                                                        self.inds[d]['dataclose'](-1) > self.inds[d]['bolling'].bot(-1)))

            ## RSI indicator
            self.inds[d]['rsi_s'] = bt.indicators.RelativeStrengthIndex(d, period=self.params.rsi_short, safediv=True)
            self.inds[d]['rsi_l'] = bt.indicators.RelativeStrengthIndex(d, period=self.params.rsi_long, safediv=True)
            self.inds[d]['rsi_buy'] = bt.And(self.inds[d]['rsi_s'](0) > self.inds[d]['rsi_l'](0), 
                                             self.inds[d]['rsi_s'](-1) < self.inds[d]['rsi_l'](-1))
            self.inds[d]['rsi_sell'] = bt.And(self.inds[d]['rsi_s'](0) < self.inds[d]['rsi_l'](0), 
                                              self.inds[d]['rsi_s'](-1) > self.inds[d]['rsi_l'](-1))

            ## WilliamR indicator
            self.inds[d]['wr'] = bt.indicators.WilliamsR(d, period=self.params.wr)
            self.inds[d]['wr_buy'] = self.inds[d]['wr'] < -80
            self.inds[d]['wr_sell'] = self.inds[d]['wr'] > -20
        
            ## ATR indicator
            self.inds[d]['tr'] = bt.indicators.Max((self.inds[d]['datahigh'](0) - self.inds[d]['datalow'](0)), 
                                                    abs(self.inds[d]['dataclose'](-1) - self.inds[d]['datahigh'](0)),
                                                    abs(self.inds[d]['dataclose'](-1) - self.inds[d]['datalow'](0)))
            self.inds[d]['atr'] = bt.indicators.SimpleMovingAverage(self.inds[d]['tr'], period=self.params.atr_period)





    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                if self.inds[self.data_tracker]['wave_buy']:
                    self.inds[self.data_tracker]['buyprice']
                self.log('BUY EXECUTED, Price:%.2f, Lot:%i, Cash:%i.' %
                         (order.executed.price,
                          order.executed.size,
                          self.broker.get_cash()))

            else:  # Sell
                self.inds[self.data_tracker]['sellprice'] = order.executed.price
                self.log('SELL EXECUTED, Price:%.2f, Lot:%i, Cash:%i.' %
                        (order.executed.price,
                          -order.executed.size,
                          self.broker.get_cash()))

        elif order.status in [order.Canceled]:
            self.log('Order Canceled')

        elif order.status in [order.Margin]:
            self.log('Order Margin')

        elif order.status in [order.Rejected]:
            self.log('Order Rejected')

        # Write down: no pending order
        #self.order = None


    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))
    

    def next(self):

        buy_list = []
        sell_list = []

        for d in self.datas:
        # Check if an order is pending ... if yes, we cannot send a 2nd one
            if self.inds[d]['order']:
                return
            self.data_tracker = d
            buy_indicator = (self.params.buy_signal == 'b' and self.inds[d]['bolling_buy']) or \
                            (self.params.buy_signal == 'm' and self.inds[d]['macd_buy']) or \
                            (self.params.buy_signal == 'w' and self.inds[d]['wave_buy'] and self.inds[d]['dataclose'][0] > self.inds[d]['buyprice']) or \
                            (self.params.buy_signal == 'r' and self.inds[d]['rsi_buy']) or \
                            (self.params.buy_signal == 'wr' and self.inds[d]['wr_buy'])
            
            #buy_indicator = self.inds[d]['bolling_buy'] and \
            #                self.inds[d]['macd_buy'] and \
            #                (self.inds[d]['wave_buy'] and self.inds[d]['dataclose'][0] > self.inds[d]['buyprice']) and \
            #                self.inds[d]['rsi_buy'] and \
            #                self.inds[d]['wr_buy']
                            
            sell_indicator = (self.params.sell_signal == 'b' and self.inds[d]['bolling_sell']) or \
                            (self.params.sell_signal == 'm' and self.inds[d]['macd_sell']) or \
                            (self.params.sell_signal == 'w' and self.inds[d]['wave_sell']) or \
                            (self.params.sell_signal == 'r' and self.inds[d]['rsi_sell']) or \
                            (self.params.sell_signal == 'wr' and self.inds[d]['wr_sell'])
            
            #sell_indicator = self.inds[d]['bolling_sell'] or \
            #                 self.inds[d]['macd_sell'] or \
            #                 self.inds[d]['wave_sell'] or \
            #                 self.inds[d]['rsi_sell'] or \
            #                 self.inds[d]['wr_sell']

            if sell_indicator and self.getposition(d).size > 0:
                sell_list.append((d, -1))
                #self.log('Sell CREATE(Close), Code: %s, Price: %.2f, Current Position: %i' % 
                #         (d._name, 
                #          self.inds[d]['dataclose'][0],
                #          self.getposition(d).size))
                #self.close(data=d, name=d._name)
                
            elif buy_indicator:
                if self.params.using_atr:
                    opt_pos = np.floor(self.atr_initial * self.params.atr_percent / self.params.p_stake / self.inds[d]['atr'][0])
                    if opt_pos*self.params.p_stake > 0 and self.getposition(d).size < opt_pos*self.params.p_stake:
                        buy_list.append((d, 
                                        opt_pos*self.params.p_stake-self.getposition(d).size, 
                                        (opt_pos*self.params.p_stake-self.getposition(d).size)*self.inds[d]['dataclose'][0]))
                        #self.log('BUY CREATE, Code: %s, Price: %.2f, Lots: %i, Current Position: %i' % 
                        #        (d._name, 
                        #         self.inds[d]['dataclose'][0], 
                        #         opt_pos*self.params.p_stake-self.getposition(d).size,
                        #         self.getposition(d).size))
                        #self.buy(data=d, size=opt_pos*self.params.p_stake-self.getposition(d).size, name=d._name)
                    
                    elif opt_pos*self.params.p_stake > 0 and self.getposition(d).size > opt_pos*self.params.p_stake:
                        sell_list.append((d, 
                        self.getposition(d).size-opt_pos*self.params.p_stake))
                        #self.log('SELL CREATE, Code: %s, Price: %.2f, Lots: %i, Current Position: %i' % 
                        #        (d._name, 
                        #         self.inds[d]['dataclose'][0], 
                        #         self.getposition(d).size-opt_pos*self.params.p_stake,
                        #         self.getposition(d).size))
                        #self.sell(data=d, size=self.getposition(d).size-opt_pos*self.params.p_stake, name=d._name)
                else:
                    buy_list.append((d, 
                                     opt_pos*self.params.p_stake, 
                                     opt_pos*self.params.p_stake*self.inds[d]['dataclose'][0]))
                    #self.log('BUY CREATE, Code: %s, Price: %.2f, Lots: %i, Current Position: %i' % 
                    #        (d._name, 
                    #         self.inds[d]['dataclose'][0],
                    #         self.params.p_stake,
                    #         self.getposition(d).size))
                    #self.buy(data=d, size=self.params.p_stake, name=d._name)
            
        for s_order in sell_list:
            self.log('Sell CREATE, Code: %s, Price: %.2f, Lots:%i, Current Position: %i' % 
                        (s_order[0]._name, 
                        self.inds[s_order[0]]['dataclose'][0],
                        s_order[1] if s_order[1] != -1 else self.getposition(s_order[0]).size,
                        self.getposition(s_order[0]).size))
            self.sell(data=s_order[0], 
                        size=s_order[1] if s_order[1] != -1 else self.getposition(s_order[0]).size, 
                        name=s_order[0]._name)
        
        #buy_list = sorted(buy_list, key=lambda x: x[2], reverse=False)
        random.shuffle(buy_list)
        for b_order in buy_list:
            self.log('BUY CREATE, Code: %s, Price: %.2f, Lots: %i, Current Position: %i' % 
                        (b_order[0]._name, 
                        self.inds[b_order[0]]['dataclose'][0], 
                        b_order[1],
                        self.getposition(b_order[0]).size))
            self.buy(data=b_order[0], size=b_order[1], name=b_order[0]._name)


    def stop(self):
        self.log('Ending Position:%i. Ending Value:%.2f.' %
                (1,
                self.cerebro.broker.getvalue()), doprint=False)

# %% [markdown]
# # 全市场选股

# %% [markdown]
# ## 数据下载

# %%
s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 365)
e_date = datetime.date(2020, 12, 31)

#s_date = datetime.datetime.now() - datetime.timedelta(days = 365)
#e_date = datetime.datetime.now()

stock_index = '399300.SZ'

# Download Data
utilsJ.index_to_csv_tushare('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6', 
                            stock_index, 0.2, s_date, e_date, fpath='.\\Data\\2020\\')

# %%
profit_list = []

# 904ff4752522814dca00e032a709fdfc26d8744913500ef204e02157
# 74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6

s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 365)
e_date = datetime.date(2020, 12, 31)

stock_index = '399300.SZ'
pro = ts.pro_api('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6')
index_list = np.unique(pro.index_weight(index_code=stock_index,
                                        start_date=s_date.strftime('%Y%m%d'),
                                        end_date=e_date.strftime('%Y%m%d')).con_code).tolist()

buy_s = ['b','m','w', 'r', 'wr']
sell_s = ['b','m','w', 'r', 'wr']
random.seed(10086)
for s in product(*[buy_s, sell_s]):

    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    strats = cerebro.addstrategy(Strategy_comp_mul, printlog=False, using_atr=True, atr_percent=0.01, buy_signal = s[0], sell_signal = s[1]) 

    for s_code in index_list:
        df = pd.read_csv('.\\Data\\2020\\' + s_code + '.csv')
        df.index=pd.to_datetime(df.trade_date)
        data = bt.feeds.PandasData(dataname=df,fromdate=s_date,todate=e_date)

        # Add the index Data Feed to Cerebo
        cerebro.adddata(data, name = s_code)
    
    # Set cash inside the strategy
    cerebro.broker = bt.brokers.BackBroker(coc=True)   
    cerebro.broker.setcash(1000000)

    # Set commission
    #cerebro.broker.setcommission()

    # Print out the starting conditions
    start_value = cerebro.broker.getvalue()
    #print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    final_value = cerebro.broker.getvalue()
    #print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    print('(%s, %s) Net Profit: %.2f%%' % (s[0], s[1], (final_value - start_value) / start_value * 100))
    profit_list.append((s, (final_value - start_value) / start_value * 100))
# Out:
# (b, b) Net Profit: 13.95%
# (b, m) Net Profit: 1.61%
# (b, w) Net Profit: -2.69%
# (b, r) Net Profit: 14.49%
# (b, wr) Net Profit: 7.12%
# (m, b) Net Profit: 5.05%
# (m, m) Net Profit: 8.03%
# (m, w) Net Profit: -13.08%
# (m, r) Net Profit: -6.21%
# (m, wr) Net Profit: 37.92%
# (w, b) Net Profit: 7.29%
# (w, m) Net Profit: 16.89%
# (w, w) Net Profit: -6.62%
# (w, r) Net Profit: 16.45%
# (w, wr) Net Profit: 4.36%
# (r, b) Net Profit: 16.16%
# (r, m) Net Profit: 12.25%
# (r, w) Net Profit: -24.00%
# (r, r) Net Profit: 7.10%
# (r, wr) Net Profit: -5.73%
# (wr, b) Net Profit: -2.23%
# (wr, m) Net Profit: 6.31%
# (wr, w) Net Profit: -2.08%
# (wr, r) Net Profit: 1.36%
# (wr, wr) Net Profit: 5.80%

# %%
random.seed(10086)

s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 365)
e_date = datetime.date(2020, 12, 31)

stock_index = '399300.SZ'
pro = ts.pro_api('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6')
index_list = np.unique(pro.index_weight(index_code=stock_index,
                                        start_date=s_date.strftime('%Y%m%d'),
                                        end_date=e_date.strftime('%Y%m%d')).con_code).tolist()
profit = 0
for i in range(20):

    cerebro = bt.Cerebro()

    # Add a strategy
    strats = cerebro.addstrategy(Strategy_comp_mul, printlog=True, using_atr=True, atr_percent=0.01, buy_signal = 'm', sell_signal = 'wr') 

    for s_code in index_list:
        df = pd.read_csv('.\\Data\\2020\\' + s_code + '.csv')
        df.index=pd.to_datetime(df.trade_date)
        data = bt.feeds.PandasData(dataname=df,fromdate=s_date,todate=e_date)

        # Add the index Data Feed to Cerebo
        cerebro.adddata(data, name = s_code)

    # Set cash inside the strategy
    cerebro.broker = bt.brokers.BackBroker(coc=True)   
    cerebro.broker.setcash(500000)

    # Set commission
    #cerebro.broker.setcommission()

    # Print out the starting conditions
    start_value = cerebro.broker.getvalue()
    #print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    final_value = cerebro.broker.getvalue()
    #print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    print('Net Profit: %.2f%%' % ((final_value - start_value) / start_value * 100))

    profit += (final_value - start_value) / start_value * 100
# Out:
# 2020-08-13: BUY CREATE, Code: 601186.SH, Price: 9.07, Lots: 21200, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 600025.SH, Price: 3.86, Lots: 61900, Current Position: 0
# 2020-08-13: BUY CREATE, Code: 300070.SZ, Price: 9.27, Lots: 17400, Current Position: 0
# 2020-08-14: Order Margin
# 2020-08-14: BUY EXECUTED, Price:9.07, Lot:21200, Cash:68782.
# 2020-08-14: BUY EXECUTED, Price:3.86, Lot:61900, Cash:68782.
# 2020-08-14: Sell CREATE, Code: 600025.SH, Price: 3.92, Lots:61900, Current Position: 61900
# 2020-08-14: BUY CREATE, Code: 600928.SH, Price: 5.72, Lots: 33900, Current Position: 0
# 2020-08-14: BUY CREATE, Code: 600027.SH, Price: 3.81, Lots: 47200, Current Position: 0
# 2020-08-14: BUY CREATE, Code: 600050.SH, Price: 5.32, Lots: 51000, Current Position: 0
# 2020-08-14: BUY CREATE, Code: 600009.SH, Price: 75.15, Lots: 2600, Current Position: 0
# 2020-08-14: BUY CREATE, Code: 002230.SZ, Price: 38.45, Lots: 3900, Current Position: 0
# 2020-08-14: BUY CREATE, Code: 000671.SZ, Price: 7.30, Lots: 21400, Current Position: 0
# 2020-08-17: Order Margin
# 2020-08-17: Order Margin
# 2020-08-17: Order Margin
# 2020-08-17: Order Margin
# 2020-08-17: Order Margin
# 2020-08-17: SELL EXECUTED, Price:3.92, Lot:61900, Cash:117522.
# 2020-08-17: BUY EXECUTED, Price:5.72, Lot:33900, Cash:117522.
# 2020-08-17: OPERATION PROFIT, GROSS 3714.00, NET 3714.00
# 2020-08-17: Sell CREATE, Code: 600928.SH, Price: 5.99, Lots:33900, Current Position: 33900
# 2020-08-17: Sell CREATE, Code: 601186.SH, Price: 9.27, Lots:21200, Current Position: 21200
# 2020-08-17: BUY CREATE, Code: 601236.SH, Price: 22.82, Lots: 5600, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 600019.SH, Price: 5.06, Lots: 56400, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 601211.SH, Price: 19.90, Lots: 7500, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 000776.SZ, Price: 16.27, Lots: 9200, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 000425.SZ, Price: 6.51, Lots: 28300, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 601162.SH, Price: 7.25, Lots: 18500, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 601881.SH, Price: 13.89, Lots: 8600, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 000625.SZ, Price: 11.91, Lots: 11900, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 600406.SH, Price: 22.03, Lots: 7900, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 601225.SH, Price: 7.99, Lots: 27600, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 002010.SZ, Price: 6.16, Lots: 33100, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 600848.SH, Price: 23.23, Lots: 7900, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 600031.SH, Price: 21.30, Lots: 7200, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 600271.SH, Price: 18.21, Lots: 9800, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 600516.SH, Price: 7.16, Lots: 21100, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 601818.SH, Price: 4.10, Lots: 50300, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 601318.SH, Price: 81.10, Lots: 2500, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 601229.SH, Price: 8.72, Lots: 31600, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 600390.SH, Price: 8.15, Lots: 21200, Current Position: 0
# 2020-08-17: BUY CREATE, Code: 601688.SH, Price: 21.72, Lots: 6600, Current Position: 0
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: Order Margin
# 2020-08-18: SELL EXECUTED, Price:5.99, Lot:33900, Cash:103931.
# 2020-08-18: SELL EXECUTED, Price:9.27, Lot:21200, Cash:103931.
# 2020-08-18: BUY EXECUTED, Price:22.82, Lot:5600, Cash:103931.
# 2020-08-18: BUY EXECUTED, Price:5.06, Lot:56400, Cash:103931.
# 2020-08-18: OPERATION PROFIT, GROSS 9153.00, NET 9153.00
# 2020-08-18: OPERATION PROFIT, GROSS 4240.00, NET 4240.00
# 2020-08-18: BUY CREATE, Code: 603195.SH, Price: 168.00, Lots: 900, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 000723.SZ, Price: 7.16, Lots: 21900, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 601998.SH, Price: 5.39, Lots: 47600, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 601138.SH, Price: 15.18, Lots: 11200, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 601298.SH, Price: 6.51, Lots: 26000, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 600104.SH, Price: 18.77, Lots: 13400, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 600999.SH, Price: 23.49, Lots: 5200, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 600015.SH, Price: 6.55, Lots: 46900, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 601117.SH, Price: 6.00, Lots: 39100, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 601916.SH, Price: 4.27, Lots: 58800, Current Position: 0
# 2020-08-18: BUY CREATE, Code: 600170.SH, Price: 3.19, Lots: 101400, Current Position: 0
# 2020-08-19: Order Margin
# 2020-08-19: Order Margin
# 2020-08-19: Order Margin
# 2020-08-19: Order Margin
# 2020-08-19: Order Margin
# 2020-08-19: Order Margin
# 2020-08-19: Order Margin
# 2020-08-19: Order Margin
# 2020-08-19: Order Margin
# 2020-08-19: Order Margin
# 2020-08-19: Order Margin
# 2020-08-19: BUY CREATE, Code: 601088.SH, Price: 16.00, Lots: 16900, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 003816.SZ, Price: 3.11, Lots: 104400, Current Position: 0
# 2020-08-19: BUY CREATE, Code: 600023.SH, Price: 3.65, Lots: 85300, Current Position: 0
# 2020-08-20: Order Margin
# 2020-08-20: Order Margin
# 2020-08-20: Order Margin
# 2020-08-20: BUY CREATE, Code: 600004.SH, Price: 15.04, Lots: 10500, Current Position: 0
# 2020-08-20: BUY CREATE, Code: 603156.SH, Price: 24.54, Lots: 6900, Current Position: 0
# 2020-08-21: Order Margin
# 2020-08-21: Order Margin
# 2020-08-21: Sell CREATE, Code: 600019.SH, Price: 5.08, Lots:56400, Current Position: 56400
# 2020-08-21: BUY CREATE, Code: 600600.SH, Price: 82.00, Lots: 1500, Current Position: 0
# 2020-08-21: BUY CREATE, Code: 600900.SH, Price: 18.99, Lots: 17300, Current Position: 0
# 2020-08-24: Order Margin
# 2020-08-24: SELL EXECUTED, Price:5.08, Lot:56400, Cash:267443.
# 2020-08-24: BUY EXECUTED, Price:82.00, Lot:1500, Cash:267443.
# 2020-08-24: OPERATION PROFIT, GROSS 1128.00, NET 1128.00
# 2020-08-24: Sell CREATE, Code: 600600.SH, Price: 82.00, Lots:1500, Current Position: 1500
# 2020-08-24: BUY CREATE, Code: 300498.SZ, Price: 24.60, Lots: 8300, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 600845.SH, Price: 69.88, Lots: 1500, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 000938.SZ, Price: 45.44, Lots: 2900, Current Position: 0
# 2020-08-24: BUY CREATE, Code: 601138.SH, Price: 14.99, Lots: 11300, Current Position: 0
# 2020-08-25: Order Margin
# 2020-08-25: Order Margin
# 2020-08-25: SELL EXECUTED, Price:82.00, Lot:1500, Cash:81443.
# 2020-08-25: BUY EXECUTED, Price:24.60, Lot:8300, Cash:81443.
# 2020-08-25: BUY EXECUTED, Price:69.88, Lot:1500, Cash:81443.
# 2020-08-25: OPERATION PROFIT, GROSS 0.00, NET 0.00
# 2020-08-25: BUY CREATE, Code: 300015.SZ, Price: 46.35, Lots: 3600, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 300033.SZ, Price: 155.97, Lots: 700, Current Position: 0
# 2020-08-25: BUY CREATE, Code: 600104.SH, Price: 18.69, Lots: 13600, Current Position: 0
# 2020-08-26: Order Margin
# 2020-08-26: Order Margin
# 2020-08-26: Order Margin
# 2020-08-26: BUY CREATE, Code: 002475.SZ, Price: 54.97, Lots: 1700, Current Position: 0
# 2020-08-26: BUY CREATE, Code: 002555.SZ, Price: 45.28, Lots: 2800, Current Position: 0
# 2020-08-26: BUY CREATE, Code: 300347.SZ, Price: 107.00, Lots: 1200, Current Position: 0
# 2020-08-26: BUY CREATE, Code: 601100.SH, Price: 64.00, Lots: 2000, Current Position: 0
# 2020-08-27: Order Margin
# 2020-08-27: Order Margin
# 2020-08-27: Order Margin
# 2020-08-27: Order Margin
# 2020-08-27: Sell CREATE, Code: 600845.SH, Price: 70.93, Lots:1500, Current Position: 1500
# 2020-08-27: BUY CREATE, Code: 600170.SH, Price: 3.37, Lots: 72100, Current Position: 0
# 2020-08-27: BUY CREATE, Code: 600233.SH, Price: 15.93, Lots: 7100, Current Position: 0
# 2020-08-27: BUY CREATE, Code: 600104.SH, Price: 19.20, Lots: 12000, Current Position: 0
# 2020-08-27: BUY CREATE, Code: 300017.SZ, Price: 9.54, Lots: 15300, Current Position: 0
# 2020-08-28: Order Margin
# 2020-08-28: Order Margin
# 2020-08-28: Order Margin
# 2020-08-28: Order Margin
# 2020-08-28: SELL EXECUTED, Price:70.93, Lot:1500, Cash:187838.
# 2020-08-28: OPERATION PROFIT, GROSS 1575.00, NET 1575.00
# 2020-08-28: Sell CREATE, Code: 300498.SZ, Price: 24.96, Lots:8300, Current Position: 8300
# 2020-08-28: BUY CREATE, Code: 600276.SH, Price: 95.39, Lots: 2000, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 000166.SZ, Price: 5.74, Lots: 30800, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 002594.SZ, Price: 85.39, Lots: 1800, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 002773.SZ, Price: 49.19, Lots: 2900, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 300529.SZ, Price: 77.44, Lots: 1800, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 000776.SZ, Price: 15.93, Lots: 12800, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 601088.SH, Price: 15.85, Lots: 16900, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 601688.SH, Price: 21.70, Lots: 9000, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 000963.SZ, Price: 28.50, Lots: 5600, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 600570.SH, Price: 114.25, Lots: 1100, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 000538.SZ, Price: 114.60, Lots: 1500, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 600061.SH, Price: 15.15, Lots: 10400, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 300413.SZ, Price: 70.73, Lots: 1600, Current Position: 0
# 2020-08-28: BUY CREATE, Code: 600208.SH, Price: 3.41, Lots: 56900, Current Position: 0
# 2020-08-31: Order Margin
# 2020-08-31: Order Margin
# 2020-08-31: Order Margin
# 2020-08-31: Order Margin
# 2020-08-31: Order Margin
# 2020-08-31: Order Margin
# 2020-08-31: Order Margin
# 2020-08-31: Order Margin
# 2020-08-31: Order Margin
# 2020-08-31: Order Margin
# 2020-08-31: Order Margin
# 2020-08-31: Order Margin
# 2020-08-31: SELL EXECUTED, Price:24.96, Lot:8300, Cash:27434.
# 2020-08-31: BUY EXECUTED, Price:95.39, Lot:2000, Cash:27434.
# 2020-08-31: BUY EXECUTED, Price:5.74, Lot:30800, Cash:27434.
# 2020-08-31: OPERATION PROFIT, GROSS 2988.00, NET 2988.00
# 2020-08-31: Sell CREATE, Code: 600276.SH, Price: 94.87, Lots:2000, Current Position: 2000
# 2020-08-31: BUY CREATE, Code: 603658.SH, Price: 161.19, Lots: 700, Current Position: 0
# 2020-08-31: BUY CREATE, Code: 002938.SZ, Price: 48.90, Lots: 2500, Current Position: 0
# 2020-09-01: Order Margin
# 2020-09-01: SELL EXECUTED, Price:94.87, Lot:2000, Cash:104341.
# 2020-09-01: BUY EXECUTED, Price:161.19, Lot:700, Cash:104341.
# 2020-09-01: OPERATION PROFIT, GROSS -1040.00, NET -1040.00
# 2020-09-01: BUY CREATE, Code: 002050.SZ, Price: 23.90, Lots: 4500, Current Position: 0
# 2020-09-01: BUY CREATE, Code: 600271.SH, Price: 18.08, Lots: 12600, Current Position: 0
# 2020-09-01: BUY CREATE, Code: 300408.SZ, Price: 28.70, Lots: 4800, Current Position: 0
# 2020-09-01: BUY CREATE, Code: 600362.SH, Price: 16.23, Lots: 13100, Current Position: 0
# 2020-09-01: BUY CREATE, Code: 600999.SH, Price: 22.15, Lots: 5200, Current Position: 0
# 2020-09-02: Order Margin
# 2020-09-02: Order Margin
# 2020-09-02: Order Margin
# 2020-09-02: Order Margin
# 2020-09-02: Order Margin
# 2020-09-02: BUY CREATE, Code: 600188.SH, Price: 9.27, Lots: 27000, Current Position: 0
# 2020-09-02: BUY CREATE, Code: 603833.SH, Price: 107.60, Lots: 1200, Current Position: 0
# 2020-09-02: BUY CREATE, Code: 002410.SZ, Price: 73.00, Lots: 1700, Current Position: 0
# 2020-09-02: BUY CREATE, Code: 600019.SH, Price: 4.98, Lots: 56900, Current Position: 0
# 2020-09-02: BUY CREATE, Code: 002468.SZ, Price: 17.20, Lots: 14600, Current Position: 0
# 2020-09-02: BUY CREATE, Code: 603156.SH, Price: 26.07, Lots: 5000, Current Position: 0
# 2020-09-03: Order Margin
# 2020-09-03: Order Margin
# 2020-09-03: Order Margin
# 2020-09-03: Order Margin
# 2020-09-03: Order Margin
# 2020-09-03: Order Margin
# 2020-09-03: BUY CREATE, Code: 000723.SZ, Price: 6.83, Lots: 18000, Current Position: 0
# 2020-09-03: BUY CREATE, Code: 002673.SZ, Price: 9.92, Lots: 19400, Current Position: 0
# 2020-09-03: BUY CREATE, Code: 601166.SH, Price: 16.28, Lots: 16300, Current Position: 0
# 2020-09-03: BUY CREATE, Code: 601788.SH, Price: 23.79, Lots: 4700, Current Position: 0
# 2020-09-04: Order Margin
# 2020-09-04: Order Margin
# 2020-09-04: Order Margin
# 2020-09-04: Order Margin
# 2020-09-04: BUY CREATE, Code: 000002.SZ, Price: 28.07, Lots: 8500, Current Position: 0
# 2020-09-04: BUY CREATE, Code: 600100.SH, Price: 8.02, Lots: 31300, Current Position: 0
# 2020-09-07: Order Margin
# 2020-09-07: Order Margin
# 2020-09-07: BUY CREATE, Code: 601229.SH, Price: 8.41, Lots: 42900, Current Position: 0
# 2020-09-07: BUY CREATE, Code: 600703.SH, Price: 27.88, Lots: 4500, Current Position: 0
# 2020-09-07: BUY CREATE, Code: 600816.SH, Price: 2.13, Lots: 80400, Current Position: 0
# 2020-09-08: Order Margin
# 2020-09-08: Order Margin
# 2020-09-08: Order Margin
# 2020-09-08: BUY CREATE, Code: 002673.SZ, Price: 9.94, Lots: 20400, Current Position: 0
# 2020-09-08: BUY CREATE, Code: 600297.SH, Price: 4.01, Lots: 31800, Current Position: 0
# 2020-09-08: BUY CREATE, Code: 600221.SH, Price: 1.70, Lots: 111100, Current Position: 0
# 2020-09-09: Order Margin
# 2020-09-09: Order Margin
# 2020-09-09: Order Margin
# 2020-09-09: BUY CREATE, Code: 601992.SH, Price: 3.29, Lots: 72100, Current Position: 0
# 2020-09-09: BUY CREATE, Code: 600010.SH, Price: 1.30, Lots: 166600, Current Position: 0
# 2020-09-09: BUY CREATE, Code: 000709.SZ, Price: 2.33, Lots: 120600, Current Position: 0
# 2020-09-09: BUY CREATE, Code: 600170.SH, Price: 3.21, Lots: 68600, Current Position: 0
# 2020-09-09: BUY CREATE, Code: 601390.SH, Price: 5.61, Lots: 45400, Current Position: 0
# 2020-09-09: BUY CREATE, Code: 601898.SH, Price: 4.15, Lots: 65400, Current Position: 0
# 2020-09-10: Order Margin
# 2020-09-10: Order Margin
# 2020-09-10: Order Margin
# 2020-09-10: Order Margin
# 2020-09-10: Order Margin
# 2020-09-10: Order Margin
# 2020-09-10: BUY CREATE, Code: 000671.SZ, Price: 8.17, Lots: 17100, Current Position: 0
# 2020-09-10: BUY CREATE, Code: 600383.SH, Price: 15.00, Lots: 9400, Current Position: 0
# 2020-09-11: Order Margin
# 2020-09-11: Order Margin
# 2020-09-11: BUY CREATE, Code: 002410.SZ, Price: 71.95, Lots: 1700, Current Position: 0
# 2020-09-14: Order Margin
# 2020-09-14: BUY CREATE, Code: 600845.SH, Price: 70.40, Lots: 1800, Current Position: 0
# 2020-09-14: BUY CREATE, Code: 601828.SH, Price: 10.19, Lots: 23700, Current Position: 0
# 2020-09-14: BUY CREATE, Code: 002475.SZ, Price: 56.21, Lots: 2000, Current Position: 0
# 2020-09-14: BUY CREATE, Code: 002938.SZ, Price: 54.67, Lots: 2200, Current Position: 0
# 2020-09-14: BUY CREATE, Code: 000723.SZ, Price: 6.75, Lots: 21200, Current Position: 0
# 2020-09-15: Order Margin
# 2020-09-15: Order Margin
# 2020-09-15: Order Margin
# 2020-09-15: Order Margin
# 2020-09-15: Order Margin
# 2020-09-15: BUY CREATE, Code: 300144.SZ, Price: 19.05, Lots: 6500, Current Position: 0
# 2020-09-15: BUY CREATE, Code: 600489.SH, Price: 11.18, Lots: 13800, Current Position: 0
# 2020-09-15: BUY CREATE, Code: 601318.SH, Price: 79.91, Lots: 3100, Current Position: 0
# 2020-09-15: BUY CREATE, Code: 002153.SZ, Price: 36.61, Lots: 3000, Current Position: 0
# 2020-09-15: BUY CREATE, Code: 600867.SH, Price: 14.90, Lots: 10100, Current Position: 0
# 2020-09-15: BUY CREATE, Code: 600089.SH, Price: 8.66, Lots: 21100, Current Position: 0
# 2020-09-16: Order Margin
# 2020-09-16: Order Margin
# 2020-09-16: Order Margin
# 2020-09-16: Order Margin
# 2020-09-16: Order Margin
# 2020-09-16: Order Margin
# 2020-09-16: BUY CREATE, Code: 601916.SH, Price: 4.23, Lots: 95800, Current Position: 0
# 2020-09-16: BUY CREATE, Code: 601390.SH, Price: 5.69, Lots: 39100, Current Position: 0
# 2020-09-16: BUY CREATE, Code: 002493.SZ, Price: 18.85, Lots: 6000, Current Position: 0
# 2020-09-17: Order Margin
# 2020-09-17: Order Margin
# 2020-09-17: Order Margin
# 2020-09-17: BUY CREATE, Code: 601018.SH, Price: 4.00, Lots: 53800, Current Position: 0
# 2020-09-17: BUY CREATE, Code: 603501.SH, Price: 193.01, Lots: 500, Current Position: 0
# 2020-09-17: BUY CREATE, Code: 601238.SH, Price: 10.89, Lots: 14100, Current Position: 0
# 2020-09-18: Order Margin
# 2020-09-18: Order Margin
# 2020-09-18: Order Margin
# 2020-09-18: BUY CREATE, Code: 688009.SH, Price: 6.44, Lots: 33400, Current Position: 0
# 2020-09-18: BUY CREATE, Code: 002475.SZ, Price: 55.70, Lots: 2000, Current Position: 0
# 2020-09-18: BUY CREATE, Code: 000656.SZ, Price: 10.37, Lots: 12400, Current Position: 0
# 2020-09-18: BUY CREATE, Code: 600297.SH, Price: 4.04, Lots: 27300, Current Position: 0
# 2020-09-18: BUY CREATE, Code: 000333.SZ, Price: 70.28, Lots: 2400, Current Position: 0
# 2020-09-18: BUY CREATE, Code: 000157.SZ, Price: 8.58, Lots: 19700, Current Position: 0
# 2020-09-18: BUY CREATE, Code: 002411.SZ, Price: 7.68, Lots: 15300, Current Position: 0
# 2020-09-18: BUY CREATE, Code: 600188.SH, Price: 9.84, Lots: 20800, Current Position: 0
# 2020-09-18: BUY CREATE, Code: 601601.SH, Price: 32.44, Lots: 6800, Current Position: 0
# 2020-09-18: BUY CREATE, Code: 000723.SZ, Price: 6.95, Lots: 19300, Current Position: 0
# 2020-09-18: BUY CREATE, Code: 002493.SZ, Price: 18.94, Lots: 6100, Current Position: 0
# 2020-09-21: Order Margin
# 2020-09-21: Order Margin
# 2020-09-21: Order Margin
# 2020-09-21: Order Margin
# 2020-09-21: Order Margin
# 2020-09-21: Order Margin
# 2020-09-21: Order Margin
# 2020-09-21: Order Margin
# 2020-09-21: Order Margin
# 2020-09-21: Order Margin
# 2020-09-21: Order Margin
# 2020-09-21: BUY CREATE, Code: 600362.SH, Price: 16.03, Lots: 10100, Current Position: 0
# 2020-09-21: BUY CREATE, Code: 601377.SH, Price: 8.43, Lots: 17300, Current Position: 0
# 2020-09-21: BUY CREATE, Code: 002179.SZ, Price: 48.21, Lots: 3000, Current Position: 0
# 2020-09-21: BUY CREATE, Code: 000338.SZ, Price: 16.00, Lots: 9500, Current Position: 0
# 2020-09-22: Order Margin
# 2020-09-22: Order Margin
# 2020-09-22: Order Margin
# 2020-09-22: Order Margin
# 2020-09-22: BUY CREATE, Code: 601155.SH, Price: 37.06, Lots: 4800, Current Position: 0
# 2020-09-22: BUY CREATE, Code: 601668.SH, Price: 5.18, Lots: 63000, Current Position: 0
# 2020-09-22: BUY CREATE, Code: 000728.SZ, Price: 12.03, Lots: 11600, Current Position: 0
# 2020-09-22: BUY CREATE, Code: 601997.SH, Price: 8.07, Lots: 33800, Current Position: 0
# 2020-09-22: BUY CREATE, Code: 002460.SZ, Price: 53.91, Lots: 1900, Current Position: 0
# 2020-09-22: BUY CREATE, Code: 601577.SH, Price: 9.05, Lots: 24300, Current Position: 0
# 2020-09-23: Order Margin
# 2020-09-23: Order Margin
# 2020-09-23: Order Margin
# 2020-09-23: Order Margin
# 2020-09-23: Order Margin
# 2020-09-23: Order Margin
# 2020-09-23: Sell CREATE, Code: 603658.SH, Price: 160.31, Lots:700, Current Position: 700
# 2020-09-23: BUY CREATE, Code: 600061.SH, Price: 15.21, Lots: 9600, Current Position: 0
# 2020-09-23: BUY CREATE, Code: 601231.SH, Price: 24.06, Lots: 4600, Current Position: 0
# 2020-09-23: BUY CREATE, Code: 002129.SZ, Price: 23.06, Lots: 4500, Current Position: 0
# 2020-09-23: BUY CREATE, Code: 002821.SZ, Price: 254.17, Lots: 400, Current Position: 0
# 2020-09-23: BUY CREATE, Code: 601878.SH, Price: 15.72, Lots: 6700, Current Position: 0
# 2020-09-24: Order Margin
# 2020-09-24: Order Margin
# 2020-09-24: Order Margin
# 2020-09-24: Order Margin
# 2020-09-24: SELL EXECUTED, Price:160.31, Lot:700, Cash:70542.
# 2020-09-24: BUY EXECUTED, Price:15.21, Lot:9600, Cash:70542.
# 2020-09-24: OPERATION PROFIT, GROSS -616.00, NET -616.00
# 2020-09-24: BUY CREATE, Code: 600845.SH, Price: 69.14, Lots: 2100, Current Position: 0
# 2020-09-25: Order Margin
# 2020-09-25: Sell CREATE, Code: 600061.SH, Price: 15.41, Lots:9600, Current Position: 9600
# 2020-09-25: BUY CREATE, Code: 300408.SZ, Price: 27.94, Lots: 5600, Current Position: 0
# 2020-09-25: BUY CREATE, Code: 601555.SH, Price: 10.69, Lots: 14800, Current Position: 0
# 2020-09-25: BUY CREATE, Code: 601108.SH, Price: 14.76, Lots: 8600, Current Position: 0
# 2020-09-28: Order Margin
# 2020-09-28: Order Margin
# 2020-09-28: SELL EXECUTED, Price:15.41, Lot:9600, Cash:62014.
# 2020-09-28: BUY EXECUTED, Price:27.94, Lot:5600, Cash:62014.
# 2020-09-28: OPERATION PROFIT, GROSS 1920.00, NET 1920.00
# 2020-09-28: Sell CREATE, Code: 300408.SZ, Price: 28.63, Lots:5600, Current Position: 5600
# 2020-09-29: SELL EXECUTED, Price:28.63, Lot:5600, Cash:222342.
# 2020-09-29: OPERATION PROFIT, GROSS 3864.00, NET 3864.00
# 2020-09-29: BUY CREATE, Code: 002460.SZ, Price: 54.73, Lots: 1900, Current Position: 0
# 2020-09-29: BUY CREATE, Code: 002241.SZ, Price: 40.64, Lots: 3100, Current Position: 0
# 2020-09-29: BUY CREATE, Code: 600763.SH, Price: 204.00, Lots: 500, Current Position: 0
# 2020-09-29: BUY CREATE, Code: 600999.SH, Price: 21.88, Lots: 6400, Current Position: 0
# 2020-09-30: Order Margin
# 2020-09-30: Order Margin
# 2020-09-30: Order Margin
# 2020-09-30: BUY EXECUTED, Price:54.73, Lot:1900, Cash:118355.
# 2020-09-30: BUY CREATE, Code: 002410.SZ, Price: 72.95, Lots: 1900, Current Position: 0
# 2020-09-30: BUY CREATE, Code: 300015.SZ, Price: 51.42, Lots: 3200, Current Position: 0
# 2020-09-30: BUY CREATE, Code: 300122.SZ, Price: 139.31, Lots: 500, Current Position: 0
# 2020-10-09: Order Margin
# 2020-10-09: Order Margin
# 2020-10-09: Order Margin
# 2020-10-09: Sell CREATE, Code: 002460.SZ, Price: 56.66, Lots:1900, Current Position: 1900
# 2020-10-09: BUY CREATE, Code: 300433.SZ, Price: 35.75, Lots: 3500, Current Position: 0
# 2020-10-09: BUY CREATE, Code: 300628.SZ, Price: 61.99, Lots: 2300, Current Position: 0
# 2020-10-09: BUY CREATE, Code: 002050.SZ, Price: 23.82, Lots: 5600, Current Position: 0
# 2020-10-09: BUY CREATE, Code: 002007.SZ, Price: 61.35, Lots: 1700, Current Position: 0
# 2020-10-09: BUY CREATE, Code: 002129.SZ, Price: 23.60, Lots: 4800, Current Position: 0
# 2020-10-09: BUY CREATE, Code: 002415.SZ, Price: 38.15, Lots: 5500, Current Position: 0
# 2020-10-09: BUY CREATE, Code: 300413.SZ, Price: 68.90, Lots: 2000, Current Position: 0
# 2020-10-12: Order Margin
# 2020-10-12: Order Margin
# 2020-10-12: Order Margin
# 2020-10-12: Order Margin
# 2020-10-12: Order Margin
# 2020-10-12: Order Margin
# 2020-10-12: SELL EXECUTED, Price:56.66, Lot:1900, Cash:100884.
# 2020-10-12: BUY EXECUTED, Price:35.75, Lot:3500, Cash:100884.
# 2020-10-12: OPERATION PROFIT, GROSS 3667.00, NET 3667.00
# 2020-10-12: Sell CREATE, Code: 000166.SZ, Price: 5.58, Lots:30800, Current Position: 30800
# 2020-10-12: Sell CREATE, Code: 300433.SZ, Price: 36.46, Lots:3500, Current Position: 3500
# 2020-10-12: Sell CREATE, Code: 601236.SH, Price: 19.17, Lots:5600, Current Position: 5600
# 2020-10-12: BUY CREATE, Code: 603288.SH, Price: 172.34, Lots: 1000, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 601881.SH, Price: 13.39, Lots: 12800, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 000858.SZ, Price: 241.75, Lots: 700, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 600346.SH, Price: 19.96, Lots: 7300, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 000776.SZ, Price: 16.50, Lots: 12600, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 601198.SH, Price: 13.51, Lots: 11800, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 300014.SZ, Price: 54.72, Lots: 2400, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 600196.SH, Price: 55.33, Lots: 1900, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 000338.SZ, Price: 16.02, Lots: 8800, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 601166.SH, Price: 16.74, Lots: 19100, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 002736.SZ, Price: 14.76, Lots: 11300, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 002271.SZ, Price: 57.67, Lots: 2200, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 600038.SH, Price: 58.71, Lots: 2500, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 601688.SH, Price: 21.62, Lots: 10900, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 002179.SZ, Price: 49.49, Lots: 3200, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 300347.SZ, Price: 110.25, Lots: 1300, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 002673.SZ, Price: 9.96, Lots: 17300, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 600918.SH, Price: 16.12, Lots: 8100, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 300676.SZ, Price: 156.10, Lots: 900, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 002600.SZ, Price: 12.78, Lots: 12100, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 600019.SH, Price: 5.09, Lots: 72900, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 600115.SH, Price: 5.09, Lots: 28800, Current Position: 0
# 2020-10-12: BUY CREATE, Code: 601318.SH, Price: 80.86, Lots: 2500, Current Position: 0
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: Order Margin
# 2020-10-13: SELL EXECUTED, Price:5.58, Lot:30800, Cash:163978.
# 2020-10-13: SELL EXECUTED, Price:36.46, Lot:3500, Cash:163978.
# 2020-10-13: SELL EXECUTED, Price:19.17, Lot:5600, Cash:163978.
# 2020-10-13: BUY EXECUTED, Price:172.34, Lot:1000, Cash:163978.
# 2020-10-13: BUY EXECUTED, Price:13.39, Lot:12800, Cash:163978.
# 2020-10-13: OPERATION PROFIT, GROSS -4928.00, NET -4928.00
# 2020-10-13: OPERATION PROFIT, GROSS 2485.00, NET 2485.00
# 2020-10-13: OPERATION PROFIT, GROSS -20440.00, NET -20440.00
# 2020-10-13: Sell CREATE, Code: 601881.SH, Price: 13.19, Lots:12800, Current Position: 12800
# 2020-10-13: Sell CREATE, Code: 603288.SH, Price: 172.63, Lots:1000, Current Position: 1000
# 2020-10-13: BUY CREATE, Code: 600109.SH, Price: 15.73, Lots: 8100, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 600398.SH, Price: 7.25, Lots: 19000, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 600998.SH, Price: 17.91, Lots: 9700, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 603259.SH, Price: 109.00, Lots: 1500, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 600030.SH, Price: 31.35, Lots: 6700, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 600893.SH, Price: 43.10, Lots: 2900, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 601877.SH, Price: 31.63, Lots: 4700, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 600760.SH, Price: 62.26, Lots: 1900, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 002049.SZ, Price: 129.63, Lots: 1000, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 002304.SZ, Price: 151.20, Lots: 1000, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 300059.SZ, Price: 26.12, Lots: 5600, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 000768.SZ, Price: 25.80, Lots: 5400, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 000157.SZ, Price: 8.59, Lots: 20000, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 600848.SH, Price: 23.56, Lots: 10100, Current Position: 0
# 2020-10-13: BUY CREATE, Code: 300529.SZ, Price: 76.44, Lots: 1900, Current Position: 0
# 2020-10-14: Order Margin
# 2020-10-14: Order Margin
# 2020-10-14: Order Margin
# 2020-10-14: Order Margin
# 2020-10-14: Order Margin
# 2020-10-14: Order Margin
# 2020-10-14: Order Margin
# 2020-10-14: Order Margin
# 2020-10-14: Order Margin
# 2020-10-14: Order Margin
# 2020-10-14: Order Margin
# 2020-10-14: Order Margin
# 2020-10-14: SELL EXECUTED, Price:13.19, Lot:12800, Cash:66550.
# 2020-10-14: SELL EXECUTED, Price:172.63, Lot:1000, Cash:66550.
# 2020-10-14: BUY EXECUTED, Price:15.73, Lot:8100, Cash:66550.
# 2020-10-14: BUY EXECUTED, Price:7.25, Lot:19000, Cash:66550.
# 2020-10-14: BUY EXECUTED, Price:17.91, Lot:9700, Cash:66550.
# 2020-10-14: OPERATION PROFIT, GROSS -2560.00, NET -2560.00
# 2020-10-14: OPERATION PROFIT, GROSS 290.00, NET 290.00
# 2020-10-14: Sell CREATE, Code: 600398.SH, Price: 7.54, Lots:19000, Current Position: 19000
# 2020-10-14: Sell CREATE, Code: 600998.SH, Price: 17.90, Lots:9700, Current Position: 9700
# 2020-10-14: BUY CREATE, Code: 603195.SH, Price: 168.01, Lots: 1100, Current Position: 0
# 2020-10-14: BUY CREATE, Code: 600276.SH, Price: 93.00, Lots: 2300, Current Position: 0
# 2020-10-14: BUY CREATE, Code: 600519.SH, Price: 1729.00, Lots: 100, Current Position: 0
# 2020-10-14: BUY CREATE, Code: 600588.SH, Price: 43.29, Lots: 3500, Current Position: 0
# 2020-10-14: BUY CREATE, Code: 000651.SZ, Price: 57.60, Lots: 4700, Current Position: 0
# 2020-10-14: BUY CREATE, Code: 000786.SZ, Price: 34.68, Lots: 3300, Current Position: 0
# 2020-10-14: BUY CREATE, Code: 002202.SZ, Price: 12.00, Lots: 14600, Current Position: 0
# 2020-10-14: BUY CREATE, Code: 600837.SH, Price: 14.86, Lots: 13300, Current Position: 0
# 2020-10-14: BUY CREATE, Code: 603501.SH, Price: 186.70, Lots: 700, Current Position: 0
# 2020-10-14: BUY CREATE, Code: 601818.SH, Price: 3.97, Lots: 64200, Current Position: 0
# 2020-10-14: BUY CREATE, Code: 601577.SH, Price: 9.14, Lots: 29200, Current Position: 0
# 2020-10-14: BUY CREATE, Code: 600369.SH, Price: 5.45, Lots: 26200, Current Position: 0
# 2020-10-15: Order Margin
# 2020-10-15: Order Margin
# 2020-10-15: Order Margin
# 2020-10-15: Order Margin
# 2020-10-15: Order Margin
# 2020-10-15: Order Margin
# 2020-10-15: Order Margin
# 2020-10-15: Order Margin
# 2020-10-15: Order Margin
# 2020-10-15: Order Margin
# 2020-10-15: Order Margin
# 2020-10-15: SELL EXECUTED, Price:7.54, Lot:19000, Cash:198629.
# 2020-10-15: SELL EXECUTED, Price:17.90, Lot:9700, Cash:198629.
# 2020-10-15: BUY EXECUTED, Price:168.01, Lot:1100, Cash:198629.
# 2020-10-15: OPERATION PROFIT, GROSS 5510.00, NET 5510.00
# 2020-10-15: OPERATION PROFIT, GROSS -97.00, NET -97.00
# 2020-10-15: Sell CREATE, Code: 603195.SH, Price: 167.13, Lots:1100, Current Position: 1100
# 2020-10-15: BUY CREATE, Code: 600522.SH, Price: 11.39, Lots: 17400, Current Position: 0
# 2020-10-15: BUY CREATE, Code: 603260.SH, Price: 29.75, Lots: 5800, Current Position: 0
# 2020-10-15: BUY CREATE, Code: 600352.SH, Price: 14.99, Lots: 14900, Current Position: 0
# 2020-10-15: BUY CREATE, Code: 002607.SZ, Price: 36.71, Lots: 2800, Current Position: 0
# 2020-10-15: BUY CREATE, Code: 002142.SZ, Price: 35.02, Lots: 4400, Current Position: 0
# 2020-10-15: BUY CREATE, Code: 600036.SH, Price: 39.01, Lots: 5900, Current Position: 0
# 2020-10-16: Order Margin
# 2020-10-16: Order Margin
# 2020-10-16: Order Margin
# 2020-10-16: Order Margin
# 2020-10-16: SELL EXECUTED, Price:167.13, Lot:1100, Cash:11736.
# 2020-10-16: BUY EXECUTED, Price:11.39, Lot:17400, Cash:11736.
# 2020-10-16: BUY EXECUTED, Price:29.75, Lot:5800, Cash:11736.
# 2020-10-16: OPERATION PROFIT, GROSS -968.00, NET -968.00
# 2020-10-16: Sell CREATE, Code: 600109.SH, Price: 15.77, Lots:8100, Current Position: 8100
# 2020-10-16: Sell CREATE, Code: 600522.SH, Price: 11.45, Lots:17400, Current Position: 17400
# 2020-10-16: BUY CREATE, Code: 601788.SH, Price: 22.68, Lots: 6700, Current Position: 0
# 2020-10-16: BUY CREATE, Code: 603369.SH, Price: 48.84, Lots: 2500, Current Position: 0
# 2020-10-16: BUY CREATE, Code: 600958.SH, Price: 11.53, Lots: 11900, Current Position: 0
# 2020-10-16: BUY CREATE, Code: 601939.SH, Price: 6.40, Lots: 60800, Current Position: 0
# 2020-10-16: BUY CREATE, Code: 601998.SH, Price: 5.28, Lots: 68600, Current Position: 0
# 2020-10-16: BUY CREATE, Code: 601898.SH, Price: 4.18, Lots: 60800, Current Position: 0
# 2020-10-19: Order Margin
# 2020-10-19: Order Margin
# 2020-10-19: Order Margin
# 2020-10-19: Order Margin
# 2020-10-19: SELL EXECUTED, Price:15.77, Lot:8100, Cash:64646.
# 2020-10-19: SELL EXECUTED, Price:11.45, Lot:17400, Cash:64646.
# 2020-10-19: BUY EXECUTED, Price:22.68, Lot:6700, Cash:64646.
# 2020-10-19: BUY EXECUTED, Price:48.84, Lot:2500, Cash:64646.
# 2020-10-19: OPERATION PROFIT, GROSS 324.00, NET 324.00
# 2020-10-19: OPERATION PROFIT, GROSS 1044.00, NET 1044.00
# 2020-10-19: BUY CREATE, Code: 002252.SZ, Price: 8.86, Lots: 19500, Current Position: 0
# 2020-10-19: BUY CREATE, Code: 000703.SZ, Price: 11.75, Lots: 12600, Current Position: 0
# 2020-10-19: BUY CREATE, Code: 600177.SH, Price: 7.12, Lots: 42100, Current Position: 0
# 2020-10-19: BUY CREATE, Code: 600977.SH, Price: 15.42, Lots: 11800, Current Position: 0
# 2020-10-19: BUY CREATE, Code: 002945.SZ, Price: 15.25, Lots: 11100, Current Position: 0
# 2020-10-19: BUY CREATE, Code: 601398.SH, Price: 5.02, Lots: 101400, Current Position: 0
# 2020-10-19: BUY CREATE, Code: 601658.SH, Price: 4.67, Lots: 80400, Current Position: 0
# 2020-10-20: Order Margin
# 2020-10-20: Order Margin
# 2020-10-20: Order Margin
# 2020-10-20: Order Margin
# 2020-10-20: Order Margin
# 2020-10-20: Order Margin
# 2020-10-20: Order Margin
# 2020-10-20: Sell CREATE, Code: 603369.SH, Price: 49.70, Lots:2500, Current Position: 2500
# 2020-10-20: BUY CREATE, Code: 600332.SH, Price: 32.11, Lots: 5800, Current Position: 0
# 2020-10-20: BUY CREATE, Code: 601899.SH, Price: 6.75, Lots: 20500, Current Position: 0
# 2020-10-20: BUY CREATE, Code: 000963.SZ, Price: 26.64, Lots: 7300, Current Position: 0
# 2020-10-21: Order Margin
# 2020-10-21: Order Margin
# 2020-10-21: SELL EXECUTED, Price:49.70, Lot:2500, Cash:2659.
# 2020-10-21: BUY EXECUTED, Price:32.11, Lot:5800, Cash:2659.
# 2020-10-21: OPERATION PROFIT, GROSS 2150.00, NET 2150.00
# 2020-10-21: BUY CREATE, Code: 601607.SH, Price: 21.27, Lots: 9700, Current Position: 0
# 2020-10-21: BUY CREATE, Code: 601238.SH, Price: 11.45, Lots: 12500, Current Position: 0
# 2020-10-21: BUY CREATE, Code: 002120.SZ, Price: 21.16, Lots: 8600, Current Position: 0
# 2020-10-21: BUY CREATE, Code: 601229.SH, Price: 8.51, Lots: 37600, Current Position: 0
# 2020-10-22: Order Margin
# 2020-10-22: Order Margin
# 2020-10-22: Order Margin
# 2020-10-22: Order Margin
# 2020-10-22: BUY CREATE, Code: 002024.SZ, Price: 9.73, Lots: 26700, Current Position: 0
# 2020-10-22: BUY CREATE, Code: 601288.SH, Price: 3.21, Lots: 148900, Current Position: 0
# 2020-10-22: BUY CREATE, Code: 601901.SH, Price: 8.95, Lots: 22300, Current Position: 0
# 2020-10-22: BUY CREATE, Code: 601997.SH, Price: 8.22, Lots: 29900, Current Position: 0
# 2020-10-23: Order Margin
# 2020-10-23: Order Margin
# 2020-10-23: Order Margin
# 2020-10-23: Order Margin
# 2020-10-23: BUY CREATE, Code: 600600.SH, Price: 80.97, Lots: 1700, Current Position: 0
# 2020-10-23: BUY CREATE, Code: 601169.SH, Price: 4.84, Lots: 77700, Current Position: 0
# 2020-10-23: BUY CREATE, Code: 601009.SH, Price: 8.45, Lots: 25700, Current Position: 0
# 2020-10-23: BUY CREATE, Code: 600015.SH, Price: 6.36, Lots: 56400, Current Position: 0
# 2020-10-23: BUY CREATE, Code: 002841.SZ, Price: 100.65, Lots: 2000, Current Position: 0
# 2020-10-23: BUY CREATE, Code: 601319.SH, Price: 7.15, Lots: 33400, Current Position: 0
# 2020-10-26: Order Margin
# 2020-10-26: Order Margin
# 2020-10-26: Order Margin
# 2020-10-26: Order Margin
# 2020-10-26: Order Margin
# 2020-10-26: Order Margin
# 2020-10-26: BUY CREATE, Code: 002008.SZ, Price: 37.58, Lots: 4400, Current Position: 0
# 2020-10-26: BUY CREATE, Code: 600733.SH, Price: 6.56, Lots: 19800, Current Position: 0
# 2020-10-26: BUY CREATE, Code: 600660.SH, Price: 32.60, Lots: 3700, Current Position: 0
# 2020-10-26: BUY CREATE, Code: 600297.SH, Price: 4.00, Lots: 29100, Current Position: 0
# 2020-10-26: BUY CREATE, Code: 601668.SH, Price: 5.22, Lots: 65400, Current Position: 0
# 2020-10-26: BUY CREATE, Code: 601669.SH, Price: 4.07, Lots: 54200, Current Position: 0
# 2020-10-27: Order Margin
# 2020-10-27: Order Margin
# 2020-10-27: Order Margin
# 2020-10-27: Order Margin
# 2020-10-27: Order Margin
# 2020-10-27: Order Margin
# 2020-10-27: BUY CREATE, Code: 000898.SZ, Price: 2.75, Lots: 107600, Current Position: 0
# 2020-10-27: BUY CREATE, Code: 002044.SZ, Price: 16.31, Lots: 6800, Current Position: 0
# 2020-10-28: Order Margin
# 2020-10-28: Order Margin
# 2020-10-28: BUY CREATE, Code: 601231.SH, Price: 25.01, Lots: 4500, Current Position: 0
# 2020-10-28: BUY CREATE, Code: 002230.SZ, Price: 38.00, Lots: 5400, Current Position: 0
# 2020-10-28: BUY CREATE, Code: 002236.SZ, Price: 22.40, Lots: 7100, Current Position: 0
# 2020-10-29: Order Margin
# 2020-10-29: Order Margin
# 2020-10-29: Order Margin
# 2020-10-29: Sell CREATE, Code: 603260.SH, Price: 29.85, Lots:5800, Current Position: 5800
# 2020-10-29: BUY CREATE, Code: 600867.SH, Price: 14.91, Lots: 12700, Current Position: 0
# 2020-10-29: BUY CREATE, Code: 688036.SH, Price: 118.80, Lots: 800, Current Position: 0
# 2020-10-29: BUY CREATE, Code: 603799.SH, Price: 41.40, Lots: 3200, Current Position: 0
# 2020-10-29: BUY CREATE, Code: 601877.SH, Price: 32.23, Lots: 5100, Current Position: 0
# 2020-10-29: BUY CREATE, Code: 600068.SH, Price: 7.37, Lots: 31200, Current Position: 0
# 2020-10-29: BUY CREATE, Code: 002422.SZ, Price: 24.29, Lots: 7800, Current Position: 0
# 2020-10-29: BUY CREATE, Code: 600406.SH, Price: 21.22, Lots: 9100, Current Position: 0
# 2020-10-30: Order Margin
# 2020-10-30: Order Margin
# 2020-10-30: Order Margin
# 2020-10-30: Order Margin
# 2020-10-30: Order Margin
# 2020-10-30: Order Margin
# 2020-10-30: Order Margin
# 2020-10-30: SELL EXECUTED, Price:29.85, Lot:5800, Cash:175789.
# 2020-10-30: OPERATION PROFIT, GROSS 580.00, NET 580.00
# 2020-10-30: BUY CREATE, Code: 603501.SH, Price: 198.02, Lots: 600, Current Position: 0
# 2020-11-02: BUY EXECUTED, Price:198.02, Lot:600, Cash:56977.
# 2020-11-02: Sell CREATE, Code: 603501.SH, Price: 217.82, Lots:600, Current Position: 600
# 2020-11-02: BUY CREATE, Code: 603260.SH, Price: 30.78, Lots: 5200, Current Position: 0
# 2020-11-02: BUY CREATE, Code: 603986.SH, Price: 205.60, Lots: 700, Current Position: 0
# 2020-11-02: BUY CREATE, Code: 601658.SH, Price: 4.69, Lots: 57800, Current Position: 0
# 2020-11-02: BUY CREATE, Code: 000338.SZ, Price: 15.98, Lots: 10700, Current Position: 0
# 2020-11-02: BUY CREATE, Code: 600674.SH, Price: 10.01, Lots: 35300, Current Position: 0
# 2020-11-02: BUY CREATE, Code: 603160.SH, Price: 177.01, Lots: 800, Current Position: 0
# 2020-11-03: Order Margin
# 2020-11-03: Order Margin
# 2020-11-03: Order Margin
# 2020-11-03: Order Margin
# 2020-11-03: Order Margin
# 2020-11-03: SELL EXECUTED, Price:217.82, Lot:600, Cash:27613.
# 2020-11-03: BUY EXECUTED, Price:30.78, Lot:5200, Cash:27613.
# 2020-11-03: OPERATION PROFIT, GROSS 11880.00, NET 11880.00
# 2020-11-03: Sell CREATE, Code: 603260.SH, Price: 31.00, Lots:5200, Current Position: 5200
# 2020-11-03: BUY CREATE, Code: 600900.SH, Price: 20.00, Lots: 14900, Current Position: 0
# 2020-11-03: BUY CREATE, Code: 601985.SH, Price: 4.61, Lots: 65400, Current Position: 0
# 2020-11-03: BUY CREATE, Code: 600362.SH, Price: 16.10, Lots: 10200, Current Position: 0
# 2020-11-03: BUY CREATE, Code: 603993.SH, Price: 4.19, Lots: 53000, Current Position: 0
# 2020-11-03: BUY CREATE, Code: 002371.SZ, Price: 180.90, Lots: 600, Current Position: 0
# 2020-11-03: BUY CREATE, Code: 002456.SZ, Price: 16.09, Lots: 9800, Current Position: 0
# 2020-11-03: BUY CREATE, Code: 002508.SZ, Price: 38.00, Lots: 3900, Current Position: 0
# 2020-11-04: Order Margin
# 2020-11-04: Order Margin
# 2020-11-04: Order Margin
# 2020-11-04: Order Margin
# 2020-11-04: Order Margin
# 2020-11-04: Order Margin
# 2020-11-04: Order Margin
# 2020-11-04: SELL EXECUTED, Price:31.00, Lot:5200, Cash:188813.
# 2020-11-04: OPERATION PROFIT, GROSS 1144.00, NET 1144.00
# 2020-11-04: BUY CREATE, Code: 600535.SH, Price: 17.85, Lots: 11200, Current Position: 0
# 2020-11-05: Order Margin
# 2020-11-05: BUY CREATE, Code: 600886.SH, Price: 9.38, Lots: 24100, Current Position: 0
# 2020-11-05: BUY CREATE, Code: 600183.SH, Price: 26.39, Lots: 5700, Current Position: 0
# 2020-11-05: BUY CREATE, Code: 601117.SH, Price: 5.66, Lots: 50300, Current Position: 0
# 2020-11-05: BUY CREATE, Code: 000002.SZ, Price: 29.25, Lots: 8100, Current Position: 0
# 2020-11-05: BUY CREATE, Code: 603392.SH, Price: 197.50, Lots: 500, Current Position: 0
# 2020-11-05: BUY CREATE, Code: 002081.SZ, Price: 10.53, Lots: 14400, Current Position: 0
# 2020-11-05: BUY CREATE, Code: 600584.SH, Price: 38.76, Lots: 3700, Current Position: 0
# 2020-11-05: BUY CREATE, Code: 603288.SH, Price: 168.65, Lots: 900, Current Position: 0
# 2020-11-05: BUY CREATE, Code: 600219.SH, Price: 2.44, Lots: 93300, Current Position: 0
# 2020-11-05: BUY CREATE, Code: 002736.SZ, Price: 14.07, Lots: 13900, Current Position: 0
# 2020-11-05: BUY CREATE, Code: 600297.SH, Price: 3.84, Lots: 20400, Current Position: 0
# 2020-11-06: Order Margin
# 2020-11-06: Order Margin
# 2020-11-06: Order Margin
# 2020-11-06: Order Margin
# 2020-11-06: Order Margin
# 2020-11-06: Order Margin
# 2020-11-06: Order Margin
# 2020-11-06: Order Margin
# 2020-11-06: Order Margin
# 2020-11-06: Order Margin
# 2020-11-06: Order Margin
# 2020-11-06: BUY CREATE, Code: 002466.SZ, Price: 23.94, Lots: 3900, Current Position: 0
# 2020-11-06: BUY CREATE, Code: 000725.SZ, Price: 5.24, Lots: 29400, Current Position: 0
# 2020-11-06: BUY CREATE, Code: 600028.SH, Price: 3.98, Lots: 134600, Current Position: 0
# 2020-11-09: Order Margin
# 2020-11-09: Order Margin
# 2020-11-09: BUY EXECUTED, Price:23.94, Lot:3900, Cash:95447.
# 2020-11-09: Sell CREATE, Code: 002466.SZ, Price: 26.33, Lots:3900, Current Position: 3900
# 2020-11-09: BUY CREATE, Code: 000776.SZ, Price: 17.67, Lots: 11100, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 600522.SH, Price: 11.31, Lots: 12800, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 601377.SH, Price: 8.81, Lots: 18300, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 600848.SH, Price: 23.75, Lots: 7100, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 002414.SZ, Price: 37.74, Lots: 3700, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 601600.SH, Price: 3.29, Lots: 65400, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 601898.SH, Price: 4.16, Lots: 67900, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 600663.SH, Price: 12.47, Lots: 16200, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 600018.SH, Price: 4.89, Lots: 43400, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 000100.SZ, Price: 6.80, Lots: 20900, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 000423.SZ, Price: 41.82, Lots: 3400, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 600498.SH, Price: 26.32, Lots: 7100, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 600516.SH, Price: 6.53, Lots: 37400, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 600958.SH, Price: 11.75, Lots: 14300, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 000063.SZ, Price: 38.07, Lots: 3300, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 601877.SH, Price: 32.20, Lots: 3700, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 000630.SZ, Price: 2.35, Lots: 107600, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 000783.SZ, Price: 8.47, Lots: 18200, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 300059.SZ, Price: 26.92, Lots: 5400, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 601138.SH, Price: 14.40, Lots: 13700, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 600519.SH, Price: 1742.57, Lots: 100, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 002384.SZ, Price: 29.34, Lots: 4600, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 601211.SH, Price: 19.11, Lots: 11100, Current Position: 0
# 2020-11-09: BUY CREATE, Code: 601298.SH, Price: 6.37, Lots: 45100, Current Position: 0
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: Order Margin
# 2020-11-10: SELL EXECUTED, Price:26.33, Lot:3900, Cash:1996.
# 2020-11-10: BUY EXECUTED, Price:17.67, Lot:11100, Cash:1996.
# 2020-11-10: OPERATION PROFIT, GROSS 9321.00, NET 9321.00
# 2020-11-10: BUY CREATE, Code: 601018.SH, Price: 3.98, Lots: 53800, Current Position: 0
# 2020-11-10: BUY CREATE, Code: 000596.SZ, Price: 235.95, Lots: 400, Current Position: 0
# 2020-11-10: BUY CREATE, Code: 601398.SH, Price: 5.02, Lots: 99900, Current Position: 0
# 2020-11-10: BUY CREATE, Code: 601288.SH, Price: 3.21, Lots: 179400, Current Position: 0
# 2020-11-10: BUY CREATE, Code: 002463.SZ, Price: 20.37, Lots: 6700, Current Position: 0
# 2020-11-10: BUY CREATE, Code: 600025.SH, Price: 4.20, Lots: 83300, Current Position: 0
# 2020-11-10: BUY CREATE, Code: 600176.SH, Price: 16.42, Lots: 7500, Current Position: 0
# 2020-11-10: BUY CREATE, Code: 000708.SZ, Price: 18.35, Lots: 8900, Current Position: 0
# 2020-11-11: Order Margin
# 2020-11-11: Order Margin
# 2020-11-11: Order Margin
# 2020-11-11: Order Margin
# 2020-11-11: Order Margin
# 2020-11-11: Order Margin
# 2020-11-11: Order Margin
# 2020-11-11: Order Margin
# 2020-11-11: BUY CREATE, Code: 601155.SH, Price: 35.31, Lots: 4800, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 601111.SH, Price: 7.66, Lots: 22200, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 601669.SH, Price: 4.07, Lots: 44300, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 601800.SH, Price: 7.95, Lots: 29500, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 002739.SZ, Price: 17.86, Lots: 6800, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 600196.SH, Price: 56.80, Lots: 1500, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 600009.SH, Price: 74.10, Lots: 2100, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 601021.SH, Price: 46.10, Lots: 2900, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 000069.SZ, Price: 7.09, Lots: 33600, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 002001.SZ, Price: 30.92, Lots: 5700, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 601006.SH, Price: 6.52, Lots: 73600, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 601857.SH, Price: 4.27, Lots: 95800, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 600111.SH, Price: 11.61, Lots: 12600, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 600655.SH, Price: 9.33, Lots: 20800, Current Position: 0
# 2020-11-11: BUY CREATE, Code: 601390.SH, Price: 5.68, Lots: 48200, Current Position: 0
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: Order Margin
# 2020-11-12: BUY CREATE, Code: 000671.SZ, Price: 7.39, Lots: 26800, Current Position: 0
# 2020-11-12: BUY CREATE, Code: 600015.SH, Price: 6.30, Lots: 55500, Current Position: 0
# 2020-11-12: BUY CREATE, Code: 600010.SH, Price: 1.17, Lots: 218700, Current Position: 0
# 2020-11-12: BUY CREATE, Code: 600795.SH, Price: 2.07, Lots: 162700, Current Position: 0
# 2020-11-12: BUY CREATE, Code: 603156.SH, Price: 26.26, Lots: 6400, Current Position: 0
# 2020-11-12: BUY CREATE, Code: 300144.SZ, Price: 17.87, Lots: 7100, Current Position: 0
# 2020-11-13: Order Margin
# 2020-11-13: Order Margin
# 2020-11-13: Order Margin
# 2020-11-13: Order Margin
# 2020-11-13: Order Margin
# 2020-11-13: Order Margin
# 2020-11-13: BUY CREATE, Code: 600029.SH, Price: 5.93, Lots: 26400, Current Position: 0
# 2020-11-13: BUY CREATE, Code: 000629.SZ, Price: 2.37, Lots: 72900, Current Position: 0
# 2020-11-13: BUY CREATE, Code: 601212.SH, Price: 2.85, Lots: 64200, Current Position: 0
# 2020-11-13: BUY CREATE, Code: 600968.SH, Price: 2.42, Lots: 99900, Current Position: 0
# 2020-11-13: BUY CREATE, Code: 600004.SH, Price: 14.38, Lots: 10300, Current Position: 0
# 2020-11-13: BUY CREATE, Code: 600703.SH, Price: 25.79, Lots: 5500, Current Position: 0
# 2020-11-13: BUY CREATE, Code: 000709.SZ, Price: 2.17, Lots: 125000, Current Position: 0
# 2020-11-16: Order Margin
# 2020-11-16: Order Margin
# 2020-11-16: Order Margin
# 2020-11-16: Order Margin
# 2020-11-16: Order Margin
# 2020-11-16: Order Margin
# 2020-11-16: Order Margin
# 2020-11-16: BUY CREATE, Code: 600188.SH, Price: 9.82, Lots: 22200, Current Position: 0
# 2020-11-16: BUY CREATE, Code: 600989.SH, Price: 11.02, Lots: 12300, Current Position: 0
# 2020-11-16: BUY CREATE, Code: 600352.SH, Price: 14.95, Lots: 13700, Current Position: 0
# 2020-11-16: BUY CREATE, Code: 600023.SH, Price: 3.78, Lots: 90900, Current Position: 0
# ...
# 2020-12-01: Order Margin
# 2020-12-01: Order Margin
# 2020-12-01: Order Margin
# 2020-12-01: Order Margin
# 2020-12-01: Order Margin
# 2020-12-01: Order Margin
# 2020-12-01: Order Margin
# 2020-12-01: Order Margin
# 2020-12-01: BUY EXECUTED, Price:22.00, Lot:7300, Cash:38319.
# 2020-12-01: Sell CREATE, Code: 600999.SH, Price: 24.01, Lots:7300, Current Position: 7300
# 2020-12-01: Sell CREATE, Code: 601788.SH, Price: 19.93, Lots:6700, Current Position: 6700
# 2020-12-01: BUY CREATE, Code: 002939.SZ, Price: 13.37, Lots: 17400, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 601916.SH, Price: 4.28, Lots: 76000, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 000627.SZ, Price: 5.34, Lots: 42100, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 002384.SZ, Price: 27.65, Lots: 5700, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 600928.SH, Price: 5.95, Lots: 37600, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 600016.SH, Price: 5.41, Lots: 63000, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 002673.SZ, Price: 9.83, Lots: 25900, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 002736.SZ, Price: 14.05, Lots: 18800, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 600050.SH, Price: 4.95, Lots: 76900, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 002958.SZ, Price: 5.39, Lots: 31300, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 600919.SH, Price: 6.43, Lots: 45100, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 601816.SH, Price: 5.86, Lots: 56900, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 601696.SH, Price: 27.18, Lots: 4100, Current Position: 0
# 2020-12-01: BUY CREATE, Code: 600061.SH, Price: 15.35, Lots: 11700, Current Position: 0
# 2020-12-02: Order Margin
# 2020-12-02: Order Margin
# 2020-12-02: Order Margin
# 2020-12-02: Order Margin
# 2020-12-02: Order Margin
# 2020-12-02: Order Margin
# 2020-12-02: Order Margin
# 2020-12-02: Order Margin
# 2020-12-02: Order Margin
# 2020-12-02: Order Margin
# 2020-12-02: Order Margin
# 2020-12-02: Order Margin
# 2020-12-02: Order Margin
# 2020-12-02: SELL EXECUTED, Price:24.01, Lot:7300, Cash:114485.
# 2020-12-02: SELL EXECUTED, Price:19.93, Lot:6700, Cash:114485.
# 2020-12-02: BUY EXECUTED, Price:13.37, Lot:17400, Cash:114485.
# 2020-12-02: OPERATION PROFIT, GROSS 14673.00, NET 14673.00
# 2020-12-02: OPERATION PROFIT, GROSS -18425.00, NET -18425.00
# 2020-12-02: BUY CREATE, Code: 688009.SH, Price: 6.23, Lots: 71400, Current Position: 0
# 2020-12-02: BUY CREATE, Code: 300070.SZ, Price: 8.69, Lots: 23300, Current Position: 0
# 2020-12-02: BUY CREATE, Code: 601555.SH, Price: 10.37, Lots: 21200, Current Position: 0
# 2020-12-02: BUY CREATE, Code: 600606.SH, Price: 6.64, Lots: 29500, Current Position: 0
# 2020-12-02: BUY CREATE, Code: 600340.SH, Price: 14.95, Lots: 13700, Current Position: 0
# 2020-12-02: BUY CREATE, Code: 601108.SH, Price: 13.65, Lots: 14100, Current Position: 0
# 2020-12-02: BUY CREATE, Code: 002938.SZ, Price: 55.68, Lots: 2200, Current Position: 0
# 2020-12-02: BUY CREATE, Code: 000425.SZ, Price: 5.93, Lots: 27200, Current Position: 0
# 2020-12-02: BUY CREATE, Code: 601229.SH, Price: 8.17, Lots: 41900, Current Position: 0
# 2020-12-02: BUY CREATE, Code: 600522.SH, Price: 11.08, Lots: 22500, Current Position: 0
# 2020-12-03: Order Margin
# 2020-12-03: Order Margin
# 2020-12-03: Order Margin
# 2020-12-03: Order Margin
# 2020-12-03: Order Margin
# 2020-12-03: Order Margin
# 2020-12-03: Order Margin
# 2020-12-03: Order Margin
# 2020-12-03: Order Margin
# 2020-12-03: Order Margin
# 2020-12-03: Sell CREATE, Code: 601231.SH, Price: 22.58, Lots:4500, Current Position: 4500
# 2020-12-03: BUY CREATE, Code: 000661.SZ, Price: 386.99, Lots: 300, Current Position: 0
# 2020-12-03: BUY CREATE, Code: 600170.SH, Price: 3.08, Lots: 139900, Current Position: 0
# 2020-12-03: BUY CREATE, Code: 601162.SH, Price: 6.57, Lots: 25700, Current Position: 0
# 2020-12-03: BUY CREATE, Code: 600637.SH, Price: 9.75, Lots: 39100, Current Position: 0
# 2020-12-03: BUY CREATE, Code: 003816.SZ, Price: 2.80, Lots: 114700, Current Position: 0
# 2020-12-03: BUY CREATE, Code: 600332.SH, Price: 31.36, Lots: 12300, Current Position: 0
# 2020-12-03: BUY CREATE, Code: 688008.SH, Price: 79.88, Lots: 1800, Current Position: 0
# 2020-12-03: BUY CREATE, Code: 601336.SH, Price: 63.99, Lots: 2400, Current Position: 0
# 2020-12-03: BUY CREATE, Code: 603288.SH, Price: 171.55, Lots: 1300, Current Position: 0
# 2020-12-03: BUY CREATE, Code: 002812.SZ, Price: 103.13, Lots: 1200, Current Position: 0
# 2020-12-04: Order Margin
# 2020-12-04: Order Margin
# 2020-12-04: Order Margin
# 2020-12-04: Order Margin
# 2020-12-04: Order Margin
# 2020-12-04: Order Margin
# 2020-12-04: Order Margin
# 2020-12-04: Order Margin
# 2020-12-04: Order Margin
# 2020-12-04: SELL EXECUTED, Price:22.58, Lot:4500, Cash:99998.
# 2020-12-04: BUY EXECUTED, Price:386.99, Lot:300, Cash:99998.
# 2020-12-04: OPERATION PROFIT, GROSS -10935.00, NET -10935.00
# 2020-12-04: Sell CREATE, Code: 000661.SZ, Price: 390.40, Lots:300, Current Position: 300
# 2020-12-04: BUY CREATE, Code: 002773.SZ, Price: 44.49, Lots: 3300, Current Position: 0
# 2020-12-04: BUY CREATE, Code: 601990.SH, Price: 13.15, Lots: 15100, Current Position: 0
# 2020-12-04: BUY CREATE, Code: 601077.SH, Price: 4.71, Lots: 52600, Current Position: 0
# 2020-12-04: BUY CREATE, Code: 600763.SH, Price: 233.60, Lots: 500, Current Position: 0
# 2020-12-04: BUY CREATE, Code: 002129.SZ, Price: 24.18, Lots: 5300, Current Position: 0
# 2020-12-04: BUY CREATE, Code: 300347.SZ, Price: 130.00, Lots: 900, Current Position: 0
# 2020-12-07: Order Margin
# 2020-12-07: Order Margin
# 2020-12-07: Order Margin
# 2020-12-07: Order Margin
# 2020-12-07: Order Margin
# 2020-12-07: SELL EXECUTED, Price:390.40, Lot:300, Cash:70301.
# 2020-12-07: BUY EXECUTED, Price:44.49, Lot:3300, Cash:70301.
# 2020-12-07: OPERATION PROFIT, GROSS 1023.00, NET 1023.00
# 2020-12-07: BUY CREATE, Code: 601888.SH, Price: 207.75, Lots: 600, Current Position: 0
# 2020-12-07: BUY CREATE, Code: 600655.SH, Price: 9.17, Lots: 29600, Current Position: 0
# 2020-12-07: BUY CREATE, Code: 600276.SH, Price: 89.88, Lots: 2800, Current Position: 0
# 2020-12-07: BUY CREATE, Code: 600588.SH, Price: 45.98, Lots: 2700, Current Position: 0
# 2020-12-07: BUY CREATE, Code: 600872.SH, Price: 70.41, Lots: 2000, Current Position: 0
# 2020-12-07: BUY CREATE, Code: 300498.SZ, Price: 19.99, Lots: 10900, Current Position: 0
# 2020-12-07: BUY CREATE, Code: 000596.SZ, Price: 228.91, Lots: 700, Current Position: 0
# 2020-12-08: Order Margin
# 2020-12-08: Order Margin
# 2020-12-08: Order Margin
# 2020-12-08: Order Margin
# 2020-12-08: Order Margin
# 2020-12-08: Order Margin
# 2020-12-08: Order Margin
# 2020-12-08: BUY CREATE, Code: 600887.SH, Price: 40.68, Lots: 5500, Current Position: 0
# 2020-12-08: BUY CREATE, Code: 603369.SH, Price: 51.80, Lots: 2700, Current Position: 0
# 2020-12-08: BUY CREATE, Code: 601012.SH, Price: 72.54, Lots: 2100, Current Position: 0
# 2020-12-08: BUY CREATE, Code: 600570.SH, Price: 98.15, Lots: 1700, Current Position: 0
# 2020-12-08: BUY CREATE, Code: 002049.SZ, Price: 111.30, Lots: 1100, Current Position: 0
# 2020-12-09: Order Margin
# 2020-12-09: Order Margin
# 2020-12-09: Order Margin
# 2020-12-09: Order Margin
# 2020-12-09: Order Margin
# 2020-12-09: BUY CREATE, Code: 600196.SH, Price: 55.07, Lots: 2700, Current Position: 0
# 2020-12-09: BUY CREATE, Code: 603899.SH, Price: 79.12, Lots: 1900, Current Position: 0
# 2020-12-09: BUY CREATE, Code: 600436.SH, Price: 238.57, Lots: 700, Current Position: 0
# 2020-12-10: Order Margin
# 2020-12-10: Order Margin
# 2020-12-10: Order Margin
# 2020-12-10: BUY CREATE, Code: 300433.SZ, Price: 33.10, Lots: 4600, Current Position: 0
# 2020-12-10: BUY CREATE, Code: 000538.SZ, Price: 103.53, Lots: 2100, Current Position: 0
# 2020-12-10: BUY CREATE, Code: 002821.SZ, Price: 277.53, Lots: 400, Current Position: 0
# 2020-12-11: Order Margin
# 2020-12-11: Order Margin
# 2020-12-11: Order Margin
# 2020-12-11: BUY CREATE, Code: 002311.SZ, Price: 59.66, Lots: 2400, Current Position: 0
# 2020-12-11: BUY CREATE, Code: 603392.SH, Price: 193.32, Lots: 600, Current Position: 0
# 2020-12-11: BUY CREATE, Code: 600170.SH, Price: 3.10, Lots: 137200, Current Position: 0
# 2020-12-11: BUY CREATE, Code: 300122.SZ, Price: 138.50, Lots: 700, Current Position: 0
# 2020-12-14: Order Margin
# 2020-12-14: Order Margin
# 2020-12-14: Order Margin
# 2020-12-14: Order Margin
# 2020-12-14: BUY CREATE, Code: 603259.SH, Price: 113.20, Lots: 1400, Current Position: 0
# 2020-12-14: BUY CREATE, Code: 002415.SZ, Price: 45.85, Lots: 3200, Current Position: 0
# 2020-12-14: BUY CREATE, Code: 688012.SH, Price: 165.45, Lots: 800, Current Position: 0
# 2020-12-15: Order Margin
# 2020-12-15: Order Margin
# 2020-12-15: Order Margin
# 2020-12-15: BUY CREATE, Code: 600438.SH, Price: 31.78, Lots: 3400, Current Position: 0
# 2020-12-15: BUY CREATE, Code: 600660.SH, Price: 39.87, Lots: 3600, Current Position: 0
# 2020-12-16: Order Margin
# 2020-12-16: Order Margin
# 2020-12-16: BUY CREATE, Code: 300529.SZ, Price: 72.30, Lots: 2100, Current Position: 0
# 2020-12-16: BUY CREATE, Code: 000963.SZ, Price: 29.27, Lots: 5900, Current Position: 0
# 2020-12-17: Order Margin
# 2020-12-17: Order Margin
# 2020-12-17: BUY CREATE, Code: 000066.SZ, Price: 16.20, Lots: 8500, Current Position: 0
# 2020-12-17: BUY CREATE, Code: 600406.SH, Price: 23.48, Lots: 8100, Current Position: 0
# 2020-12-17: BUY CREATE, Code: 600089.SH, Price: 8.96, Lots: 17300, Current Position: 0
# 2020-12-17: BUY CREATE, Code: 600588.SH, Price: 44.72, Lots: 3200, Current Position: 0
# 2020-12-17: BUY CREATE, Code: 002916.SZ, Price: 116.80, Lots: 1300, Current Position: 0
# 2020-12-17: BUY CREATE, Code: 601898.SH, Price: 4.32, Lots: 31100, Current Position: 0
# 2020-12-17: BUY CREATE, Code: 600309.SH, Price: 85.95, Lots: 1900, Current Position: 0
# 2020-12-17: BUY CREATE, Code: 600795.SH, Price: 2.17, Lots: 109300, Current Position: 0
# 2020-12-17: BUY CREATE, Code: 600845.SH, Price: 63.10, Lots: 2300, Current Position: 0
# 2020-12-17: BUY CREATE, Code: 600029.SH, Price: 6.17, Lots: 26600, Current Position: 0
# 2020-12-17: BUY CREATE, Code: 603087.SH, Price: 124.48, Lots: 1200, Current Position: 0
# 2020-12-18: Order Margin
# 2020-12-18: Order Margin
# 2020-12-18: Order Margin
# 2020-12-18: Order Margin
# 2020-12-18: Order Margin
# 2020-12-18: Order Margin
# 2020-12-18: Order Margin
# 2020-12-18: Order Margin
# 2020-12-18: Order Margin
# 2020-12-18: Order Margin
# 2020-12-18: Order Margin
# 2020-12-18: BUY CREATE, Code: 000709.SZ, Price: 2.30, Lots: 95800, Current Position: 0
# 2020-12-18: BUY CREATE, Code: 600038.SH, Price: 56.30, Lots: 2800, Current Position: 0
# 2020-12-18: BUY CREATE, Code: 600019.SH, Price: 6.23, Lots: 22600, Current Position: 0
# 2020-12-18: BUY CREATE, Code: 300601.SZ, Price: 166.00, Lots: 500, Current Position: 0
# 2020-12-18: BUY CREATE, Code: 002410.SZ, Price: 72.00, Lots: 1900, Current Position: 0
# 2020-12-18: BUY CREATE, Code: 600219.SH, Price: 2.81, Lots: 53000, Current Position: 0
# 2020-12-18: BUY CREATE, Code: 600372.SH, Price: 17.25, Lots: 8600, Current Position: 0
# 2020-12-18: BUY CREATE, Code: 002607.SZ, Price: 38.92, Lots: 3600, Current Position: 0
# 2020-12-18: BUY CREATE, Code: 000630.SZ, Price: 2.57, Lots: 52200, Current Position: 0
# 2020-12-21: Order Margin
# 2020-12-21: Order Margin
# 2020-12-21: Order Margin
# 2020-12-21: Order Margin
# 2020-12-21: Order Margin
# 2020-12-21: Order Margin
# 2020-12-21: Order Margin
# 2020-12-21: Order Margin
# 2020-12-21: Order Margin
# 2020-12-21: BUY CREATE, Code: 002032.SZ, Price: 74.55, Lots: 2600, Current Position: 0
# 2020-12-21: BUY CREATE, Code: 600516.SH, Price: 6.82, Lots: 21500, Current Position: 0
# 2020-12-21: BUY CREATE, Code: 601618.SH, Price: 2.89, Lots: 66600, Current Position: 0
# 2020-12-21: BUY CREATE, Code: 601298.SH, Price: 6.19, Lots: 48600, Current Position: 0
# 2020-12-22: Order Margin
# 2020-12-22: Order Margin
# 2020-12-22: Order Margin
# 2020-12-22: Order Margin
# 2020-12-22: BUY CREATE, Code: 002352.SZ, Price: 86.50, Lots: 1800, Current Position: 0
# 2020-12-22: BUY CREATE, Code: 000725.SZ, Price: 5.34, Lots: 28400, Current Position: 0
# 2020-12-23: Order Margin
# 2020-12-23: Order Margin
# 2020-12-23: BUY CREATE, Code: 002008.SZ, Price: 41.10, Lots: 3200, Current Position: 0
# 2020-12-24: Order Margin
# 2020-12-24: Sell CREATE, Code: 002773.SZ, Price: 44.12, Lots:3300, Current Position: 3300
# 2020-12-24: BUY CREATE, Code: 600690.SH, Price: 28.40, Lots: 5100, Current Position: 0
# 2020-12-24: BUY CREATE, Code: 601212.SH, Price: 2.91, Lots: 48900, Current Position: 0
# 2020-12-24: BUY CREATE, Code: 002475.SZ, Price: 55.73, Lots: 2600, Current Position: 0
# 2020-12-25: Order Margin
# 2020-12-25: Order Margin
# 2020-12-25: SELL EXECUTED, Price:44.12, Lot:3300, Cash:71056.
# 2020-12-25: BUY EXECUTED, Price:28.40, Lot:5100, Cash:71056.
# 2020-12-25: OPERATION PROFIT, GROSS -1221.00, NET -1221.00
# 2020-12-25: Sell CREATE, Code: 600690.SH, Price: 28.43, Lots:5100, Current Position: 5100
# 2020-12-25: BUY CREATE, Code: 000630.SZ, Price: 2.60, Lots: 51400, Current Position: 0
# 2020-12-25: BUY CREATE, Code: 002773.SZ, Price: 44.79, Lots: 3200, Current Position: 0
# 2020-12-25: BUY CREATE, Code: 000723.SZ, Price: 7.10, Lots: 14700, Current Position: 0
# 2020-12-25: BUY CREATE, Code: 002050.SZ, Price: 25.05, Lots: 4600, Current Position: 0
# 2020-12-25: BUY CREATE, Code: 600111.SH, Price: 13.26, Lots: 7600, Current Position: 0
# 2020-12-25: BUY CREATE, Code: 003816.SZ, Price: 2.86, Lots: 81300, Current Position: 0
# 2020-12-25: BUY CREATE, Code: 300628.SZ, Price: 72.68, Lots: 1500, Current Position: 0
# 2020-12-28: Order Margin
# 2020-12-28: Order Margin
# 2020-12-28: Order Margin
# 2020-12-28: Order Margin
# 2020-12-28: Order Margin
# 2020-12-28: Order Margin
# 2020-12-28: SELL EXECUTED, Price:28.43, Lot:5100, Cash:82409.
# 2020-12-28: BUY EXECUTED, Price:2.60, Lot:51400, Cash:82409.
# 2020-12-28: OPERATION PROFIT, GROSS 153.00, NET 153.00
# 2020-12-28: Sell CREATE, Code: 000630.SZ, Price: 2.60, Lots:51400, Current Position: 51400
# 2020-12-28: BUY CREATE, Code: 002714.SZ, Price: 77.50, Lots: 2100, Current Position: 0
# 2020-12-28: BUY CREATE, Code: 002673.SZ, Price: 9.73, Lots: 18100, Current Position: 0
# 2020-12-29: Order Margin
# 2020-12-29: SELL EXECUTED, Price:2.60, Lot:51400, Cash:53299.
# 2020-12-29: BUY EXECUTED, Price:77.50, Lot:2100, Cash:53299.
# 2020-12-29: OPERATION PROFIT, GROSS 0.00, NET 0.00
# 2020-12-29: Sell CREATE, Code: 002714.SZ, Price: 76.45, Lots:2100, Current Position: 2100
# 2020-12-29: BUY CREATE, Code: 002371.SZ, Price: 175.77, Lots: 600, Current Position: 0
# 2020-12-29: BUY CREATE, Code: 002271.SZ, Price: 38.62, Lots: 3800, Current Position: 0
# 2020-12-29: BUY CREATE, Code: 000001.SZ, Price: 19.17, Lots: 8400, Current Position: 0
# 2020-12-30: Order Margin
# 2020-12-30: Order Margin
# 2020-12-30: SELL EXECUTED, Price:76.45, Lot:2100, Cash:108382.
# 2020-12-30: BUY EXECUTED, Price:175.77, Lot:600, Cash:108382.
# 2020-12-30: OPERATION PROFIT, GROSS -2205.00, NET -2205.00
# 2020-12-30: BUY CREATE, Code: 601236.SH, Price: 18.18, Lots: 5900, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600018.SH, Price: 4.60, Lots: 46900, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 002624.SZ, Price: 29.51, Lots: 3800, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600183.SH, Price: 28.09, Lots: 4700, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 002008.SZ, Price: 42.66, Lots: 2800, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 600482.SH, Price: 17.43, Lots: 11600, Current Position: 0
# 2020-12-30: BUY CREATE, Code: 002555.SZ, Price: 31.04, Lots: 3400, Current Position: 0
# 2020-12-31: Order Margin
# 2020-12-31: Order Margin
# 2020-12-31: Order Margin
# 2020-12-31: Order Margin
# 2020-12-31: Order Margin
# 2020-12-31: Order Margin
# 2020-12-31: BUY EXECUTED, Price:18.18, Lot:5900, Cash:1120.
# 2020-12-31: Sell CREATE, Code: 002371.SZ, Price: 180.74, Lots:600, Current Position: 600
# 2020-12-31: Sell CREATE, Code: 601236.SH, Price: 18.59, Lots:5900, Current Position: 5900
# 2020-12-31: BUY CREATE, Code: 601901.SH, Price: 10.37, Lots: 14700, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 300413.SZ, Price: 72.50, Lots: 1600, Current Position: 0
# 2020-12-31: BUY CREATE, Code: 601696.SH, Price: 27.68, Lots: 3900, Current Position: 0
# 2020-12-31: Ending Position:1. Ending Value:501528.00.
# Net Profit: 0.31%
