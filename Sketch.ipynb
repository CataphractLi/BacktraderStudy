# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('.\\Data\\stockuniverse_w(1).csv')
stk_dict = {}
for idx, row in df.iterrows():
    if row.SEC_CODE not in stk_dict.keys():
        stk_dict[row.SEC_CODE] = []
    stk_dict[row.SEC_CODE].append(row[0])

# %%
sorted(stk_dict.items(), key=lambda x: len(x[1]), reverse=True)
# Out:
# [('300059.SZ',
#   [20180323,
#    20180330,
#    20180404,
#    20180413,
#    20180420,
#    20180427,
#    20180504,
#    20180511,
#    20180518,
#    20180525,
#    20180601,
#    20180608,
#    20180615,
#    20180622,
#    20180629,
#    20180706,
#    20180713,
#    20180810,
#    20180817,
#    20180824,
#    20180831,
#    20180907,
#    20180914,
#    20180921,
#    20180928,
#    20181012,
#    20181019,
#    20181026,
#    20181102,
#    20181109,
#    20181116,
#    20181123,
#    20181130,
#    20181207,
#    20181214,
#    20181221,
#    20181228,
#    20190104,
#    20190111,
#    20190118,
#    20190719,
#    20190726,
#    20190802,
#    20190809,
#    20190816,
#    20190823,
#    20190830,
#    20190906,
#    20190912,
#    20190920,
#    20190927,
#    20190930,
#    20191011,
#    20191018,
#    20191025,
#    20191101,
#    20191108,
#    20191115,
#    20191122,
#    20191129,
#    20191206,
#    20191213,
#    20191220,
#    20191227,
#    20200103,
# ...

# %%
2**3
# Out:
# 8
