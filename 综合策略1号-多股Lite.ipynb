# %%
# 数据接口 
import akshare as ak
import baostock as bs
import tushare as ts

# 基础模块
import datetime
from itertools import product
import matplotlib.pyplot as plt
import multiprocessing
import numpy as np
import pandas as pd
import random
import time

# 回测框架
import backtrader as bt

# 基础函数
import utilsJ

# %% [markdown]
# # 策略

# %%
class Strategy_comp_lite(bt.Strategy):
    
    params = (
        # General params
        ('printlog', False),
        ('units', 300),
        ('p_stake', 100),

        # Indicator params
        ('bollinger_per', 20),
        ('bollinger_dev', 2),
        ('direction_lag', 5),
        ('wave_period_buy', 7),
        ('wave_period_sell', 7),

        # ATR params
        ('using_atr', False),
        ('atr_period', 14),
        ('atr_percent', 1),
    )

    
    def log(self, txt, dt=None, doprint=False):
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s: %s' % (dt.isoformat(), txt))
            #with open('log.txt', 'a') as file:
                #file.write('%s: %s \n' % (dt.isoformat(), txt))

    
    def __init__(self):

        # Record ATR Initial
        self.atr_initial = self.broker.get_cash()
        self.inds = dict()
        self.profit_i = dict()
        self.data_tracker = None
        self.money_unit = self.broker.get_cash() / self.params.units

        for d in self.datas:

            self.inds[d] = dict()
            self.profit_i[d._name] = 0

            # Keep references to lines in the data[0] dataseries
            self.inds[d]['dataclose'] = d.close
            self.inds[d]['datahigh'] = d.high
            self.inds[d]['datalow'] = d.low

            # Keep references to executed order & price
            self.inds[d]['buyprice'] = 0
            self.inds[d]['sellprice'] = 0
            self.inds[d]['order'] = None

            # Add indicators
            ## Bollinger Bands indicator
            self.inds[d]['bolling'] = bt.indicators.BollingerBands(d, 
                                                        period=self.params.bollinger_per, 
                                                        devfactor=self.params.bollinger_dev)
            self.inds[d]['direction'] = self.inds[d]['bolling'].mid(0) > self.inds[d]['bolling'].mid(-self.params.direction_lag)
            #self.inds[d]['bolling_buy'] = bt.Or(bt.And(self.inds[d]['dataclose'](0) > self.inds[d]['bolling'].top(0), 
            #                                           self.inds[d]['dataclose'](-1) < self.inds[d]['bolling'].top(-1)), 
            #                                    bt.And(self.inds[d]['dataclose'](0) > self.inds[d]['bolling'].bot(0), 
            #                                           self.inds[d]['dataclose'](-1) < self.inds[d]['bolling'].bot(-1)))
            self.inds[d]['bolling_buy'] = bt.And(self.inds[d]['dataclose'](0) > self.inds[d]['bolling'].mid(0), 
                                                 self.inds[d]['dataclose'](-1) < self.inds[d]['bolling'].mid(-1))

            self.inds[d]['bolling_sell'] = bt.Or(bt.And(self.inds[d]['dataclose'](0) < self.inds[d]['bolling'].top(0), 
                                                        self.inds[d]['dataclose'](-1) > self.inds[d]['bolling'].top(-1)), 
                                                 bt.And(self.inds[d]['dataclose'](0) < self.inds[d]['bolling'].bot(0), 
                                                        self.inds[d]['dataclose'](-1) > self.inds[d]['bolling'].bot(-1)))


            ## MovingAverageSimple indicator
            self.inds[d]['sma_buy'] = bt.indicators.SimpleMovingAverage(d, period=self.params.wave_period_buy)
            self.inds[d]['sma_sell'] = bt.indicators.SimpleMovingAverage(d, period=self.params.wave_period_sell)
            
            ## Wave indicator
            self.inds[d]['wave_buy'] = bt.And(self.inds[d]['sma_buy'](0) > self.inds[d]['sma_buy'](-1), 
                                              self.inds[d]['sma_buy'](-1) < self.inds[d]['sma_buy'](-2), 
                                              self.inds[d]['sma_buy'](-2) < self.inds[d]['sma_buy'](-3),
                                              self.inds[d]['sma_buy'](0) > self.inds[d]['bolling'].mid(0))
                                             

            self.inds[d]['wave_sell'] = bt.And(self.inds[d]['sma_sell'](0) < self.inds[d]['sma_sell'](-1), 
                                               self.inds[d]['sma_sell'](-1) > self.inds[d]['sma_sell'](-2), 
                                               self.inds[d]['sma_sell'](-2) > self.inds[d]['sma_sell'](-3))
        
            ## ATR indicator
            self.inds[d]['tr'] = bt.indicators.Max((self.inds[d]['datahigh'](0) - self.inds[d]['datalow'](0)), 
                                                    abs(self.inds[d]['dataclose'](-1) - self.inds[d]['datahigh'](0)),
                                                    abs(self.inds[d]['dataclose'](-1) - self.inds[d]['datalow'](0)))
            self.inds[d]['atr'] = bt.indicators.SimpleMovingAverage(self.inds[d]['tr'], period=self.params.atr_period)


    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                if self.inds[self.data_tracker]['wave_buy']:
                    self.inds[self.data_tracker]['buyprice']
                self.log('买单执行, 代码：%s, 价格:%.2f, 股数:%i, 持有现金:%i' %
                         (order.info['name'],
                          order.executed.price,
                          order.executed.size,
                          self.broker.get_cash()))
                self.profit_i[order.info['name']] -= order.executed.price*order.executed.size

            else:  # Sell
                self.inds[self.data_tracker]['sellprice'] = order.executed.price
                self.log('卖单执行, 代码：%s, 价格:%.2f, 股数:%i, 持有现金:%i' %
                        (order.info['name'],
                         order.executed.price,
                         -order.executed.size,
                         self.broker.get_cash()))
                self.profit_i[order.info['name']] -= order.executed.price*order.executed.size

        elif order.status in [order.Canceled]:
            self.log('订单取消：被撤销')

        elif order.status in [order.Margin]:
            self.log('订单取消：资金不足，代码：%s，持有资金:%i' %
                        (order.info['name'],
                         self.broker.get_cash()))

        elif order.status in [order.Rejected]:
            self.log('订单取消：被拒绝')

        # Write down: no pending order
        #self.order = None


    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('交易收益：代码：%s, 毛利润 %.2f, 净利润 %.2f' %
                 (trade.history[0]['event']['order'].info['name'], 
                  trade.pnl, trade.pnlcomm))
    

    def next(self):

        buy_list = []
        sell_list = []

        for d in self.datas:
        # Check if an order is pending ... if yes, we cannot send a 2nd one
            if self.inds[d]['order']:
                return

            buy_indicator = (self.inds[d]['wave_buy'] and self.inds[d]['dataclose'][0] > self.inds[d]['bolling'].mid[0]) or self.inds[d]['bolling_buy']
            sell_indicator = self.inds[d]['wave_sell'] or self.inds[d]['bolling_sell']

            if sell_indicator and self.getposition(d).size > 0:
                sell_list.append((d, -1))

            elif buy_indicator and self.getposition(d).size == 0 and self.inds[d]['direction']:
                if self.params.using_atr:
                    opt_pos = np.floor(self.atr_initial * self.params.atr_percent / self.params.p_stake / self.inds[d]['atr'][0])
                    if opt_pos*self.params.p_stake > 0 and self.getposition(d).size < opt_pos*self.params.p_stake:
                        buy_list.append((d, 
                                        opt_pos*self.params.p_stake-self.getposition(d).size, 
                                        (opt_pos*self.params.p_stake-self.getposition(d).size)*self.inds[d]['dataclose'][0]))
                else:
                    lots = np.floor(self.money_unit / (self.params.p_stake*self.inds[d]['dataclose'][0]))*self.params.p_stake
                    buy_list.append((d, lots, lots * self.inds[d]['dataclose'][0]))
        
        for s_order in sell_list:
            self.data_tracker = s_order[0]
            self.log('卖单创建, 代码: %s, 价格: %.2f, 股数:%i, 现有持仓: %i' % 
                        (s_order[0]._name, 
                        self.inds[s_order[0]]['dataclose'][0],
                        s_order[1] if s_order[1] != -1 else self.getposition(s_order[0]).size,
                        self.getposition(s_order[0]).size))
            self.sell(data=s_order[0], 
                        size=s_order[1] if s_order[1] != -1 else self.getposition(s_order[0]).size, 
                        name=s_order[0]._name)
        
        #buy_list = sorted(buy_list, key=lambda x: x[2], reverse=False)
        random.shuffle(buy_list)
        for b_order in buy_list:
            self.data_tracker = b_order[0]
            self.log('买单创建, 代码: %s, 价格: %.2f, 股数: %i, 现有持仓: %i' % 
                        (b_order[0]._name, 
                        self.inds[b_order[0]]['dataclose'][0], 
                        b_order[1],
                        self.getposition(b_order[0]).size))
            self.buy(data=b_order[0], size=b_order[1], name=b_order[0]._name)


    def stop(self):
        #for d in self.datas:
        #    if self.getposition(d).size > 0:
        #        self.profit_i[d._name] += self.getposition(d).size * d.close[0]
        #self.log('Ending Value:%.2f.' %
        #        (self.cerebro.broker.getvalue()), doprint=False)
        #print(sorted(self.profit_i.items(), key=lambda x: x[1]))
        #print(sum([x[1] for x in self.profit_i.items()]))
        return

# %% [markdown]
# # 全市场回测

# %% [markdown]
# ### 数据下载

# %%
s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 365 * 2)
e_date = datetime.date(2020, 12, 31)

#s_date = datetime.datetime.now() - datetime.timedelta(days = 365)
#e_date = datetime.datetime.now()

stock_index = '399300.SZ'

# Download Data
utilsJ.index_to_csv_tushare('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6',
                            stock_index, 0.2, s_date, e_date, fpath='.\\Data\\2019\\')

# %% [markdown]
# ### 循环回测

# %%
profit_dict = {}

# 904ff4752522814dca00e032a709fdfc26d8744913500ef204e02157
# 74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6

def getdata_mul(s_code, start=datetime.date(2020, 12, 31)-datetime.timedelta(days = 385),
                end = datetime.date(2020, 12, 31)):
    global cerebro
    df = pd.read_csv('.\\Data\\2019\\'+s_code+'.csv', 
                     converters={'trade_date':lambda x:pd.to_datetime(x)}).set_index('trade_date')
    data = bt.feeds.PandasData(dataname=df, fromdate=s_date, todate=e_date)
    cerebro.adddata(data, name=s_code)
    return

s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 385)
e_date = datetime.date(2020, 12, 31)



stock_index = '399300.SZ'
pro = ts.pro_api('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6')
index_list = np.unique(pro.index_weight(index_code=stock_index,
                                        start_date=s_date.strftime('%Y%m%d'),
                                        end_date=e_date.strftime('%Y%m%d')).con_code).tolist()


if __name__ == '__main__':
    for i in range(10):
        random.seed(10086)
        # Create a cerebro entity
        cerebro = bt.Cerebro(tradehistory=True)

        # Add a strategy
        strats = cerebro.addstrategy(Strategy_comp_lite, printlog=False, using_atr=True, atr_percent=0.01)

        t_list = [utilsJ.MyThread(getdata_mul, (s_code, s_date, e_date)) for s_code in index_list]
        [t.start() for t in t_list]
        [t.join() for t in t_list]
        #for s_code in index_list:
        #    df = pd.read_csv('.\\Data\\2020\\'+s_code+'.csv', 
        #                     converters={'trade_date':lambda x:pd.to_datetime(x)}).set_index('trade_date')
        #    data = bt.feeds.PandasData(dataname=df, fromdate=s_date, todate=e_date)

            # Add the index Data Feed to Cerebo
        #    cerebro.adddata(data, name=s_code)
        
        # Set cash inside the strategy
        cerebro.broker = bt.brokers.BackBroker(coc=True)   
        cerebro.broker.setcash(10000000)

        # Set commission
        #cerebro.broker.setcommission()

        # Print out the starting conditions
        start_value = cerebro.broker.getvalue()
        #print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

        # Run over everything
        cerebro.run(maxcpus=8)

        # Print out the final result
        final_value = cerebro.broker.getvalue()
        #print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
        #print('(%s, %s) Net Profit: %.2f%%' % (s[0], s[1], (final_value - start_value) / start_value * 100))
        print('Net Profit: %.2f%%' % ((final_value - start_value) / start_value * 100))

# %%
s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 405)
e_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 345)

stock_index = '399300.SZ'
pro = ts.pro_api('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6')
index_df = pro.index_weight(index_code=stock_index,
                                        start_date=s_date.strftime('%Y%m%d'),
                                        end_date=e_date.strftime('%Y%m%d'))

# %% [markdown]
# ### 单次验证

# %%
random.seed(10086)


if __name__ ==  '__main__':
    
    # Create a cerebro entity
    cerebro = bt.Cerebro(tradehistory=True)

    # Add a strategy
    strats = cerebro.addstrategy(Strategy_comp_lite, printlog=True, units=50)

    s_date = datetime.date(2020,12,31) - datetime.timedelta(days=385)
    e_date = datetime.date(2020,12,31)

    stock_index = '399300.SZ'
    pro = ts.pro_api('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6')
    index_list = np.unique(pro.index_weight(index_code=stock_index,
                                            start_date=s_date.strftime('%Y%m%d'),
                                            end_date=e_date.strftime('%Y%m%d')).con_code).tolist()

    for s_code in index_list[236:240]:
        df = pd.read_csv('.\\Data\\2019\\' + s_code + '.csv', converters={'trade_date':lambda x:pd.to_datetime(x)}).set_index('trade_date')
        data = bt.feeds.PandasData(dataname=df,fromdate=s_date,todate=e_date)

        # Add the index Data Feed to Cerebo
        cerebro.adddata(data, name=s_code)

    # Set cash inside the strategy
    cerebro.broker = bt.brokers.BackBroker(coc=True)
    cerebro.broker.setcash(5000 * 50 * 100)

    # Set commission
    #cerebro.broker.setcommission()

    # Print out the starting conditions
    start_value = cerebro.broker.getvalue()
    #print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run(runonce=False, exactbars=-1, maxcpus=16)

    # Print out the final result
    final_value = cerebro.broker.getvalue()
    #print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    print('Net Profit: %.2f%%' % ((final_value - start_value) / start_value * 100))
    #profit.append((final_value - start_value) / start_value * 100)
# Out:
# 2020-07-03: 买单创建, 代码: 600926.SH, 价格: 9.60, 股数: 52000, 现有持仓: 0
# 2020-07-03: 买单创建, 代码: 600928.SH, 价格: 5.91, 股数: 84600, 现有持仓: 0
# 2020-07-03: 买单创建, 代码: 600919.SH, 价格: 6.06, 股数: 82500, 现有持仓: 0
# 2020-07-03: 买单创建, 代码: 600918.SH, 价格: 15.68, 股数: 31800, 现有持仓: 0
# 2020-07-06: 买单执行, 代码：600926.SH, 价格:9.60, 股数:52000, 持有现金:23002240
# 2020-07-06: 买单执行, 代码：600928.SH, 价格:5.91, 股数:84600, 持有现金:23002240
# 2020-07-06: 买单执行, 代码：600919.SH, 价格:6.06, 股数:82500, 持有现金:23002240
# 2020-07-06: 买单执行, 代码：600918.SH, 价格:15.68, 股数:31800, 持有现金:23002240
# 2020-07-09: 卖单创建, 代码: 600919.SH, 价格: 6.67, 股数:82500, 现有持仓: 82500
# 2020-07-09: 卖单创建, 代码: 600926.SH, 价格: 10.33, 股数:52000, 现有持仓: 52000
# 2020-07-09: 卖单创建, 代码: 600928.SH, 价格: 6.25, 股数:84600, 现有持仓: 84600
# 2020-07-10: 卖单执行, 代码：600919.SH, 价格:6.67, 股数:82500, 持有现金:24618425
# 2020-07-10: 卖单执行, 代码：600926.SH, 价格:10.33, 股数:52000, 持有现金:24618425
# 2020-07-10: 卖单执行, 代码：600928.SH, 价格:6.25, 股数:84600, 持有现金:24618425
# 2020-07-10: 交易收益 代码：600919.SH, 毛利润 50325.00, 净利润 50325.00
# 2020-07-10: 交易收益 代码：600926.SH, 毛利润 37960.00, 净利润 37960.00
# 2020-07-10: 交易收益 代码：600928.SH, 毛利润 28764.00, 净利润 28764.00
# 2020-07-10: 卖单创建, 代码: 600918.SH, 价格: 19.72, 股数:31800, 现有持仓: 31800
# 2020-07-10: 买单创建, 代码: 600928.SH, 价格: 6.05, 股数: 82600, 现有持仓: 0
# 2020-07-10: 买单创建, 代码: 600926.SH, 价格: 9.80, 股数: 51000, 现有持仓: 0
# 2020-07-10: 买单创建, 代码: 600919.SH, 价格: 6.36, 股数: 78600, 现有持仓: 0
# 2020-07-13: 卖单执行, 代码：600918.SH, 价格:19.72, 股数:31800, 持有现金:23746095
# 2020-07-13: 买单执行, 代码：600928.SH, 价格:6.05, 股数:82600, 持有现金:23746095
# 2020-07-13: 买单执行, 代码：600926.SH, 价格:9.80, 股数:51000, 持有现金:23746095
# 2020-07-13: 买单执行, 代码：600919.SH, 价格:6.36, 股数:78600, 持有现金:23746095
# 2020-07-13: 交易收益 代码：600918.SH, 毛利润 128472.00, 净利润 128472.00
# 2020-07-13: 买单创建, 代码: 600918.SH, 价格: 19.99, 股数: 25000, 现有持仓: 0
# 2020-07-14: 买单执行, 代码：600918.SH, 价格:19.99, 股数:25000, 持有现金:23246345
# 2020-07-15: 卖单创建, 代码: 600919.SH, 价格: 6.22, 股数:78600, 现有持仓: 78600
# 2020-07-15: 卖单创建, 代码: 600926.SH, 价格: 9.69, 股数:51000, 现有持仓: 51000
# 2020-07-15: 卖单创建, 代码: 600928.SH, 价格: 5.91, 股数:82600, 现有持仓: 82600
# 2020-07-16: 卖单执行, 代码：600919.SH, 价格:6.22, 股数:78600, 持有现金:24717593
# 2020-07-16: 卖单执行, 代码：600926.SH, 价格:9.69, 股数:51000, 持有现金:24717593
# 2020-07-16: 卖单执行, 代码：600928.SH, 价格:5.91, 股数:82600, 持有现金:24717593
# 2020-07-16: 交易收益 代码：600919.SH, 毛利润 -11004.00, 净利润 -11004.00
# 2020-07-16: 交易收益 代码：600926.SH, 毛利润 -5610.00, 净利润 -5610.00
# 2020-07-16: 交易收益 代码：600928.SH, 毛利润 -11564.00, 净利润 -11564.00
# 2020-07-16: 买单创建, 代码: 600919.SH, 价格: 6.19, 股数: 80700, 现有持仓: 0
# 2020-07-16: 买单创建, 代码: 600928.SH, 价格: 5.84, 股数: 85600, 现有持仓: 0
# 2020-07-16: 买单创建, 代码: 600926.SH, 价格: 9.68, 股数: 51600, 现有持仓: 0
# 2020-07-17: 买单执行, 代码：600919.SH, 价格:6.19, 股数:80700, 持有现金:23218668
# 2020-07-17: 买单执行, 代码：600928.SH, 价格:5.84, 股数:85600, 持有现金:23218668
# 2020-09-11: 卖单执行, 代码：600919.SH, 价格:6.48, 股数:79300, 持有现金:24729116
# 2020-09-11: 买单执行, 代码：600926.SH, 价格:12.63, 股数:39500, 持有现金:24729116
# 2020-09-11: 交易收益 代码：600919.SH, 毛利润 14274.00, 净利润 14274.00
# 2020-09-15: 卖单创建, 代码: 600926.SH, 价格: 12.49, 股数:39500, 现有持仓: 39500
# 2020-09-16: 卖单执行, 代码：600926.SH, 价格:12.49, 股数:39500, 持有现金:25222471
# 2020-09-16: 交易收益 代码：600926.SH, 毛利润 -5530.00, 净利润 -5530.00
# 2020-09-16: 买单创建, 代码: 600919.SH, 价格: 6.49, 股数: 77000, 现有持仓: 0
# 2020-09-16: 买单创建, 代码: 600926.SH, 价格: 12.67, 股数: 39400, 现有持仓: 0
# 2020-09-17: 买单执行, 代码：600919.SH, 价格:6.49, 股数:77000, 持有现金:24223543
# 2020-09-17: 买单执行, 代码：600926.SH, 价格:12.67, 股数:39400, 持有现金:24223543
# 2020-09-18: 买单创建, 代码: 600918.SH, 价格: 15.52, 股数: 32200, 现有持仓: 0
# 2020-09-21: 买单执行, 代码：600918.SH, 价格:15.52, 股数:32200, 持有现金:23723799
# 2020-09-22: 卖单创建, 代码: 600926.SH, 价格: 12.45, 股数:39400, 现有持仓: 39400
# 2020-09-22: 买单创建, 代码: 600928.SH, 价格: 5.65, 股数: 88400, 现有持仓: 0
# 2020-09-23: 卖单执行, 代码：600926.SH, 价格:12.45, 股数:39400, 持有现金:23714869
# 2020-09-23: 买单执行, 代码：600928.SH, 价格:5.65, 股数:88400, 持有现金:23714869
# 2020-09-23: 交易收益 代码：600926.SH, 毛利润 -8668.00, 净利润 -8668.00
# 2020-09-24: 卖单创建, 代码: 600919.SH, 价格: 6.28, 股数:77000, 现有持仓: 77000
# 2020-09-25: 卖单执行, 代码：600919.SH, 价格:6.28, 股数:77000, 持有现金:24198429
# 2020-09-25: 交易收益 代码：600919.SH, 毛利润 -16170.00, 净利润 -16170.00
# 2020-09-29: 卖单创建, 代码: 600928.SH, 价格: 5.35, 股数:88400, 现有持仓: 88400
# 2020-09-30: 卖单执行, 代码：600928.SH, 价格:5.35, 股数:88400, 持有现金:24671369
# 2020-09-30: 交易收益 代码：600928.SH, 毛利润 -26520.00, 净利润 -26520.00
# 2020-10-12: 买单创建, 代码: 600928.SH, 价格: 5.53, 股数: 90400, 现有持仓: 0
# 2020-10-13: 买单执行, 代码：600928.SH, 价格:5.53, 股数:90400, 持有现金:24171457
# 2020-10-14: 卖单创建, 代码: 600918.SH, 价格: 15.19, 股数:32200, 现有持仓: 32200
# 2020-10-14: 买单创建, 代码: 600926.SH, 价格: 12.42, 股数: 40200, 现有持仓: 0
# 2020-10-15: 卖单执行, 代码：600918.SH, 价格:15.19, 股数:32200, 持有现金:24161291
# 2020-10-15: 买单执行, 代码：600926.SH, 价格:12.42, 股数:40200, 持有现金:24161291
# 2020-10-15: 交易收益 代码：600918.SH, 毛利润 -10626.00, 净利润 -10626.00
# 2020-10-15: 买单创建, 代码: 600918.SH, 价格: 15.22, 股数: 32800, 现有持仓: 0
# 2020-11-18: 买单创建, 代码: 600928.SH, 价格: 5.28, 股数: 94600, 现有持仓: 0
# 2020-11-19: 卖单执行, 代码：600918.SH, 价格:14.29, 股数:33500, 持有现金:23597664
# 2020-11-19: 买单执行, 代码：600919.SH, 价格:6.10, 股数:81900, 持有现金:23597664
# 2020-11-19: 买单执行, 代码：600928.SH, 价格:5.28, 股数:94600, 持有现金:23597664
# 2020-11-19: 交易收益 代码：600918.SH, 毛利润 -20435.00, 净利润 -20435.00
# 2020-11-19: 买单创建, 代码: 600918.SH, 价格: 14.27, 股数: 35000, 现有持仓: 0
# 2020-11-20: 买单执行, 代码：600918.SH, 价格:14.27, 股数:35000, 持有现金:23098214
# 2020-11-20: 卖单创建, 代码: 600919.SH, 价格: 6.07, 股数:81900, 现有持仓: 81900
# 2020-11-23: 卖单执行, 代码：600919.SH, 价格:6.07, 股数:81900, 持有现金:23595347
# 2020-11-23: 交易收益 代码：600919.SH, 毛利润 -2457.00, 净利润 -2457.00
# 2020-11-23: 买单创建, 代码: 600919.SH, 价格: 6.14, 股数: 81400, 现有持仓: 0
# 2020-11-24: 买单执行, 代码：600919.SH, 价格:6.14, 股数:81400, 持有现金:23095551
# 2020-11-24: 卖单创建, 代码: 600926.SH, 价格: 14.82, 股数:37100, 现有持仓: 37100
# 2020-11-25: 卖单执行, 代码：600926.SH, 价格:14.82, 股数:37100, 持有现金:23645373
# 2020-11-25: 交易收益 代码：600926.SH, 毛利润 50456.00, 净利润 50456.00
# 2020-11-25: 卖单创建, 代码: 600918.SH, 价格: 14.89, 股数:35000, 现有持仓: 35000
# 2020-11-25: 买单创建, 代码: 600926.SH, 价格: 14.58, 股数: 34200, 现有持仓: 0
# 2020-11-26: 卖单执行, 代码：600918.SH, 价格:14.89, 股数:35000, 持有现金:23667887
# 2020-11-26: 买单执行, 代码：600926.SH, 价格:14.58, 股数:34200, 持有现金:23667887
# 2020-11-26: 交易收益 代码：600918.SH, 毛利润 21700.00, 净利润 21700.00
# 2020-11-26: 买单创建, 代码: 600918.SH, 价格: 15.64, 股数: 31900, 现有持仓: 0
# 2020-11-27: 买单执行, 代码：600918.SH, 价格:15.64, 股数:31900, 持有现金:23168971
# 2020-12-02: 卖单创建, 代码: 600926.SH, 价格: 14.86, 股数:34200, 现有持仓: 34200
# 2020-12-03: 卖单执行, 代码：600926.SH, 价格:14.86, 股数:34200, 持有现金:23677183
# 2020-12-03: 交易收益 代码：600926.SH, 毛利润 9576.00, 净利润 9576.00
# 2020-12-03: 卖单创建, 代码: 600918.SH, 价格: 16.90, 股数:31900, 现有持仓: 31900
# 2020-12-03: 买单创建, 代码: 600926.SH, 价格: 14.64, 股数: 34100, 现有持仓: 0
# 2020-12-04: 卖单执行, 代码：600918.SH, 价格:16.90, 股数:31900, 持有现金:23717069
# 2020-12-04: 买单执行, 代码：600926.SH, 价格:14.64, 股数:34100, 持有现金:23717069
# 2020-12-04: 交易收益 代码：600918.SH, 毛利润 40194.00, 净利润 40194.00
# 2020-12-04: 卖单创建, 代码: 600919.SH, 价格: 6.25, 股数:81400, 现有持仓: 81400
# 2020-12-04: 卖单创建, 代码: 600928.SH, 价格: 5.85, 股数:94600, 现有持仓: 94600
# 2020-12-04: 买单创建, 代码: 600918.SH, 价格: 16.57, 股数: 30100, 现有持仓: 0
# 2020-12-07: 卖单执行, 代码：600919.SH, 价格:6.25, 股数:81400, 持有现金:24280472
# 2020-12-07: 卖单执行, 代码：600928.SH, 价格:5.85, 股数:94600, 持有现金:24280472
# 2020-12-07: 买单执行, 代码：600918.SH, 价格:16.57, 股数:30100, 持有现金:24280472
# 2020-12-07: 交易收益 代码：600919.SH, 毛利润 8954.00, 净利润 8954.00
# 2020-12-07: 交易收益 代码：600928.SH, 毛利润 53922.00, 净利润 53922.00
# 2020-12-07: 买单创建, 代码: 600928.SH, 价格: 5.76, 股数: 86800, 现有持仓: 0
# 2020-12-08: 买单执行, 代码：600928.SH, 价格:5.76, 股数:86800, 持有现金:23780504
# 2020-12-09: 卖单创建, 代码: 600918.SH, 价格: 15.50, 股数:30100, 现有持仓: 30100
# 2020-12-10: 卖单执行, 代码：600918.SH, 价格:15.50, 股数:30100, 持有现金:24247054
# 2020-12-10: 交易收益 代码：600918.SH, 毛利润 -32207.00, 净利润 -32207.00
# 2020-12-10: 卖单创建, 代码: 600928.SH, 价格: 5.53, 股数:86800, 现有持仓: 86800
# 2020-12-10: 买单创建, 代码: 600918.SH, 价格: 15.68, 股数: 31800, 现有持仓: 0
# 2020-12-11: 卖单执行, 代码：600928.SH, 价格:5.53, 股数:86800, 持有现金:24228434
# 2020-12-11: 买单执行, 代码：600918.SH, 价格:15.68, 股数:31800, 持有现金:24228434
# 2020-12-11: 交易收益 代码：600928.SH, 毛利润 -19964.00, 净利润 -19964.00
# 2020-12-11: 买单创建, 代码: 600928.SH, 价格: 5.61, 股数: 89100, 现有持仓: 0
# 2020-12-14: 买单执行, 代码：600928.SH, 价格:5.61, 股数:89100, 持有现金:23728583
# 2020-12-18: 卖单创建, 代码: 600926.SH, 价格: 14.32, 股数:34100, 现有持仓: 34100
# 2020-12-21: 卖单执行, 代码：600926.SH, 价格:14.32, 股数:34100, 持有现金:24216895
# 2020-12-21: 交易收益 代码：600926.SH, 毛利润 -10912.00, 净利润 -10912.00
# 2020-12-24: 买单创建, 代码: 600926.SH, 价格: 14.66, 股数: 34100, 现有持仓: 0
# 2020-12-25: 买单执行, 代码：600926.SH, 价格:14.66, 股数:34100, 持有现金:23716989
# 2020-12-28: 卖单创建, 代码: 600918.SH, 价格: 16.74, 股数:31800, 现有持仓: 31800
# 2020-12-29: 卖单执行, 代码：600918.SH, 价格:16.74, 股数:31800, 持有现金:24249321
# 2020-12-29: 交易收益 代码：600918.SH, 毛利润 33708.00, 净利润 33708.00
# 2020-12-29: 买单创建, 代码: 600918.SH, 价格: 16.83, 股数: 29700, 现有持仓: 0
# 2020-12-30: 买单执行, 代码：600918.SH, 价格:16.83, 股数:29700, 持有现金:23749470
# Net Profit: 1.21%

# %%
index_list[236:240]
# Out:
# ['600918.SH', '600919.SH', '600926.SH', '600928.SH']

# %% [markdown]
# ### 循环调参

# %%
profit_dict = {}

# 904ff4752522814dca00e032a709fdfc26d8744913500ef204e02157
# 74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6

def getdata_mul(s_code, start=datetime.date(2020, 12, 31)-datetime.timedelta(days = 385),
                end = datetime.date(2020, 12, 31)):
    global cerebro
    df = pd.read_csv('.\\Data\\2019\\'+s_code+'.csv', 
                     converters={'trade_date':lambda x:pd.to_datetime(x)}).set_index('trade_date')
    data = bt.feeds.PandasData(dataname=df, fromdate=s_date, todate=e_date)
    cerebro.adddata(data, name=s_code)
    return

s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 385)
e_date = datetime.date(2020, 12, 31)


stock_index = '399300.SZ'
pro = ts.pro_api('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6')
index_list = np.unique(pro.index_weight(index_code=stock_index,
                                        start_date=s_date.strftime('%Y%m%d'),
                                        end_date=e_date.strftime('%Y%m%d')).con_code).tolist()


if __name__ == '__main__':
    for i in range(3,10):
        for j in range(3,10):
            profit = list()
            for _ in range(10):
                random.seed(10086)
                # Create a cerebro entity
                cerebro = bt.Cerebro(tradehistory=True)

                # Add a strategy
                strats = cerebro.addstrategy(Strategy_comp_lite, printlog=False, using_atr=True, atr_percent=0.01, wave_period_buy=i, wave_period_sell=j)
                t_list = [utilsJ.MyThread(getdata_mul, (s_code, s_date, e_date)) for s_code in index_list]
                [t.start() for t in t_list]
                [t.join() for t in t_list]
                #for s_code in index_list:
                #    df = pd.read_csv('.\\Data\\2020\\'+s_code+'.csv',
                #                     converters={'trade_date':lambda x:pd.to_datetime(x)}).set_index('trade_date')
                #    data = bt.feeds.PandasData(dataname=df, fromdate=s_date, todate=e_date)

                    # Add the index Data Feed to Cerebo
                #    cerebro.adddata(data, name=s_code)
                
                # Set cash inside the strategy
                cerebro.broker = bt.brokers.BackBroker(coc=True)
                cerebro.broker.setcash(10000000)

                # Set commission
                #cerebro.broker.setcommission()

                # Print out the starting conditions
                start_value = cerebro.broker.getvalue()
                #print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

                # Run over everything
                cerebro.run(maxcpus=16)

                # Print out the final result
                final_value = cerebro.broker.getvalue()
                #print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
                #print('(%s, %s) Net Profit: %.2f%%' % (s[0], s[1], (final_value-start_value)/start_value*100))
                profit.append((final_value - start_value) / start_value * 100)
            print((i, j, max(profit), min(profit), np.mean(profit)))
# Out:
# (3, 3, 30.61622, -15.267449999999998, 6.993897000000002)
# (3, 4, 29.43319000000002, -2.22742, 12.004607000000002)
# (3, 5, 26.80259000000002, -4.66272, 12.084409)
# (3, 6, 66.80713999999996, -16.23792, 11.824182999999996)
# (3, 7, 38.934000000000005, -8.8027, 11.546664000000003)
# (3, 8, 42.44266, -2.1581300000000003, 11.674179000000002)
# (3, 9, 18.57857, -12.36416, 6.387382000000002)
# (4, 3, 27.33895, -2.9983699999999813, 9.348509000000005)
# (4, 4, 35.87536, -19.171459999999982, 8.373752999999995)
# (4, 5, 16.97974, -12.01473, 7.835573999999999)
# (4, 6, 32.35104, -10.424990000000001, 15.040164)
# (4, 7, 38.56657, -17.96259, 10.542054999999998)
# (4, 8, 27.29801, -10.734610000000037, 8.731038999999996)
# (4, 9, 20.823050000000002, -6.58164, 8.240261999999998)
# (5, 3, 17.25256, -2.008769999999981, 4.555616000000002)
# (5, 4, 25.99187, -16.62052999999998, 5.392438000000004)
# (5, 5, 33.613530000000004, -2.4419899999999815, 18.102934000000005)
# (5, 6, 26.29503999999998, -10.70800000000002, 11.364631999999993)
# (5, 7, 33.28256, -12.45636, 9.686954999999996)
# (5, 8, 32.587120000000006, -4.45424, 12.908046999999993)
# (5, 9, 28.315350000000016, -15.69865, 6.655185999999998)
# (6, 3, 21.907160000000037, -3.1544700000000003, 6.975033000000009)
# (6, 4, 38.48932, -6.12979, 6.777031999999994)
# (6, 5, 18.232110000000002, -19.13077000000002, 3.843116999999998)
# (6, 6, 36.876550000000016, -3.346670000000019, 11.669938000000005)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15956\2384873947.py in <module>
#      60
#      61                 # Run over everything
# ---> 62                 cerebro.run(maxcpus=16)
#      63
#      64                 # Print out the final result
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\cerebro.py in run(self, **kwargs)
#    1125             # let's skip process "spawning"
#    1126             for iterstrat in iterstrats:
# -> 1127                 runstrat = self.runstrategies(iterstrat)
#    1128                 self.runstrats.append(runstrat)
#    1129                 if self._dooptimize:
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\cerebro.py in runstrategies(self, iterstrat, predata)
#    1215             sargs = self.datas + list(sargs)
#    1216             try:
# -> 1217                 strat = stratcls(*sargs, **skwargs)
#    1218             except bt.errors.StrategySkipError:
#    1219                 continue  # do not add strategy to the mix
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\metabase.py in __call__(cls, *args, **kwargs)
#      86         _obj, args, kwargs = cls.donew(*args, **kwargs)
#      87         _obj, args, kwargs = cls.dopreinit(_obj, *args, **kwargs)
# ---> 88         _obj, args, kwargs = cls.doinit(_obj, *args, **kwargs)
#      89         _obj, args, kwargs = cls.dopostinit(_obj, *args, **kwargs)
#      90         return _obj
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\metabase.py in doinit(cls, _obj, *args, **kwargs)
#      76
#      77     def doinit(cls, _obj, *args, **kwargs):
# ---> 78         _obj.__init__(*args, **kwargs)
#      79         return _obj, args, kwargs
#      80
#
# ~\AppData\Local\Temp\ipykernel_15956\246484787.py in __init__(self)
#      53             # Add indicators
#      54             ## Bollinger Bands indicator
# ---> 55             self.inds[d]['bolling'] = bt.indicators.BollingerBands(d,
#      56                                                         period=self.params.bollinger_per,
#      57                                                         devfactor=self.params.bollinger_dev)
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\indicator.py in __call__(cls, *args, **kwargs)
#      51     def __call__(cls, *args, **kwargs):
#      52         if not cls._icacheuse:
# ---> 53             return super(MetaIndicator, cls).__call__(*args, **kwargs)
#      54
#      55         # implement a cache to avoid duplicating lines actions
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\metabase.py in __call__(cls, *args, **kwargs)
#      86         _obj, args, kwargs = cls.donew(*args, **kwargs)
#      87         _obj, args, kwargs = cls.dopreinit(_obj, *args, **kwargs)
# ---> 88         _obj, args, kwargs = cls.doinit(_obj, *args, **kwargs)
#      89         _obj, args, kwargs = cls.dopostinit(_obj, *args, **kwargs)
#      90         return _obj
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\metabase.py in doinit(cls, _obj, *args, **kwargs)
#      76
#      77     def doinit(cls, _obj, *args, **kwargs):
# ---> 78         _obj.__init__(*args, **kwargs)
#      79         return _obj, args, kwargs
#      80
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\indicators\bollinger.py in __init__(self)
#      56
#      57     def __init__(self):
# ---> 58         self.lines.mid = ma = self.p.movav(self.data, period=self.p.period)
#      59         stddev = self.p.devfactor * StdDev(self.data, ma, period=self.p.period,
#      60                                            movav=self.p.movav)
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\indicator.py in __call__(cls, *args, **kwargs)
#      51     def __call__(cls, *args, **kwargs):
#      52         if not cls._icacheuse:
# ---> 53             return super(MetaIndicator, cls).__call__(*args, **kwargs)
#      54
#      55         # implement a cache to avoid duplicating lines actions
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\metabase.py in __call__(cls, *args, **kwargs)
#      84     def __call__(cls, *args, **kwargs):
#      85         cls, args, kwargs = cls.doprenew(*args, **kwargs)
# ---> 86         _obj, args, kwargs = cls.donew(*args, **kwargs)
#      87         _obj, args, kwargs = cls.dopreinit(_obj, *args, **kwargs)
#      88         _obj, args, kwargs = cls.doinit(_obj, *args, **kwargs)
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\lineiterator.py in donew(cls, *args, **kwargs)
#      39     def donew(cls, *args, **kwargs):
#      40         _obj, args, kwargs = \
# ---> 41             super(MetaLineIterator, cls).donew(*args, **kwargs)
#      42
#      43         # Prepare to hold children that need to be calculated and
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\lineseries.py in donew(cls, *args, **kwargs)
#     423
#     424         # _obj.lines shadows the lines (class) definition in the class
# --> 425         _obj.lines = cls.lines()
#     426
#     427         # _obj.plotinfo shadows the plotinfo (class) definition in the class
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\lineseries.py in __init__(self, initlines)
#     205         for line, linealias in enumerate(self._getlines()):
#     206             kwargs = dict()
# --> 207             self.lines.append(LineBuffer(**kwargs))
#     208
#     209         # Add the required extralines
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\metabase.py in __call__(cls, *args, **kwargs)
#      87         _obj, args, kwargs = cls.dopreinit(_obj, *args, **kwargs)
#      88         _obj, args, kwargs = cls.doinit(_obj, *args, **kwargs)
# ---> 89         _obj, args, kwargs = cls.dopostinit(_obj, *args, **kwargs)
#      90         return _obj
#      91
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\metabase.py in dopostinit(cls, _obj, *args, **kwargs)
#      79         return _obj, args, kwargs
#      80
# ---> 81     def dopostinit(cls, _obj, *args, **kwargs):
#      82         return _obj, args, kwargs
#      83
#
# KeyboardInterrupt:
