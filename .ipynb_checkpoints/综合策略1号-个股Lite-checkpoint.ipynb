# %%
# 数据接口 
import akshare as ak
import baostock as bs
import tushare as ts

# 基础模块
import datetime
from itertools import product
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time

# 回测框架
import backtrader as bt

# 基础函数
import utilsJ

# %% [markdown]
# # 策略

# %% [markdown]
# ### 现有指标：
# + 均线
# + 布林带
# + MACD柱状图
# + RSI相对强弱
# + WilliamR指标

# %%
class Strategy_lite1(bt.Strategy):
    
    params = (
        # General params
        ('printlog', False),
        ('p_stake', 100),

        # Indicator params
        ('bollinger_per', 20),
        ('bollinger_dev', 2),
        ('wave_period', 7),
        
        # ATR params
        ('using_atr', False),
        ('atr_period', 14),
        ('atr_percent', 1),
    )
    
    
    def log(self, txt, dt=None, doprint=False):
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s: %s' % (dt.isoformat(), txt))
            #with open('log.txt', 'a') as file:
                #file.write('%s: %s \n' % (dt.isoformat(), txt))
        
    
    def __init__(self):
        # Keep references to lines in the data[0] dataseries
        self.dataclose = self.datas[0].close
        self.datahigh = self.datas[0].high
        self.datalow = self.datas[0].low

        # Keep references to executed order & price
        self.buyprice = 0
        self.sellprice = 0
        self.order = None

        # Add indicator
        ## Bollinger Bands indicator
        self.bolling = bt.indicators.BollingerBands(self.datas[0], 
                                                    period = self.params.bollinger_per, 
                                                    devfactor = self.params.bollinger_dev)
        self.bolling_buy = bt.Or(bt.And(self.dataclose(0) > self.bolling.top(0), self.dataclose(-1) < self.bolling.top(-1)), 
                                 bt.And(self.dataclose(0) > self.bolling.bot(0), self.dataclose(-1) < self.bolling.bot(-1)))
        self.bolling_sell = bt.Or(bt.And(self.dataclose(0) < self.bolling.top(0), self.dataclose(-1) > self.bolling.top(-1)), 
                                  bt.And(self.dataclose(0) < self.bolling.bot(0), self.dataclose(-1) > self.bolling.bot(-1)))

        ## Wave indicator
        ### MovingAverageSimple indicator
        self.sma = bt.indicators.SimpleMovingAverage(self.datas[0], period=self.params.wave_period)
        self.wave_buy = bt.Or(bt.And(self.sma(0) > self.sma(-1), self.sma(-1) < self.sma(-2), self.sma(-2) < self.sma(-3)),
                                               self.sma(0) > self.bolling.mid(0))
        self.wave_sell = bt.And(self.sma(0) < self.sma(-1), self.sma(-1) > self.sma(-2), self.sma(-2) > self.sma(-3))


    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.buyprice = order.executed.price
                self.log('BUY EXECUTED, Price:%.2f, Lot:%i, Cash:%i.' %
                         (order.executed.price,
                          order.executed.size,
                          self.broker.get_cash()))

            else:  # Sell
                self.sellprice = order.executed.price
                self.log('SELL EXECUTED, Price:%.2f, Lot:%i, Cash:%i.' %
                        (order.executed.price,
                          -order.executed.size,
                          self.broker.get_cash()))

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        # Write down: no pending order
        #self.order = None


    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))
    

    def next(self):
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return

        buy_indicator = self.wave_buy and not self.downwards
                        
        sell_indicator = self.bolling_sell or self.wave_sell
            
        if buy_indicator and self.getposition(self.data).size == 0:
            if self.params.using_atr:
                opt_pos = np.round(self.atr_initial * self.params.atr_percent / self.params.p_stake / self.atr[0])
                if opt_pos*self.params.p_stake > 0 and self.getposition(self.data).size < opt_pos*self.params.p_stake:
                    self.log('BUY CREATE, Price: %.2f, Lots: %i, Current Position: %i' % 
                             (self.dataclose[0], 
                             opt_pos*self.params.p_stake-self.getposition(self.data).size,
                             self.getposition(self.data).size))
                    self.buy(size=opt_pos*self.params.p_stake-self.getposition(self.data).size)
            else:
                self.log('BUY CREATE, Price: %.2f, Lots: %i, Current Position: %i' % (self.dataclose[0], 
                        self.params.p_stake,
                        self.getposition(self.data).size))
                self.buy(size=self.params.p_stake)
        elif sell_indicator and self.getposition(self.data).size > 0:
            self.log('Sell CREATE(Close), Price: %.2f, Current Position: %i' % (self.dataclose[0],
                        self.getposition(self.data).size))
            self.close()


    def stop(self):
        self.log('Ending Position:%i. Ending Value:%.2f.' %
                (self.getposition(self.data).size,
                self.cerebro.broker.getvalue()), doprint=False)

# %% [markdown]
# ### 沪深300回测

# %%
s_date = datetime.date(2020,12,31) - datetime.timedelta(days=385)
e_date = datetime.date(2020,12,31)
idx = '399300.SZ'
pro = ts.pro_api('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6')
index_list = np.unique(pro.index_weight(index_code=idx,
                                        start_date=s_date.strftime('%Y%m%d'),
                                        end_date=e_date.strftime('%Y%m%d')).con_code).tolist()


profit_stk = dict()
for stk in index_list:
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    strats = cerebro.addstrategy(Strategy_lite1, printlog=False, using_atr=True, atr_percent=0.01) 

    # Create stock Data Feed
    #df = utilsJ.stock_tushare('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6', 
    #                    stock_index, s_date, e_date)
    df = pd.read_csv('.\\Data\\2019\\'+stk+'.csv', 
                        converters={'trade_date':lambda x:pd.to_datetime(x)}).set_index('trade_date')
    data = bt.feeds.PandasData(dataname=df,fromdate=s_date,todate=e_date)

    # Add the index Data Feed to Cerebo
    cerebro.adddata(data)

    # Set cash inside the strategy
    cerebro.broker = bt.brokers.BackBroker(coc=True)   
    cerebro.broker.setcash(500000)

    # Set commission
    #cerebro.broker.setcommission()

    # Print out the starting conditions
    start_value = cerebro.broker.getvalue()
    #print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    final_value = cerebro.broker.getvalue()
    #print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    print('%s, Net Profit: %.2f%%' % (stk, (final_value - start_value) / start_value * 100))

    profit_stk[stk] = (final_value - start_value) / start_value * 100
# Out:
# 000001.SZ, Net Profit: 12.76%
# 000002.SZ, Net Profit: 6.79%
# 000063.SZ, Net Profit: 4.15%
# 000066.SZ, Net Profit: -3.85%
# 000069.SZ, Net Profit: 4.52%
# 000100.SZ, Net Profit: 4.37%
# 000157.SZ, Net Profit: -2.58%
# 000166.SZ, Net Profit: -0.88%
# 000333.SZ, Net Profit: 2.65%
# 000338.SZ, Net Profit: 3.30%
# 000413.SZ, Net Profit: -1.22%
# 000415.SZ, Net Profit: -5.22%
# 000423.SZ, Net Profit: -2.31%
# 000425.SZ, Net Profit: 2.35%
# 000538.SZ, Net Profit: 5.48%
# 000568.SZ, Net Profit: 10.87%
# 000596.SZ, Net Profit: 7.33%
# 000625.SZ, Net Profit: 3.28%
# 000627.SZ, Net Profit: -4.64%
# 000629.SZ, Net Profit: -4.01%
# 000630.SZ, Net Profit: 7.93%
# 000651.SZ, Net Profit: 0.43%
# 000656.SZ, Net Profit: -1.78%
# 000661.SZ, Net Profit: 4.00%
# 000671.SZ, Net Profit: -0.24%
# 000703.SZ, Net Profit: -14.18%
# 000708.SZ, Net Profit: 3.52%
# 000709.SZ, Net Profit: 1.25%
# 000723.SZ, Net Profit: 1.95%
# 000725.SZ, Net Profit: 5.90%
# 000728.SZ, Net Profit: 3.41%
# 000768.SZ, Net Profit: 3.33%
# 000776.SZ, Net Profit: -4.34%
# 000783.SZ, Net Profit: -6.80%
# 000786.SZ, Net Profit: 6.37%
# 000858.SZ, Net Profit: 20.76%
# 000860.SZ, Net Profit: -1.70%
# 000876.SZ, Net Profit: 2.34%
# 000895.SZ, Net Profit: 1.38%
# 000898.SZ, Net Profit: 0.70%
# 000938.SZ, Net Profit: -1.02%
# 000961.SZ, Net Profit: 9.67%
# 000963.SZ, Net Profit: -3.58%
# 000977.SZ, Net Profit: -1.57%
# 001979.SZ, Net Profit: 2.51%
# 002001.SZ, Net Profit: -2.84%
# 002007.SZ, Net Profit: 6.68%
# 002008.SZ, Net Profit: -4.63%
# 002010.SZ, Net Profit: -4.69%
# 002024.SZ, Net Profit: 3.01%
# 002027.SZ, Net Profit: 7.81%
# 002032.SZ, Net Profit: 3.56%
# 002044.SZ, Net Profit: 1.86%
# 002049.SZ, Net Profit: 6.00%
# 002050.SZ, Net Profit: -5.84%
# 002081.SZ, Net Profit: 7.54%
# 002120.SZ, Net Profit: 3.31%
# 002129.SZ, Net Profit: 0.93%
# 002142.SZ, Net Profit: 1.88%
# 002146.SZ, Net Profit: -0.04%
# 002153.SZ, Net Profit: -6.11%
# 002157.SZ, Net Profit: 1.97%
# 002179.SZ, Net Profit: 6.46%
# 002202.SZ, Net Profit: 6.88%
# 002230.SZ, Net Profit: -10.20%
# 002236.SZ, Net Profit: -7.92%
# 002241.SZ, Net Profit: 2.81%
# 002252.SZ, Net Profit: -1.32%
# 002271.SZ, Net Profit: 6.41%
# 002294.SZ, Net Profit: 1.59%
# 002304.SZ, Net Profit: 12.16%
# 002311.SZ, Net Profit: 0.93%
# 002352.SZ, Net Profit: 21.20%
# 002371.SZ, Net Profit: 5.04%
# 002384.SZ, Net Profit: 2.77%
# 002410.SZ, Net Profit: 0.95%
# 002411.SZ, Net Profit: -14.65%
# 002414.SZ, Net Profit: -0.44%
# 002415.SZ, Net Profit: 0.59%
# 002422.SZ, Net Profit: 2.87%
# 002456.SZ, Net Profit: 6.03%
# 002460.SZ, Net Profit: 3.24%
# 002463.SZ, Net Profit: 1.36%
# 002466.SZ, Net Profit: 6.70%
# 002468.SZ, Net Profit: -0.17%
# 002475.SZ, Net Profit: 3.42%
# 002493.SZ, Net Profit: 6.24%
# 002508.SZ, Net Profit: -5.12%
# 002555.SZ, Net Profit: 3.35%
# 002558.SZ, Net Profit: -1.19%
# 002594.SZ, Net Profit: 7.78%
# 002600.SZ, Net Profit: 1.00%
# 002601.SZ, Net Profit: -3.39%
# 002602.SZ, Net Profit: -0.56%
# 002607.SZ, Net Profit: -1.18%
# 002624.SZ, Net Profit: -2.56%
# 002673.SZ, Net Profit: -0.88%
# 002714.SZ, Net Profit: -8.64%
# 002736.SZ, Net Profit: -3.28%
# 002739.SZ, Net Profit: 3.82%
# 002773.SZ, Net Profit: -1.51%
# 002812.SZ, Net Profit: 13.91%
# 002821.SZ, Net Profit: -4.41%
# 002841.SZ, Net Profit: -5.81%
# 002916.SZ, Net Profit: 2.15%
# 002938.SZ, Net Profit: 1.98%
# 002939.SZ, Net Profit: -4.45%
# 002945.SZ, Net Profit: -7.84%
# 002958.SZ, Net Profit: -1.81%
# 003816.SZ, Net Profit: -2.23%
# 300003.SZ, Net Profit: 3.85%
# 300014.SZ, Net Profit: -0.74%
# 300015.SZ, Net Profit: 6.64%
# 300017.SZ, Net Profit: 3.00%
# 300024.SZ, Net Profit: 0.82%
# 300033.SZ, Net Profit: 3.22%
# 300059.SZ, Net Profit: 3.60%
# 300070.SZ, Net Profit: 1.93%
# 300122.SZ, Net Profit: 5.14%
# 300124.SZ, Net Profit: 10.23%
# 300136.SZ, Net Profit: 5.40%
# 300142.SZ, Net Profit: 11.29%
# 300144.SZ, Net Profit: -3.76%
# 300347.SZ, Net Profit: 6.76%
# 300408.SZ, Net Profit: 7.71%
# 300413.SZ, Net Profit: 6.48%
# 300433.SZ, Net Profit: 6.49%
# 300498.SZ, Net Profit: -3.38%
# 300529.SZ, Net Profit: -3.16%
# 300601.SZ, Net Profit: 3.46%
# 300628.SZ, Net Profit: 4.19%
# 300676.SZ, Net Profit: 1.34%
# 600000.SH, Net Profit: -3.92%
# 600004.SH, Net Profit: -3.00%
# 600009.SH, Net Profit: 0.33%
# 600010.SH, Net Profit: -3.86%
# 600011.SH, Net Profit: -0.06%
# 600015.SH, Net Profit: 3.72%
# 600016.SH, Net Profit: 0.72%
# 600018.SH, Net Profit: 5.70%
# 600019.SH, Net Profit: 2.82%
# 600023.SH, Net Profit: -0.88%
# 600025.SH, Net Profit: 0.18%
# 600027.SH, Net Profit: -3.09%
# 600028.SH, Net Profit: 0.43%
# 600029.SH, Net Profit: -1.42%
# 600030.SH, Net Profit: 1.03%
# 600031.SH, Net Profit: 3.47%
# 600036.SH, Net Profit: 10.68%
# 600038.SH, Net Profit: 1.36%
# 600048.SH, Net Profit: 4.03%
# 600050.SH, Net Profit: -6.43%
# 600061.SH, Net Profit: -1.65%
# 600066.SH, Net Profit: 3.14%
# 600068.SH, Net Profit: 4.05%
# 600085.SH, Net Profit: 1.44%
# 600089.SH, Net Profit: 8.79%
# 600100.SH, Net Profit: -6.14%
# 600104.SH, Net Profit: -3.68%
# 600109.SH, Net Profit: 4.27%
# 600111.SH, Net Profit: 7.80%
# 600115.SH, Net Profit: 0.97%
# 600118.SH, Net Profit: -5.79%
# 600150.SH, Net Profit: 8.32%
# 600153.SH, Net Profit: -4.86%
# 600161.SH, Net Profit: -7.92%
# 600170.SH, Net Profit: -6.15%
# 600176.SH, Net Profit: 1.69%
# 600177.SH, Net Profit: 4.63%
# 600183.SH, Net Profit: 8.80%
# 600188.SH, Net Profit: -0.79%
# 600196.SH, Net Profit: 8.91%
# 600208.SH, Net Profit: 5.27%
# 600219.SH, Net Profit: 5.77%
# 600221.SH, Net Profit: -2.99%
# 600233.SH, Net Profit: -0.73%
# 600271.SH, Net Profit: -3.18%
# 600276.SH, Net Profit: -6.79%
# 600297.SH, Net Profit: 0.48%
# 600299.SH, Net Profit: 3.91%
# 600309.SH, Net Profit: 2.83%
# 600332.SH, Net Profit: 0.83%
# 600340.SH, Net Profit: -7.79%
# 600346.SH, Net Profit: 10.09%
# 600352.SH, Net Profit: 4.27%
# 600362.SH, Net Profit: 0.93%
# 600369.SH, Net Profit: -5.20%
# 600372.SH, Net Profit: 10.84%
# 600383.SH, Net Profit: 9.40%
# 600390.SH, Net Profit: -10.22%
# 600398.SH, Net Profit: 0.80%
# 600406.SH, Net Profit: -0.71%
# 600436.SH, Net Profit: 1.50%
# 600438.SH, Net Profit: 3.05%
# 600482.SH, Net Profit: 8.47%
# 600487.SH, Net Profit: 5.26%
# 600489.SH, Net Profit: -4.17%
# 600498.SH, Net Profit: -2.20%
# 600516.SH, Net Profit: -2.00%
# 600519.SH, Net Profit: 4.18%
# 600522.SH, Net Profit: 3.86%
# 600535.SH, Net Profit: 0.91%
# 600547.SH, Net Profit: -3.16%
# 600566.SH, Net Profit: -2.55%
# 600570.SH, Net Profit: 6.13%
# 600583.SH, Net Profit: -9.55%
# 600584.SH, Net Profit: 16.99%
# 600585.SH, Net Profit: 0.14%
# 600588.SH, Net Profit: 11.66%
# 600600.SH, Net Profit: 7.81%
# 600606.SH, Net Profit: 25.66%
# 600637.SH, Net Profit: 5.61%
# 600655.SH, Net Profit: -6.37%
# 600660.SH, Net Profit: 18.27%
# 600663.SH, Net Profit: -3.93%
# 600674.SH, Net Profit: 0.44%
# 600690.SH, Net Profit: 13.34%
# 600703.SH, Net Profit: 0.87%
# 600705.SH, Net Profit: -5.07%
# 600733.SH, Net Profit: 2.99%
# 600741.SH, Net Profit: 6.68%
# 600745.SH, Net Profit: 4.88%
# 600760.SH, Net Profit: 1.42%
# 600763.SH, Net Profit: 0.98%
# 600795.SH, Net Profit: 0.00%
# 600809.SH, Net Profit: 16.19%
# 600816.SH, Net Profit: 1.47%
# 600837.SH, Net Profit: -4.14%
# 600845.SH, Net Profit: -1.03%
# 600848.SH, Net Profit: 1.55%
# 600867.SH, Net Profit: -12.51%
# 600872.SH, Net Profit: 4.18%
# 600886.SH, Net Profit: 1.63%
# 600887.SH, Net Profit: -0.51%
# 600893.SH, Net Profit: 4.96%
# 600900.SH, Net Profit: 2.29%
# 600918.SH, Net Profit: -0.96%
# 600919.SH, Net Profit: 2.76%
# 600926.SH, Net Profit: 5.59%
# 600928.SH, Net Profit: 5.15%
# 600958.SH, Net Profit: -1.01%
# 600968.SH, Net Profit: 1.68%
# 600977.SH, Net Profit: 2.48%
# 600989.SH, Net Profit: 4.28%
# 600998.SH, Net Profit: -1.49%
# 600999.SH, Net Profit: 35.36%
# 601006.SH, Net Profit: -7.45%
# 601009.SH, Net Profit: 8.13%
# 601012.SH, Net Profit: 4.26%
# 601018.SH, Net Profit: 4.13%
# 601021.SH, Net Profit: 7.33%
# 601066.SH, Net Profit: 0.46%
# 601077.SH, Net Profit: 10.63%
# 601088.SH, Net Profit: 4.21%
# 601100.SH, Net Profit: 2.17%
# 601108.SH, Net Profit: 9.21%
# 601111.SH, Net Profit: -0.32%
# 601117.SH, Net Profit: -7.09%
# 601138.SH, Net Profit: -5.81%
# 601155.SH, Net Profit: 2.95%
# 601162.SH, Net Profit: -2.53%
# 601166.SH, Net Profit: -3.86%
# 601169.SH, Net Profit: 0.08%
# 601186.SH, Net Profit: 0.48%
# 601198.SH, Net Profit: -4.88%
# 601211.SH, Net Profit: -4.00%
# 601212.SH, Net Profit: 7.70%
# 601216.SH, Net Profit: -9.35%
# 601225.SH, Net Profit: 2.34%
# 601229.SH, Net Profit: 5.01%
# 601231.SH, Net Profit: 1.46%
# 601236.SH, Net Profit: -1.28%
# 601238.SH, Net Profit: 0.49%
# 601288.SH, Net Profit: -1.38%
# 601298.SH, Net Profit: 10.60%
# 601318.SH, Net Profit: 2.27%
# 601319.SH, Net Profit: -8.46%
# 601328.SH, Net Profit: -0.87%
# 601336.SH, Net Profit: 2.51%
# 601360.SH, Net Profit: -4.49%
# 601377.SH, Net Profit: 12.88%
# 601390.SH, Net Profit: -1.22%
# 601398.SH, Net Profit: -1.81%
# 601555.SH, Net Profit: -4.63%
# 601577.SH, Net Profit: -3.02%
# 601600.SH, Net Profit: 8.17%
# 601601.SH, Net Profit: -5.99%
# 601607.SH, Net Profit: 6.32%
# 601618.SH, Net Profit: 2.77%
# 601628.SH, Net Profit: 18.78%
# 601633.SH, Net Profit: 12.08%
# 601658.SH, Net Profit: -1.01%
# 601668.SH, Net Profit: -1.88%
# 601669.SH, Net Profit: 6.93%
# 601688.SH, Net Profit: -5.61%
# 601696.SH, Net Profit: 2.93%
# 601698.SH, Net Profit: 0.96%
# 601727.SH, Net Profit: -2.72%
# 601766.SH, Net Profit: -3.79%
# 601788.SH, Net Profit: 57.07%
# 601800.SH, Net Profit: -2.63%
# 601808.SH, Net Profit: -2.77%
# 601816.SH, Net Profit: -0.19%
# 601818.SH, Net Profit: 6.83%
# 601828.SH, Net Profit: -1.79%
# 601838.SH, Net Profit: 0.48%
# 601857.SH, Net Profit: -1.05%
# 601872.SH, Net Profit: 2.15%
# 601877.SH, Net Profit: 2.92%
# 601878.SH, Net Profit: 34.29%
# 601881.SH, Net Profit: 0.99%
# 601888.SH, Net Profit: -2.88%
# 601898.SH, Net Profit: 0.17%
# 601899.SH, Net Profit: -2.79%
# 601901.SH, Net Profit: -3.11%
# 601916.SH, Net Profit: -1.88%
# 601919.SH, Net Profit: 3.60%
# 601933.SH, Net Profit: 6.13%
# 601939.SH, Net Profit: -1.93%
# 601985.SH, Net Profit: -0.15%
# 601988.SH, Net Profit: 0.00%
# 601989.SH, Net Profit: 6.70%
# 601990.SH, Net Profit: 7.74%
# 601992.SH, Net Profit: 2.88%
# 601997.SH, Net Profit: 1.63%
# 601998.SH, Net Profit: -3.98%
# 603019.SH, Net Profit: -11.12%
# 603087.SH, Net Profit: -1.30%
# 603156.SH, Net Profit: -8.28%
# 603160.SH, Net Profit: 2.46%
# 603195.SH, Net Profit: -5.21%
# 603259.SH, Net Profit: -6.05%
# 603260.SH, Net Profit: 6.99%
# 603288.SH, Net Profit: 1.26%
# 603369.SH, Net Profit: 2.93%
# 603392.SH, Net Profit: 8.33%
# 603501.SH, Net Profit: -1.08%
# 603658.SH, Net Profit: 1.60%
# 603799.SH, Net Profit: 1.06%
# 603833.SH, Net Profit: 0.50%
# 603899.SH, Net Profit: -1.63%
# 603986.SH, Net Profit: -4.05%
# 603993.SH, Net Profit: 7.08%
# 688008.SH, Net Profit: -1.20%
# 688009.SH, Net Profit: -5.93%
# 688012.SH, Net Profit: -2.46%
# 688036.SH, Net Profit: 2.94%

# %% [markdown]
# # 单股回测

# %%
if __name__ ==  '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    strats = cerebro.addstrategy(Strategy_lite1, printlog=True, using_atr=True, atr_percent=0.01) 

    s_date = datetime.date(2020,12,31) - datetime.timedelta(days=385)
    e_date = datetime.date(2020,12,31)

    # Create stock Data Feed
    stock_index = '000066.SZ'
    #df = utilsJ.stock_tushare('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6', 
    #                    stock_index, s_date, e_date)
    df = pd.read_csv('.\\Data\\2019\\' + stock_index + '.csv', converters={'trade_date':lambda x:pd.to_datetime(x)}).set_index('trade_date')
    data = bt.feeds.PandasData(dataname=df,fromdate=s_date,todate=e_date)

    # Add the index Data Feed to Cerebo
    cerebro.adddata(data)

    # Set cash inside the strategy
    cerebro.broker = bt.brokers.BackBroker(coc=True)   
    cerebro.broker.setcash(20000)

    # Set commission
    #cerebro.broker.setcommission()

    # Print out the starting conditions
    start_value = cerebro.broker.getvalue()
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    final_value = cerebro.broker.getvalue()
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    print('Net Profit: %.2f%%' % ((final_value - start_value) / start_value * 100))
# Out:
# Starting Portfolio Value: 20000.00
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6740\2214923034.py in <module>
#      31
#      32     # Run over everything
# ---> 33     cerebro.run()
#      34
#      35     # Print out the final result
#
# D:\Anaconda\envs\py38\lib\site-packages\backtrader\cerebro.py in run(self, **kwargs)
#    1125             # let's skip process "spawning"
#    1126             for iterstrat in iterstrats:
# -> 1127                 runstrat = self.runstrategies(iterstrat)
#    1128                 self.runstrats.append(runstrat)
#    1129                 if self._dooptimize:
#
# D:\Anaconda\envs\py38\lib\site-packages\backtrader\cerebro.py in runstrategies(self, iterstrat, predata)
#    1215             sargs = self.datas + list(sargs)
#    1216             try:
# -> 1217                 strat = stratcls(*sargs, **skwargs)
#    1218             except bt.errors.StrategySkipError:
#    1219                 continue  # do not add strategy to the mix
#
# D:\Anaconda\envs\py38\lib\site-packages\backtrader\metabase.py in __call__(cls, *args, **kwargs)
#      86         _obj, args, kwargs = cls.donew(*args, **kwargs)
#      87         _obj, args, kwargs = cls.dopreinit(_obj, *args, **kwargs)
# ---> 88         _obj, args, kwargs = cls.doinit(_obj, *args, **kwargs)
#      89         _obj, args, kwargs = cls.dopostinit(_obj, *args, **kwargs)
#      90         return _obj
#
# D:\Anaconda\envs\py38\lib\site-packages\backtrader\metabase.py in doinit(cls, _obj, *args, **kwargs)
#      76
#      77     def doinit(cls, _obj, *args, **kwargs):
# ---> 78         _obj.__init__(*args, **kwargs)
#      79         return _obj, args, kwargs
#      80
#
# ~\AppData\Local\Temp\ipykernel_6740\2832542513.py in __init__(self)
#      45         self.atr = bt.indicators.SimpleMovingAverage(self.tr, period=self.params.atr_period)
#      46
# ---> 47         self.downwards = bt.Or(self.bolling.mid(0) > self.dataclose(0),
#      48                                                    self.bolling.mid(-1) > self.dataclose(-1),
#      49                                                 self.bolling.mid(-2) > self.dataclose(-2),)
#
# D:\Anaconda\envs\py38\lib\site-packages\backtrader\lineseries.py in __getattr__(self, name)
#     459         # in this object if we set an attribute in this object it will be
#     460         # found before we end up here
# --> 461         return getattr(self.lines, name)
#     462
#     463     def __len__(self):
#
# AttributeError: 'Lines_LineSeries_LineIterator_DataAccessor_Strateg' object has no attribute 'bolling'

# %%
cerebro.plot()
# Out:
# <img src="data:image/png;base64,..." width="961">
# [[<Figure size 640x480 with 4 Axes>]]
