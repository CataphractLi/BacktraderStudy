# %%
# 数据接口 
import akshare as ak
import baostock as bs
import tushare as ts

# 基础模块
import datetime
from itertools import product
import matplotlib.pyplot as plt
import multiprocessing
import numpy as np
import pandas as pd
import random
import time

# 回测框架
import backtrader as bt

# 基础函数
import utilsJ

# %% [markdown]
# # 策略

# %%
class Strategy_comp_mul(bt.Strategy):
    
    params = (
        # General params
        ('printlog', False),
        ('p_stake', 100),
        ('buy_signal', 'b'),
        ('sell_signal', 'b'),

        # Indicator params
        ('bollinger_per', 20),
        ('bollinger_dev', 2),
        ('rsi_short', 6),
        ('rsi_long', 12),
        ('wave_period', 7),
        ('wr', 14),

        # ATR params
        ('using_atr', False),
        ('atr_period', 14),
        ('atr_percent', 1),
    )

    
    def log(self, txt, dt=None, doprint=False):
        if self.params.printlog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s: %s' % (dt.isoformat(), txt))
            #with open('log.txt', 'a') as file:
                #file.write('%s: %s \n' % (dt.isoformat(), txt))

    
    def __init__(self):

        # Record ATR Initial
        self.atr_initial = self.broker.get_cash()
        self.inds = dict()
        self.profit_i = dict()
        self.data_tracker = None

        for d in self.datas:

            self.inds[d] = dict()
            self.profit_i[d._name] = 0

            # Keep references to lines in the data[0] dataseries
            self.inds[d]['dataclose'] = d.close
            self.inds[d]['datahigh'] = d.high
            self.inds[d]['datalow'] = d.low

            # Keep references to executed order & price
            self.inds[d]['buyprice'] = 0
            self.inds[d]['sellprice'] = 0
            self.inds[d]['order'] = None
                
            # Add indicators
            ## Wave indicator
            ### MovingAverageSimple indicator
            self.inds[d]['sma'] = bt.indicators.SimpleMovingAverage(d, period=self.params.wave_period)
            self.inds[d]['wave_buy'] = bt.And(self.inds[d]['sma'](0) > self.inds[d]['sma'](-1), 
                                              self.inds[d]['sma'](-1) < self.inds[d]['sma'](-2), 
                                              self.inds[d]['sma'](-2) < self.inds[d]['sma'](-3))

            self.inds[d]['wave_sell'] = bt.And(self.inds[d]['sma'](0) < self.inds[d]['sma'](-1), 
                                               self.inds[d]['sma'](-1) > self.inds[d]['sma'](-2), 
                                               self.inds[d]['sma'](-2) > self.inds[d]['sma'](-3))

            ## MACD indicator
            self.inds[d]['macdhisto'] = bt.indicators.MACDHisto(d)
            self.inds[d]['macd_buy'] = bt.And(self.inds[d]['macdhisto'](0) > 0, self.inds[d]['macdhisto'](-1) < 0)
            self.inds[d]['macd_sell'] = bt.And(self.inds[d]['macdhisto'](0) < 0, self.inds[d]['macdhisto'](-1) > 0)

            ## Bollinger Bands indicator
            self.inds[d]['bolling'] = bt.indicators.BollingerBands(d, 
                                                        period=self.params.bollinger_per, 
                                                        devfactor=self.params.bollinger_dev)
            self.inds[d]['bolling_buy'] = bt.Or(bt.And(self.inds[d]['dataclose'](0) > self.inds[d]['bolling'].top(0), 
                                                       self.inds[d]['dataclose'](-1) < self.inds[d]['bolling'].top(-1)), 
                                                bt.And(self.inds[d]['dataclose'](0) > self.inds[d]['bolling'].bot(0), 
                                                       self.inds[d]['dataclose'](-1) < self.inds[d]['bolling'].bot(-1)))
            self.inds[d]['bolling_sell'] = bt.Or(bt.And(self.inds[d]['dataclose'](0) < self.inds[d]['bolling'].top(0), 
                                                        self.inds[d]['dataclose'](-1) > self.inds[d]['bolling'].top(-1)), 
                                                 bt.And(self.inds[d]['dataclose'](0) < self.inds[d]['bolling'].bot(0), 
                                                        self.inds[d]['dataclose'](-1) > self.inds[d]['bolling'].bot(-1)))

            ## RSI indicator
            self.inds[d]['rsi_s'] = bt.indicators.RelativeStrengthIndex(d, period=self.params.rsi_short, safediv=True)
            self.inds[d]['rsi_l'] = bt.indicators.RelativeStrengthIndex(d, period=self.params.rsi_long, safediv=True)
            self.inds[d]['rsi_buy'] = bt.And(self.inds[d]['rsi_s'](0) > self.inds[d]['rsi_l'](0), 
                                             self.inds[d]['rsi_s'](-1) < self.inds[d]['rsi_l'](-1))
            self.inds[d]['rsi_sell'] = bt.And(self.inds[d]['rsi_s'](0) < self.inds[d]['rsi_l'](0), 
                                              self.inds[d]['rsi_s'](-1) > self.inds[d]['rsi_l'](-1))

            ## WilliamR indicator
            self.inds[d]['wr'] = bt.indicators.WilliamsR(d, period=self.params.wr)
            self.inds[d]['wr_buy'] = self.inds[d]['wr'] < -80
            self.inds[d]['wr_sell'] = self.inds[d]['wr'] > -20
        
            ## ATR indicator
            self.inds[d]['tr'] = bt.indicators.Max((self.inds[d]['datahigh'](0) - self.inds[d]['datalow'](0)), 
                                                    abs(self.inds[d]['dataclose'](-1) - self.inds[d]['datahigh'](0)),
                                                    abs(self.inds[d]['dataclose'](-1) - self.inds[d]['datalow'](0)))
            self.inds[d]['atr'] = bt.indicators.SimpleMovingAverage(self.inds[d]['tr'], period=self.params.atr_period)


    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                if self.inds[self.data_tracker]['wave_buy']:
                    self.inds[self.data_tracker]['buyprice']
                self.log('买单执行, 代码：%s, 价格:%.2f, 股数:%i, 持有现金:%i' %
                         (order.info['name'],
                          order.executed.price,
                          order.executed.size,
                          self.broker.get_cash()))
                self.profit_i[order.info['name']] -= order.executed.price*order.executed.size

            else:  # Sell
                self.inds[self.data_tracker]['sellprice'] = order.executed.price
                self.log('卖单执行, 代码：%s, 价格:%.2f, 股数:%i, 持有现金:%i' %
                        (order.info['name'],
                         order.executed.price,
                         -order.executed.size,
                         self.broker.get_cash()))
                self.profit_i[order.info['name']] -= order.executed.price*order.executed.size

        elif order.status in [order.Canceled]:
            self.log('订单取消：被撤销')

        elif order.status in [order.Margin]:
            self.log('订单取消：资金不足，代码：%s，持有资金:%i' %
                        (order.info['name'],
                         self.broker.get_cash()))

        elif order.status in [order.Rejected]:
            self.log('订单取消：被拒绝')

        # Write down: no pending order
        #self.order = None


    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('交易收益 代码：%s, 毛利润 %.2f, 净利润 %.2f' %
                 (trade.history[0]['event']['order'].info['name'], 
                  trade.pnl, trade.pnlcomm))
    

    def next(self):

        buy_list = []
        sell_list = []

        for d in self.datas:
        # Check if an order is pending ... if yes, we cannot send a 2nd one
            if self.inds[d]['order']:
                return
            buy_indicator = (self.params.buy_signal == 'b' and self.inds[d]['bolling_buy']) or \
                            (self.params.buy_signal == 'm' and self.inds[d]['macd_buy']) or \
                            (self.params.buy_signal == 'w' and self.inds[d]['wave_buy'] and self.inds[d]['dataclose'][0] > self.inds[d]['buyprice']) or \
                            (self.params.buy_signal == 'r' and self.inds[d]['rsi_buy']) or \
                            (self.params.buy_signal == 'wr' and self.inds[d]['wr_buy'])


            sell_indicator = (self.params.sell_signal == 'b' and self.inds[d]['bolling_sell']) or \
                            (self.params.sell_signal == 'm' and self.inds[d]['macd_sell']) or \
                            (self.params.sell_signal == 'w' and self.inds[d]['wave_sell']) or \
                            (self.params.sell_signal == 'r' and self.inds[d]['rsi_sell']) or \
                            (self.params.sell_signal == 'wr' and self.inds[d]['wr_sell'])

            if sell_indicator and self.getposition(d).size > 0:
                sell_list.append((d, -1))
                #self.log('Sell CREATE(Close), Code: %s, Price: %.2f, Current Position: %i' % 
                #         (d._name, 
                #          self.inds[d]['dataclose'][0],
                #          self.getposition(d).size))
                #self.close(data=d, name=d._name)

            elif buy_indicator and self.inds[d]['dataclose'][0] > self.inds[d]['bolling'].mid[0]:
                if self.params.using_atr:
                    opt_pos = np.floor(self.atr_initial * self.params.atr_percent / self.params.p_stake / self.inds[d]['atr'][0])
                    if opt_pos*self.params.p_stake > 0 and self.getposition(d).size < opt_pos*self.params.p_stake:
                        buy_list.append((d, 
                                        opt_pos*self.params.p_stake-self.getposition(d).size, 
                                        (opt_pos*self.params.p_stake-self.getposition(d).size)*self.inds[d]['dataclose'][0]))
                        #self.log('BUY CREATE, Code: %s, Price: %.2f, Lots: %i, Current Position: %i' % 
                        #        (d._name, 
                        #         self.inds[d]['dataclose'][0], 
                        #         opt_pos*self.params.p_stake-self.getposition(d).size,
                        #         self.getposition(d).size))
                        #self.buy(data=d, size=opt_pos*self.params.p_stake-self.getposition(d).size, name=d._name)

                    #elif opt_pos*self.params.p_stake > 0 and self.getposition(d).size > opt_pos*self.params.p_stake:
                    #    sell_list.append((d, 
                    #    self.getposition(d).size-opt_pos*self.params.p_stake))
                        #self.log('SELL CREATE, Code: %s, Price: %.2f, Lots: %i, Current Position: %i' % 
                        #        (d._name, 
                        #         self.inds[d]['dataclose'][0], 
                        #         self.getposition(d).size-opt_pos*self.params.p_stake,
                        #         self.getposition(d).size))
                        #self.sell(data=d, size=self.getposition(d).size-opt_pos*self.params.p_stake, name=d._name)
                else:
                    buy_list.append((d, 
                                     opt_pos*self.params.p_stake, 
                                     opt_pos*self.params.p_stake*self.inds[d]['dataclose'][0]))
                    #self.log('BUY CREATE, Code: %s, Price: %.2f, Lots: %i, Current Position: %i' % 
                    #        (d._name, 
                    #         self.inds[d]['dataclose'][0],
                    #         self.params.p_stake,
                    #         self.getposition(d).size))
                    #self.buy(data=d, size=self.params.p_stake, name=d._name)
    
        for s_order in sell_list:
            self.data_tracker = s_order[0]
            self.log('卖单创建, 代码: %s, 价格: %.2f, 股数:%i, 现有持仓: %i' % 
                        (s_order[0]._name, 
                        self.inds[s_order[0]]['dataclose'][0],
                        s_order[1] if s_order[1] != -1 else self.getposition(s_order[0]).size,
                        self.getposition(s_order[0]).size))
            self.sell(data=s_order[0], 
                        size=s_order[1] if s_order[1] != -1 else self.getposition(s_order[0]).size, 
                        name=s_order[0]._name)
        
        #buy_list = sorted(buy_list, key=lambda x: x[2], reverse=False)
        random.shuffle(buy_list)
        for b_order in buy_list:
            self.data_tracker = b_order[0]
            self.log('买单创建, 代码: %s, 价格: %.2f, 股数: %i, 现有持仓: %i' % 
                        (b_order[0]._name, 
                        self.inds[b_order[0]]['dataclose'][0], 
                        b_order[1],
                        self.getposition(b_order[0]).size))
            self.buy(data=b_order[0], size=b_order[1], name=b_order[0]._name)


    def stop(self):
        #for d in self.datas:
        #    if self.getposition(d).size > 0:
        #        self.profit_i[d._name] += self.getposition(d).size * d.close[0]
        #self.log('Ending Value:%.2f.' %
        #        (self.cerebro.broker.getvalue()), doprint=False)
        #print(sorted(self.profit_i.items(), key=lambda x: x[1]))
        #print(sum([x[1] for x in self.profit_i.items()]))
        return

# %% [markdown]
# # 全市场回测

# %% [markdown]
# ### 数据下载

# %%
s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 365 * 2)
e_date = datetime.date(2020, 12, 31)

#s_date = datetime.datetime.now() - datetime.timedelta(days = 365)
#e_date = datetime.datetime.now()

stock_index = '399300.SZ'

# Download Data
utilsJ.index_to_csv_tushare('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6',
                            stock_index, 0.2, s_date, e_date, fpath='.\\Data\\2019\\')

# %% [markdown]
# ### 最优策略回测

# %%
profit_dict = {}

# 904ff4752522814dca00e032a709fdfc26d8744913500ef204e02157
# 74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6

def getdata_mul(s_code, start=datetime.date(2020, 12, 31)-datetime.timedelta(days = 385),
                end = datetime.date(2020, 12, 31)):
    global cerebro
    df = pd.read_csv('.\\Data\\2019\\'+s_code+'.csv', 
                     converters={'trade_date':lambda x:pd.to_datetime(x)}).set_index('trade_date')
    data = bt.feeds.PandasData(dataname=df, fromdate=s_date, todate=e_date)
    cerebro.adddata(data, name=s_code)
    return

s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 385)
e_date = datetime.date(2020, 12, 31)



#stock_index = '399300.SZ'
#pro = ts.pro_api('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6')
#index_list = np.unique(pro.index_weight(index_code=stock_index,
#                                        start_date=s_date.strftime('%Y%m%d'),
#                                        end_date=e_date.strftime('%Y%m%d')).con_code).tolist()


if __name__ == '__main__':
    buy_s = ['b','m','w', 'r', 'wr']
    sell_s = ['b','m','w', 'r', 'wr']
    for s in product(*[buy_s, sell_s]):
        random.seed(10086)
        for i in range(3):
            # Create a cerebro entity
            cerebro = bt.Cerebro(tradehistory=True)

            # Add a strategy
            strats = cerebro.addstrategy(Strategy_comp_mul, printlog=False, using_atr=True, atr_percent=0.01, buy_signal = s[0], sell_signal = s[1])

            t_list = [utilsJ.MyThread(getdata_mul, (s_code, s_date, e_date)) for s_code in index_list]
            [t.start() for t in t_list]
            [t.join() for t in t_list]
            #for s_code in index_list:
            #    df = pd.read_csv('.\\Data\\2020\\'+s_code+'.csv', 
            #                     converters={'trade_date':lambda x:pd.to_datetime(x)}).set_index('trade_date')
            #    data = bt.feeds.PandasData(dataname=df, fromdate=s_date, todate=e_date)

                # Add the index Data Feed to Cerebo
            #    cerebro.adddata(data, name=s_code)
            
            # Set cash inside the strategy
            cerebro.broker = bt.brokers.BackBroker(coc=True)   
            cerebro.broker.setcash(1000000)

            # Set commission
            #cerebro.broker.setcommission()

            # Print out the starting conditions
            start_value = cerebro.broker.getvalue()
            #print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

            # Run over everything
            cerebro.run(maxcpus=8)

            # Print out the final result
            final_value = cerebro.broker.getvalue()
            #print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
            print('(%s, %s) Net Profit: %.2f%%' % (s[0], s[1], (final_value - start_value) / start_value * 100))
            if (s[0], s[1]) not in profit_dict.keys():
                profit_dict[(s[0], s[1])] = []
            profit_dict[(s[0], s[1])].append((final_value - start_value) / start_value * 100)
# Out:
# (b, b) Net Profit: 1.16%
# (b, b) Net Profit: -2.74%
# (b, b) Net Profit: 11.16%
# (b, m) Net Profit: 18.57%
# (b, m) Net Profit: 24.88%
# (b, m) Net Profit: 8.52%
# (b, w) Net Profit: 17.84%
# (b, w) Net Profit: 18.75%
# (b, w) Net Profit: -10.59%
# (b, r) Net Profit: 22.93%
# (b, r) Net Profit: 4.98%
# (b, r) Net Profit: 1.35%
# (b, wr) Net Profit: 12.47%
# (b, wr) Net Profit: -5.15%
# (b, wr) Net Profit: 2.39%
# (m, b) Net Profit: 33.35%
# (m, b) Net Profit: 8.01%
# (m, b) Net Profit: 2.43%
# (m, m) Net Profit: -1.35%
# (m, m) Net Profit: -9.37%
# (m, m) Net Profit: -8.78%
# (m, w) Net Profit: 17.63%
# (m, w) Net Profit: 3.10%
# (m, w) Net Profit: -10.22%
# (m, r) Net Profit: -0.92%
# (m, r) Net Profit: 2.45%
# (m, r) Net Profit: 17.22%
# (m, wr) Net Profit: 17.86%
# (m, wr) Net Profit: -9.89%
# (m, wr) Net Profit: 3.03%
# (w, b) Net Profit: 8.30%
# (w, b) Net Profit: 7.92%
# (w, b) Net Profit: 37.50%
# (w, m) Net Profit: 10.31%
# (w, m) Net Profit: 6.94%
# (w, m) Net Profit: 23.06%
# (w, w) Net Profit: 17.00%
# (w, w) Net Profit: 28.59%
# (w, w) Net Profit: 4.97%
# (w, r) Net Profit: 5.87%
# (w, r) Net Profit: 7.48%
# (w, r) Net Profit: -0.05%
# (w, wr) Net Profit: 6.13%
# (w, wr) Net Profit: -17.88%
# (w, wr) Net Profit: -0.77%
# (r, b) Net Profit: 3.47%
# (r, b) Net Profit: 22.26%
# (r, b) Net Profit: -12.76%
# (r, m) Net Profit: 7.16%
# (r, m) Net Profit: 0.33%
# (r, m) Net Profit: 12.29%
# (r, w) Net Profit: -5.66%
# (r, w) Net Profit: 10.26%
# (r, w) Net Profit: 23.13%
# (r, r) Net Profit: 2.90%

# %% [markdown]
# ### 循环回测

# %%
profit_dict = {}

# 904ff4752522814dca00e032a709fdfc26d8744913500ef204e02157
# 74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6

def getdata_mul(s_code, start=datetime.date(2020, 12, 31)-datetime.timedelta(days = 385),
                end = datetime.date(2020, 12, 31)):
    global cerebro
    df = pd.read_csv('.\\Data\\2020\\'+s_code+'.csv', 
                     converters={'trade_date':lambda x:pd.to_datetime(x)}).set_index('trade_date')
    data = bt.feeds.PandasData(dataname=df, fromdate=s_date, todate=e_date)
    cerebro.adddata(data, name=s_code)
    return

s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 385)
e_date = datetime.date(2020, 12, 31)



stock_index = '399300.SZ'
pro = ts.pro_api('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6')
index_list = np.unique(pro.index_weight(index_code=stock_index,
                                        start_date=s_date.strftime('%Y%m%d'),
                                        end_date=e_date.strftime('%Y%m%d')).con_code).tolist()


if __name__ == '__main__':
    for s in []:
        for i in range(3):
            random.seed(10086)
            # Create a cerebro entity
            cerebro = bt.Cerebro(tradehistory=True)

            # Add a strategy
            strats = cerebro.addstrategy(Strategy_comp_mul, printlog=False, using_atr=True, atr_percent=0.01, buy_signal = s[0], sell_signal = s[1])

            t_list = [utilsJ.MyThread(getdata_mul, (s_code, s_date, e_date)) for s_code in index_list]
            [t.start() for t in t_list]
            [t.join() for t in t_list]
            #for s_code in index_list:
            #    df = pd.read_csv('.\\Data\\2020\\'+s_code+'.csv', 
            #                     converters={'trade_date':lambda x:pd.to_datetime(x)}).set_index('trade_date')
            #    data = bt.feeds.PandasData(dataname=df, fromdate=s_date, todate=e_date)

                # Add the index Data Feed to Cerebo
            #    cerebro.adddata(data, name=s_code)
            
            # Set cash inside the strategy
            cerebro.broker = bt.brokers.BackBroker(coc=True)   
            cerebro.broker.setcash(1000000)

            # Set commission
            #cerebro.broker.setcommission()

            # Print out the starting conditions
            start_value = cerebro.broker.getvalue()
            #print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

            # Run over everything
            cerebro.run(maxcpus=8)

            # Print out the final result
            final_value = cerebro.broker.getvalue()
            #print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
            #print('(%s, %s) Net Profit: %.2f%%' % (s[0], s[1], (final_value - start_value) / start_value * 100))
            print('Net Profit: %.2f%%' % ((final_value - start_value) / start_value * 100))
            if (s[0], s[1]) not in profit_dict.keys():
                profit_dict[(s[0], s[1])] = []
            profit_dict[(s[0], s[1])].append((final_value - start_value) / start_value * 100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7976\2764231869.py in <module>
#      60
#      61             # Run over everything
# ---> 62             cerebro.run(maxcpus=8)
#      63
#      64             # Print out the final result
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\cerebro.py in run(self, **kwargs)
#    1125             # let's skip process "spawning"
#    1126             for iterstrat in iterstrats:
# -> 1127                 runstrat = self.runstrategies(iterstrat)
#    1128                 self.runstrats.append(runstrat)
#    1129                 if self._dooptimize:
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\cerebro.py in runstrategies(self, iterstrat, predata)
#    1291                     self._runonce_old(runstrats)
#    1292                 else:
# -> 1293                     self._runonce(runstrats)
#    1294             else:
#    1295                 if self.p.oldsync:
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\cerebro.py in _runonce(self, runstrats)
#    1693
#    1694             for strat in runstrats:
# -> 1695                 strat._oncepost(dt0)
#    1696                 if self._event_stop:  # stop if requested
#    1697                     return
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\strategy.py in _oncepost(self, dt)
#     293         for indicator in self._lineiterators[LineIterator.IndType]:
#     294             if len(indicator._clock) > len(indicator):
# --> 295                 indicator.advance()
#     296
#     297         if self._oldsync:
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\indicator.py in advance(self, size)
#      97         # different lengths (timeframes)
#      98         if len(self) < len(self._clock):
# ---> 99             self.lines.advance(size=size)
#     100
#     101     def preonce_via_prenext(self, start, end):
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\lineseries.py in advance(self, size)
#     294         '''
#     295         for line in self.lines:
# --> 296             line.advance(size)
#     297
#     298     def buflen(self, line=0):
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\linebuffer.py in advance(self, size)
#     281             size (int): How many extra positions to move forward
#     282         '''
# --> 283         self.idx += size
#     284         self.lencount += size
#     285
#
# d:\Anaconda\envs\py38\lib\site-packages\backtrader\linebuffer.py in set_idx(self, idx, force)
#      83         return self._idx
#      84
# ---> 85     def set_idx(self, idx, force=False):
#      86         # if QBuffer and the last position of the buffer was reached, keep
#      87         # it (unless force) as index 0. This allows resampling
#
# KeyboardInterrupt:

# %%
random.seed(10086)

s_date = datetime.date(2020, 12, 31) - datetime.timedelta(days = 365)
e_date = datetime.date(2020, 12, 31)

stock_index = '399300.SZ'
#pro = ts.pro_api('74f1379591c9d810854fa5891fffcacaba514b82bf17ec2e239025b6')
#index_list = np.unique(pro.index_weight(index_code=stock_index,
#                                        start_date=s_date.strftime('%Y%m%d'),
#                                        end_date=e_date.strftime('%Y%m%d')).con_code).tolist()
profit = []
cerebro = bt.Cerebro(tradehistory=True)

# Add a strategy
strats = cerebro.addstrategy(Strategy_comp_mul, printlog=True, using_atr=True, atr_percent=0.00008, buy_signal = 'wr', sell_signal = 'm') 

for s_code in index_list:
    df = pd.read_csv('.\\Data\\2020\\' + s_code + '.csv')
    df.index=pd.to_datetime(df.trade_date)
    data = bt.feeds.PandasData(dataname=df,fromdate=s_date,todate=e_date)

    # Add the index Data Feed to Cerebo
    cerebro.adddata(data, name = s_code)

# Set cash inside the strategy
cerebro.broker = bt.brokers.BackBroker(coc=True)
cerebro.broker.setcash(1000000)

# Set commission
#cerebro.broker.setcommission()

# Print out the starting conditions
start_value = cerebro.broker.getvalue()
#print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
 现有持仓: 0
# 2020-08-20: 买单创建, 代码: 600535.SH, 价格: 17.40, 股数: 100, 现有持仓: 0
# 2020-08-20: 买单创建, 代码: 600018.SH, 价格: 4.47, 股数: 700, 现有持仓: 0
# 2020-08-20: 买单创建, 代码: 601018.SH, 价格: 3.91, 股数: 900, 现有持仓: 0
# 2020-08-20: 买单创建, 代码: 000338.SZ, 价格: 15.48, 股数: 100, 现有持仓: 0
# 2020-08-20: 买单创建, 代码: 600516.SH, 价格: 6.91, 股数: 300, 现有持仓: 0
# 2020-08-20: 买单创建, 代码: 600100.SH, 价格: 7.82, 股数: 300, 现有持仓: 0
# 2020-08-20: 买单创建, 代码: 688009.SH, 价格: 6.17, 股数: 600, 现有持仓: 0
# 2020-08-20: 买单创建, 代码: 600000.SH, 价格: 10.47, 股数: 400, 现有持仓: 0
# 2020-08-21: 卖单执行, 代码：601298.SH, 价格:6.28, 股数:400, 持有现金:895181
# 2020-08-21: 买单执行, 代码：600498.SH, 价格:27.37, 股数:100, 持有现金:895181
# 2020-08-21: 买单执行, 代码：601766.SH, 价格:5.87, 股数:500, 持有现金:895181
# 2020-08-21: 买单执行, 代码：600352.SH, 价格:14.66, 股数:100, 持有现金:895181
# 2020-08-21: 买单执行, 代码：600271.SH, 价格:17.50, 股数:100, 持有现金:895181
# 2020-08-21: 买单执行, 代码：002252.SZ, 价格:9.34, 股数:200, 持有现金:895181
# 2020-08-21: 买单执行, 代码：601328.SH, 价格:4.77, 股数:100, 持有现金:895181
# 2020-08-21: 买单执行, 代码：002945.SZ, 价格:15.66, 股数:100, 持有现金:895181
# 2020-08-21: 买单执行, 代码：601808.SH, 价格:13.38, 股数:200, 持有现金:895181
# 2020-08-21: 买单执行, 代码：601212.SH, 价格:3.12, 股数:100, 持有现金:895181
# 2020-08-21: 买单执行, 代码：000629.SZ, 价格:2.21, 股数:1100, 持有现金:895181
# 2020-08-21: 买单执行, 代码：600104.SH, 价格:18.16, 股数:200, 持有现金:895181
# 2020-08-21: 买单执行, 代码：600535.SH, 价格:17.40, 股数:100, 持有现金:895181
# 2020-08-21: 买单执行, 代码：600018.SH, 价格:4.47, 股数:700, 持有现金:895181
# 2020-08-21: 买单执行, 代码：601018.SH, 价格:3.91, 股数:900, 持有现金:895181
# 2020-08-21: 买单执行, 代码：000338.SZ, 价格:15.48, 股数:100, 持有现金:895181
# 2020-08-21: 买单执行, 代码：600516.SH, 价格:6.91, 股数:300, 持有现金:895181
# 2020-08-21: 买单执行, 代码：600100.SH, 价格:7.82, 股数:300, 持有现金:895181
# 2020-08-21: 买单执行, 代码：688009.SH, 价格:6.17, 股数:600, 持有现金:895181
# 2020-08-21: 买单执行, 代码：600000.SH, 价格:10.47, 股数:400, 持有现金:895181
# 2020-08-21: 交易收益 代码：601298.SH, 毛利润 4.00, 净利润 4.00
# 2020-08-21: 卖单创建, 代码: 000338.SZ, 价格: 15.39, 股数:100, 现有持仓: 100
# 2020-08-21: 卖单创建, 代码: 002024.SZ, 价格: 10.25, 股数:100, 现有持仓: 100
# 2020-08-21: 卖单创建, 代码: 600516.SH, 价格: 6.94, 股数:300, 现有持仓: 300
# 2020-08-21: 卖单创建, 代码: 601766.SH, 价格: 5.89, 股数:500, 现有持仓: 500
# 2020-08-21: 买单创建, 代码: 000629.SZ, 价格: 2.21, 股数: 100, 现有持仓: 1100
# 2020-08-21: 买单创建, 代码: 601933.SH, 价格: 8.91, 股数: 100, 现有持仓: 300
 股数:100, 持有现金:671708
# 2020-08-28: 买单执行, 代码：601668.SH, 价格:5.10, 股数:100, 持有现金:671708
# 2020-08-28: 买单执行, 代码：600968.SH, 价格:2.50, 股数:100, 持有现金:671708
# 2020-08-28: 交易收益 代码：000069.SZ, 毛利润 -9.00, 净利润 -9.00
# 2020-08-28: 交易收益 代码：000166.SZ, 毛利润 20.00, 净利润 20.00
# 2020-08-28: 交易收益 代码：000776.SZ, 毛利润 12.00, 净利润 12.00
# 2020-08-28: 交易收益 代码：002202.SZ, 毛利润 -83.00, 净利润 -83.00
# 2020-08-28: 交易收益 代码：600010.SH, 毛利润 0.00, 净利润 0.00
# 2020-08-28: 交易收益 代码：600061.SH, 毛利润 -5.00, 净利润 -5.00
# 2020-08-28: 交易收益 代码：600208.SH, 毛利润 21.00, 净利润 21.00
# 2020-08-28: 交易收益 代码：601077.SH, 毛利润 -49.00, 净利润 -49.00
# 2020-08-28: 交易收益 代码：601800.SH, 毛利润 -9.00, 净利润 -9.00
# 2020-08-28: 卖单创建, 代码: 000627.SZ, 价格: 5.64, 股数:300, 现有持仓: 300
# 2020-08-28: 卖单创建, 代码: 600352.SH, 价格: 14.45, 股数:100, 现有持仓: 100
# 2020-08-28: 卖单创建, 代码: 600968.SH, 价格: 2.52, 股数:1500, 现有持仓: 1500
# 2020-08-28: 买单创建, 代码: 600795.SH, 价格: 2.05, 股数: 100, 现有持仓: 1700
# 2020-08-28: 买单创建, 代码: 600606.SH, 价格: 7.88, 股数: 100, 现有持仓: 100
# 2020-08-28: 买单创建, 代码: 002252.SZ, 价格: 9.12, 股数: 100, 现有持仓: 200
# 2020-08-28: 买单创建, 代码: 600068.SH, 价格: 6.43, 股数: 100, 现有持仓: 400
# 2020-08-31: 卖单执行, 代码：000627.SZ, 价格:5.64, 股数:300, 持有现金:676077
# 2020-08-31: 卖单执行, 代码：600352.SH, 价格:14.45, 股数:100, 持有现金:676077
# 2020-08-31: 卖单执行, 代码：600968.SH, 价格:2.52, 股数:1500, 持有现金:676077
# 2020-08-31: 买单执行, 代码：600795.SH, 价格:2.05, 股数:100, 持有现金:676077
# 2020-08-31: 买单执行, 代码：600606.SH, 价格:7.88, 股数:100, 持有现金:676077
# 2020-08-31: 买单执行, 代码：002252.SZ, 价格:9.12, 股数:100, 持有现金:676077
# 2020-08-31: 买单执行, 代码：600068.SH, 价格:6.43, 股数:100, 持有现金:676077
# 2020-08-31: 交易收益 代码：000627.SZ, 毛利润 -27.00, 净利润 -27.00
# 2020-08-31: 交易收益 代码：600352.SH, 毛利润 -21.00, 净利润 -21.00
# 2020-08-31: 交易收益 代码：600968.SH, 毛利润 -12.00, 净利润 -12.00
# 2020-08-31: 卖单创建, 代码: 000898.SZ, 价格: 2.69, 股数:1400, 现有持仓: 1400
# 2020-08-31: 卖单创建, 代码: 600019.SH, 价格: 4.94, 股数:900, 现有持仓: 900
# 2020-08-31: 卖单创建, 代码: 600111.SH, 价格: 12.35, 股数:100, 现有持仓: 100
# 2020-08-31: 卖单创建, 代码: 601018.SH, 价格: 3.71, 股数:100, 现有持仓: 1000
# 2020-09-01: 买单执行, 代码：601600.SH, 价格:3.16, 股数:200, 持有现金:659035
# 2020-09-01: 买单执行, 代码：600705.SH, 价格:5.03, 股数:100, 持有现金:659035
# 2020-09-01: 买单执行, 代码：600516.SH, 价格:6.73, 股数:100, 持有现金:659035
# 2020-09-01: 买单执行, 代码：601669.SH, 价格:4.07, 股数:100, 持有现金:659035
# 2020-09-01: 买单执行, 代码：601077.SH, 价格:5.22, 股数:800, 持有现金:659035
# 2020-09-01: 买单执行, 代码：600000.SH, 价格:10.36, 股数:100, 持有现金:659035
# 2020-09-01: 买单执行, 代码：000066.SZ, 价格:17.71, 股数:100, 持有现金:659035
# 2020-09-01: 买单执行, 代码：000425.SZ, 价格:6.21, 股数:400, 持有现金:659035
# 2020-09-01: 买单执行, 代码：003816.SZ, 价格:3.01, 股数:100, 持有现金:659035
# 2020-09-01: 买单执行, 代码：600048.SH, 价格:16.10, 股数:100, 持有现金:659035
# 2020-09-01: 买单执行, 代码：601800.SH, 价格:7.95, 股数:400, 持有现金:659035
# 2020-09-01: 买单执行, 代码：600383.SH, 价格:14.32, 股数:100, 持有现金:659035
# 2020-09-01: 交易收益 代码：000898.SZ, 毛利润 14.00, 净利润 14.00
# 2020-09-01: 交易收益 代码：600019.SH, 毛利润 36.00, 净利润 36.00
# 2020-09-01: 交易收益 代码：600111.SH, 毛利润 -58.00, 净利润 -58.00
# 2020-09-01: 交易收益 代码：601727.SH, 毛利润 -18.00, 净利润 -18.00
# 2020-09-01: 卖单创建, 代码: 600089.SH, 价格: 8.16, 股数:200, 现有持仓: 200
# 2020-09-01: 卖单创建, 代码: 600170.SH, 价格: 3.16, 股数:500, 现有持仓: 1500
# 2020-09-01: 卖单创建, 代码: 600606.SH, 价格: 7.66, 股数:200, 现有持仓: 200
# 2020-09-01: 卖单创建, 代码: 600663.SH, 价格: 12.44, 股数:200, 现有持仓: 200
# 2020-09-01: 卖单创建, 代码: 601319.SH, 价格: 7.25, 股数:300, 现有持仓: 300
# 2020-09-01: 卖单创建, 代码: 601988.SH, 价格: 3.25, 股数:100, 现有持仓: 2400
# 2020-09-01: 买单创建, 代码: 600018.SH, 价格: 4.42, 股数: 300, 现有持仓: 1000
# 2020-09-01: 买单创建, 代码: 600221.SH, 价格: 1.63, 股数: 300, 现有持仓: 1600
# 2020-09-01: 买单创建, 代码: 600340.SH, 价格: 16.74, 股数: 100, 现有持仓: 100
# 2020-09-01: 买单创建, 代码: 600487.SH, 价格: 16.28, 股数: 200, 现有持仓: 0
# 2020-09-01: 买单创建, 代码: 003816.SZ, 价格: 3.01, 股数: 100, 现有持仓: 1600
# 2020-09-01: 买单创建, 代码: 601872.SH, 价格: 6.38, 股数: 300, 现有持仓: 0
# 2020-09-01: 买单创建, 代码: 600583.SH, 价格: 4.87, 股数: 800, 现有持仓: 0
# 2020-09-01: 买单创建, 代码: 601901.SH, 价格: 8.74, 股数: 100, 现有持仓: 200
# 2020-09-01: 买单创建, 代码: 600795.SH, 价格: 2.04, 股数: 100, 现有持仓: 1800
# 2020-09-01: 买单创建, 代码: 601117.SH, 价格: 5.77, 股数: 600, 现有持仓: 0
# 2020-09-01: 买单创建, 代码: 600332.SH, 价格: 32.35, 股数: 100, 现有持仓: 0
# 2020-09-01: 买单创建, 代码: 000413.SZ, 价格: 3.09, 股数: 400, 现有持仓: 0
# 2020-09-01: 买单创建, 代码:
# 2020-12-28: 买单创建, 代码: 600637.SH, 价格: 8.75, 股数: 100, 现有持仓: 400
# 2020-12-28: 买单创建, 代码: 601988.SH, 价格: 3.17, 股数: 100, 现有持仓: 3200
# 2020-12-28: 买单创建, 代码: 600919.SH, 价格: 5.37, 股数: 100, 现有持仓: 400
# 2020-12-29: 卖单执行, 代码：000415.SZ, 价格:2.37, 股数:100, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：000425.SZ, 价格:5.25, 股数:300, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：002010.SZ, 价格:4.59, 股数:100, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：002027.SZ, 价格:9.59, 股数:100, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：002456.SZ, 价格:13.05, 股数:100, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：002958.SZ, 价格:5.04, 股数:400, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：600050.SH, 价格:4.50, 股数:100, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：600100.SH, 价格:6.03, 股数:100, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：600115.SH, 价格:4.47, 股数:100, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：600271.SH, 价格:12.16, 股数:100, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：600487.SH, 价格:13.55, 股数:100, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：600606.SH, 价格:5.67, 股数:100, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：600977.SH, 价格:11.89, 股数:100, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：601989.SH, 价格:4.07, 股数:100, 持有现金:342582
# 2020-12-29: 卖单执行, 代码：601992.SH, 价格:2.96, 股数:100, 持有现金:342582
# 2020-12-29: 买单执行, 代码：600016.SH, 价格:5.16, 股数:100, 持有现金:342582
# 2020-12-29: 买单执行, 代码：600028.SH, 价格:3.99, 股数:100, 持有现金:342582
# 2020-12-29: 买单执行, 代码：601169.SH, 价格:4.76, 股数:100, 持有现金:342582
# 2020-12-29: 买单执行, 代码：600705.SH, 价格:4.13, 股数:100, 持有现金:342582
# 2020-12-29: 买单执行, 代码：601857.SH, 价格:4.14, 股数:100, 持有现金:342582
# 2020-12-29: 买单执行, 代码：600029.SH, 价格:5.70, 股数:100, 持有现金:342582
# 2020-12-29: 买单执行, 代码：601288.SH, 价格:3.14, 股数:200, 持有现金:342582
# 2020-12-29: 买单执行, 代码：002600.SZ, 价格:12.55, 股数:100, 持有现金:342582
# 2020-12-29: 买单执行, 代码：600637.SH, 价格:8.75, 股数:100, 持有现金:342582
# 2020-12-29: 买单执行, 代码：601988.SH, 价格:3.17, 股数:100, 持有现金:342582
# 2020-12-29: 买单执行, 代码：600919.SH, 价格:5.37, 股数:100, 持有现金:342582
# 2020-12-29: 交易收益 代码：000425.SZ, 毛利润 -458.00, 净利润 -458.00
# 2020-12-29: 交易收益 代码：002027.SZ, 毛利润 517.00, 净利润 517.00
# 2020-12-29: 卖单创建, 代码: 601600.SH, 价格: 3.54, 股数:500, 现有持仓: 500
# 2020-12-29: 买单创建, 代码: 601988.SH, 价格: 3.17, 股数: 200, 现有持仓: 3300
# 2020-12-29: 买单创建, 代码: 002411.SZ, 价格: 5.21, 股数: 100, 现有持仓: 300
# 2020-12-29: 买单创建, 代码: 601939.SH, 价格: 6.25, 股数: 100, 现有持仓: 600
# 2020-12-29: 买单创建, 代码: 601006.SH, 价格: 6.44, 股数: 100, 现有持仓: 700
# 2020-12-29: 买单创建, 代码: 601328.SH, 价格: 4.46, 股数: 200, 现有持仓: 1800
# 2020-12-29: 买单创建, 代码: 601229.SH, 价格: 7.74, 股数: 100, 现有持仓: 800
# 2020-12-29: 买单创建, 代码: 601077.SH, 价格: 4.43, 股数: 100, 现有持仓: 1200
# 2020-12-29: 买单创建, 代码: 600015.SH, 价格: 6.15, 股数: 100, 现有持仓: 900
# 2020-12-29: 买单创建, 代码: 600188.SH, 价格: 10.03, 股数: 100, 现有持仓: 0
# 2020-12-29: 买单创建, 代码: 601766.SH, 价格: 5.32, 股数: 100, 现有持仓: 1000
# 2020-12-29: 买单创建, 代码: 000425.SZ, 价格: 5.30, 股数: 400, 现有持仓: 0
# 2020-12-29: 买单创建, 代码: 600016.SH, 价格: 5.16, 股数: 100, 现有持仓: 1100
# 2020-12-29: 买单创建, 代码: 600019.SH, 价格: 5.88, 股数: 300, 现有持仓: 0
# 2020-12-30: 卖单执行, 代码：601600.SH, 价格:3.54, 股数:500, 持有现金:333269
# 2020-12-30: 买单执行, 代码：601988.SH, 价格:3.17, 股数:200, 持有现金:333269
# 2020-12-30: 买单执行, 代码：002411.SZ, 价格:5.21, 股数:100, 持有现金:333269
# 2020-12-30: 买单执行, 代码：601939.SH, 价格:6.25, 股数:100, 持有现金:333269
# 2020-12-30: 买单执行, 代码：601006.SH, 价格:6.44, 股数:100, 持有现金:333269
# 2020-12-30: 买单执行, 代码：601328.SH, 价格:4.46, 股数:200, 持有现金:333269
# 2020-12-30: 买单执行, 代码：601229.SH, 价格:7.74, 股数:100, 持有现金:333269
# 2020-12-30: 买单执行, 代码：601077.SH, 价格:4.43, 股数:100, 持有现金:333269
# 2020-12-30: 买单执行, 代码：600015.SH, 价格:6.15, 股数:100, 持有现金:333269
# 2020-12-30: 买单执行, 代码：600188.SH, 价格:10.03, 股数:100, 持有现金:333269
# 2020-12-30: 买单执行, 代码：601766.SH, 价格:5.32, 股数:100, 持有现金:333269
# 2020-12-30: 买单执行, 代码：000425.SZ, 价格:5.30, 股数:400, 持有现金:333269
# 2020-12-30: 买单执行, 代码：600016.SH, 价格:5.16, 股数:100, 持有现金:333269
# 2020-12-30: 买单执行, 代码：600019.SH, 价格:5.88, 股数:300, 持有现金:333269
# 2020-12-30: 交易收益 代码：601600.SH, 毛利润 796.00, 净利润 796.00
# 2020-12-30: 卖单创建, 代码: 000671.SZ, 价格: 6.41, 股数:100, 现有持仓: 600
# 2020-12-30: 卖单创建, 代码: 002146.SZ, 价格: 6.48, 股数:100, 现有持仓: 700
# 2020-12-30: 卖单创建, 代码: 601186.SH, 价格: 7.83, 股数:100, 现有持仓: 800
# 2020-12-30: 卖单创建, 代码: 601766.SH, 价格: 5.27, 股数:100, 现有持仓: 1100
# 2020-12-30: 卖单创建, 代码: 603156.SH, 价格: 25.86, 股数:100, 现有持仓: 100
# 2020-12-30: 卖单创建, 代码: 603260.SH, 价格: 33.58, 股数:100, 现有持仓: 100
# 2020-12-30: 买单创建, 代码: 000898.SZ, 价格: 3.06, 股数: 100, 现有持仓: 700
# 2020-12-30: 买单创建, 代码: 601155.SH, 价格: 33.80, 股数: 100, 现有持仓: 0
# 2020-12-30: 买单创建, 代码: